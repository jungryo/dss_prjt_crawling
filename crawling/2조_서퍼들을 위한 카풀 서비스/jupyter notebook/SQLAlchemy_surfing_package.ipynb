# %% [markdown]
# ### SQLAlchemy
# - python 에서 사용하는 ORM
# - ORM : Object Relational Mapping
#     - 데이터 베이스를 객체화 시켜서 데이터 베이스에 있는 데이터를 CRUD 할수 있다.
#     - 쿼리 대신 함수 형태로 CRUD를 할수 있습니다.
#     - 사용하는 데이터 베이스를 변경하는 경우 엔진만 바꿔주면 됩니다.
# - 설치 : `pip install sqlalchemy`

# %%
from sqlalchemy import *
import pandas as pd

# %%
# 데이터 베이스 연결
engine = create_engine("mysql://root:dss@3.34.246.249/WsbFarm?charset=utf8")

# %%
engine
# Out:
# Engine(mysql://root:***@3.34.246.249/WsbFarm?charset=utf8)

# %% [markdown]
# - 데이터 저장하기

# %%
wsbfarm_df = pd.read_csv('wsbfarm.csv')
surfx_df = pd.read_csv('surfx.csv')
# Out:
#       eng      date                                            summary   time  \
# 0    SJH1  20200925  상급자 이상 서핑 가능해요. 서핑 영화 '폭풍속으로'의 마지막 장면을 기억하시나요?...  오후 06
# 1    SJH1  20200926  상급자 이상 서핑 가능해요. 서핑 영화 '폭풍속으로'의 마지막 장면을 기억하시나요?...  오후 03
# 2    SJH1  20200927  상급자 이상 서핑 가능해요. 서핑 영화 '폭풍속으로'의 마지막 장면을 기억하시나요?...  오전 06
# 3    SJH1  20200928  상급자 서핑하기 적당해요. 바다에서 해변으로 다소 약한 바람이 불며 성인 평균키 높...  오후 12
# 4    SJH1  20200929  중급자 서핑하기 적당해요. 바다에서 해변으로 다소 약한 바람이 불며 허리~어깨 높이...  오전 06
# 5    SJH1  20200930  초보자 서핑하기 적당해요. 바다에서 해변으로 다소 약한 바람이 불며 무릎~허리 높이...  오전 06
# 6    SJH1  20201001        초보자 서핑 가능해요. 서핑은 가능하지만 파도면이 고르지 않을 것으로 예상돼요  오후 03
# 7    SJH1  20201002    강한 바람으로 서핑하기 힘들어요. 서핑은 가능하지만 파도면이 너저분할 것으로 예상돼요  오전 09
# 8    SJH1  20201003        초보자 서핑 가능해요. 서핑은 가능하지만 파도면이 고르지 않을 것으로 예상돼요  오전 09
# 9    SJH1  20201004             패들연습 하세요~. 바다에서 바라 본 해변의 풍경은 언제나 진리에요~  오후 03
# 10   GCJ1  20200925  상급자 이상 서핑 가능해요. 서핑 영화 '폭풍속으로'의 마지막 장면을 기억하시나요?...  오후 06
# ...

# %%
wsbfarm_df.to_sql(name="WsbFarm", con=engine, if_exists="replace")
surfx_df.to_sql(name="surfx", con=engine, if_exists="replace")

# %% [markdown]
# - 데이터 가져오기

# %%
QUERY = """
    SELECT *
    FROM WsbFarm
"""
wave_df = pd.read_sql(QUERY, engine)
wave_df.tail()
# Out:
#      index   eng      date                                            summary  \
# 245    245  SKK1  20200930  역스웰에는 파도를 예측하기 힘들어요. 깜짝 파도를 대비해 주기적으로 파도웹캠을 확인...
# 246    246  SKK1  20201001  역스웰에는 파도를 예측하기 힘들어요. 깜짝 파도를 대비해 주기적으로 파도웹캠을 확인...
# 247    247  SKK1  20201002  역스웰에는 파도를 예측하기 힘들어요. 깜짝 파도를 대비해 주기적으로 파도웹캠을 확인...
# 248    248  SKK1  20201003  역스웰에는 파도를 예측하기 힘들어요. 깜짝 파도를 대비해 주기적으로 파도웹캠을 확인...
# 249    249  SKK1  20201004             패들연습 하세요~. 바다에서 바라 본 해변의 풍경은 언제나 진리에요~
#
#       time    wind  temp  wave  wave_tide
# 245  오후 03  3.0m/s    24   0.5       0.75
# 246  오전 09  1.9m/s    20   1.0       2.63
# 247  오전 09  4.3m/s    21   0.5       2.70
# 248  오전 09  1.6m/s    20   0.4       2.73
# 249  오후 03  4.4m/s    24   0.0       1.32
