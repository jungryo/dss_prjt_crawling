# %% [markdown]
# #### url

# %%
query = '성수역'
url = f'https://www.bluer.co.kr/api/v1/restaurants?page=0&size=30&query={query}'
response = requests.get(url)
response.json()['_embedded']['restaurants']
# Out:
# [{'createdDate': 1485411664000,
#   'id': 29014,
#   'headerInfo': {'nameKR': '어니언',
#    'nameEN': 'Onion',
#    'nameCN': '',
#    'nickname': '카페어니언',
#    'year': '2021',
#    'bookYear': '2021',
#    'ribbonType': 'RIBBON_TWO',
#    'ribbonTypeByOrdinal': 1},
#   'defaultInfo': {'chefName': '',
#    'website': 'https://www.instagram.com/cafe.onion',
#    'phone': '02-1644-1941',
#    'openHours': '08:00',
#    'closeHours': '22:00',
#    'openHoursWeekend': '10:00',
#    'closeHoursWeekend': '22:00',
#    'dayOff': '연중무휴',
#    'bcPoint': True},
#   'statusInfo': {'storeType': 'HEAD_STORE',
#    'parking': '불가',
#    'creditCard': 'y',
#    'visit': '성수역 2번 출구에서 직진하다가 첫 번째 골목에서 좌회전하면 우측',
#    'menu': '커피(4천3백원~6천5백원), 차(6천5백원~7천원), 롱페이스트리, 팡도르(각 5천원), 올리브포카치아(3천5백원)',
#    'priceRange': '1만원 미만',
#    'openDate': '201609',
#    'businessHours': '08:00~22:00(마지막 주문 21:30) | 주말 10:00~22:00(마지막 주문 21:30) ',
#    'openEra': '',
#    'newOpenDate': '2016년 09월 '},
#   'timeInfo': {'mondayByOpen': '',
#    'mondayByClose': '',
#    'tuesdayByOpen': '',
#    'tuesdayByClose': '',
#    'wednesdayByOpen': '',
#    'wednesdayByClose': '',
#    'thursdayByOpen': '',
#    'thursdayByClose': '',
#    'fridayByOpen': '',
#    'fridayByClose': '',
#    'saturdayByOpen': '',
#    'saturdayByClose': '',
#    'sundayByOpen': '',
#    'sundayByClose': '',
#    'holidaysByOpen': '',
#    'holidaysByClose': '',
#    'timeEtc': ''},
#   'juso': {'detailAddress': '',
#    'roadAddrPart1': '서울특별시 성동구 아차산로9길 8',
#    'roadAddrPart2': ' (성수동2가)',
#    'jibunAddr': '서울특별시 성동구 성수동2가 277-135',
#    'engAddr': '8, Achasan-ro 9-gil, Seongdong-gu, Seoul',
#    'zipNo': '04797',
#    'admCd': '1120011500',
#    'detBdNmList': '',
#    'bdNm': '',
#    'siNm': '서울특별시',
#    'sggNm': '성동구',
#    'emdNm': '성수동2가',
#    'liNm': '',
#    'rn': '',
#    'buldMnnm': '8',
#    'buldSlno': '0',
#    'zone2_1': '서울 강북',
#    'zone2_2': '성수동',
#    'map_1': '서울 강북지역',
#    'map_2': 'AL-2. 성수역'},
#   'gps': {'latitude': 37.544644, 'longitude': 127.058323},
#   'review': {'review': '공장이었던 옛 공간을 변형한 인더스트리얼 디자인 콘셉트의 베이커리 카페. 공간과 커피와 빵을 만족시키는 곳이다. 브레드05의 오너 셰프와 뎀셀브즈 출신의 바리스타가 함께 운영하고 있다. 2층 베이킹 공간에서 직접 빵을 구우며 독특한 분위기 덕분에 핫한 인기를 끌고 있다. 팡도르가 인기메뉴. ',
#    'readerAppraisal': '“분위기 좋은 성수동의 베이커리 카페. 빵이 아주 맛있고 유행할 만한 제품이다.” “커피 테이크아웃의 가격 경쟁력이 있는 곳.”',
#    'readerReview': '',
#    'businessReview': ''},
#   'tags': '핫플맛집',
#   'etcInfo': {'interior': '',
#    'seat': '',
#    'room': '',
#    'toilet': None,
#    'toiletEtc': '',
#    'chain': False,
#    'close': False,
#    'renewal': False,
#    'appYn': False,
#    'reviewerRecommend': False,
#    'onlySiteView': False,
#    'head': None,
#    'branch': '분점 미아점(070-7816-2714), 안국점9070-7543-2123',
#    'history': '',
#    'mainMemo': '200619_메뉴가격수정\r\n190805_전화번호 변경 : 070-7816-2710 > 02-1644-1941\r\n'},
#   'status': 'ACTIVE',
#   'bookStatus': 'APPROVAL',
#   'buzUsername': '',
#   'business': False,
#   'pageView': 1133,
#   'orderDescending': 0,
#   'foodTypeDetails': None,
#   'features': None,
#   'countEvaluate': 0,
#   'bookmark': False,
#   'firstImage': {'url': '/images/es_5aebde5e547643709f43c31c344d70f9.jpg',
#    'createdDate': 1596655491000,
#    'orderAscending': 0},
#   'foodTypes': ['디저트/차/베이커리', '베이커리', '카페'],
#   '_links': {'self': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29014'},
#    'restaurant': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29014{?projection}',
#     'templated': True},
#    'relativeWriter': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29014/relativeWriter'},
#    'branches': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29014/branches'},
#    'headBranch': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29014/headBranch'},
#    'restaurantFeatures': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29014/restaurantFeatures'},
#    'reports': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29014/reports'},
#    'evaluates': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29014/evaluates'},
#    'foodTypeCategories': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29014/foodTypeCategories'},
#    'relativeBusinessOrder': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29014/relativeBusinessOrder'}}},
#  {'createdDate': 1494900248000,
#   'id': 29118,
#   'headerInfo': {'nameKR': '어반소스',
#    'nameEN': 'Urban Source',
#    'nameCN': '',
#    'nickname': '',
#    'year': '2021',
#    'bookYear': '2021',
#    'ribbonType': 'RIBBON_TWO',
#    'ribbonTypeByOrdinal': 1},
#   'defaultInfo': {'chefName': '',
#    'website': 'http://urbansource.co.kr/',
#    'phone': '02-462-6262',
#    'openHours': '11:00',
#    'closeHours': '00:00',
#    'openHoursWeekend': '',
#    'closeHoursWeekend': '',
#    'dayOff': '연중무휴',
#    'bcPoint': False},
#   'statusInfo': {'storeType': 'NOT',
#    'parking': '불가',
#    'creditCard': 'y',
#    'visit': '성수역 4번 출구에서 직진. 성수근린공원에서 좌회전하면 우측',
#    'menu': '베리에이션커피(4천5백원~6천5백원), 에이드(6천5백원), 과일타르트(8천5백원)',
#    'priceRange': '1만원 미만',
#    'openDate': '201704',
#    'businessHours': '11:00~23:00(마지막 주문 22:30) ',
#    'openEra': '',
#    'newOpenDate': '2017년 04월 '},
#   'timeInfo': {'mondayByOpen': '',
#    'mondayByClose': '',
#    'tuesdayByOpen': '',
#    'tuesdayByClose': '',
#    'wednesdayByOpen': '',
#    'wednesdayByClose': '',
#    'thursdayByOpen': '',
#    'thursdayByClose': '',
#    'fridayByOpen': '',
#    'fridayByClose': '',
#    'saturdayByOpen': '',
#    'saturdayByClose': '',
#    'sundayByOpen': '',
#    'sundayByClose': '',
#    'holidaysByOpen': '',
#    'holidaysByClose': '',
#    'timeEtc': ''},
#   'juso': {'detailAddress': '',
#    'roadAddrPart1': '서울특별시 성동구 연무장3길 9',
#    'roadAddrPart2': ' (성수동2가)',
#    'jibunAddr': '서울특별시 성동구 성수동2가 301-16',
#    'engAddr': '9, Yeonmujang 3-gil, Seongdong-gu, Seoul',
#    'zipNo': '04782',
#    'admCd': '1120011500',
#    'detBdNmList': '',
#    'bdNm': '',
#    'siNm': '서울특별시',
#    'sggNm': '성동구',
#    'emdNm': '성수동2가',
#    'liNm': '',
#    'rn': '',
#    'buldMnnm': '9',
#    'buldSlno': '0',
#    'zone2_1': '서울 강북',
#    'zone2_2': '성수동',
#    'map_1': '서울 강북지역',
#    'map_2': 'AL-2. 성수역'},
#   'gps': {'latitude': 37.544547, 'longitude': 127.051229},
#   'review': {'review': '성수동 카페거리에서 핫한 곳 중 하나. 다양한 종류의 빵을 선보이며, ‘차만다’라는 레스토랑도 함께 운영하고 있다. 공장을 개조한 곳으로, 감각적인 인더스트리얼 디자인 인테리어가 단연 시선을 끈다. 푸른 정원이 있는 야외 테라스 자리와 정원이 내다보이는 창가 자리가 인기다.',
#    'readerAppraisal': None,
#    'readerReview': '',
#    'businessReview': ''},
#   'tags': '',
#   'etcInfo': {'interior': '',
#    'seat': '',
#    'room': '',
#    'toilet': None,
#    'toiletEtc': '',
#    'chain': False,
#    'close': False,
#    'renewal': False,
#    'appYn': True,
#    'reviewerRecommend': False,
#    'onlySiteView': False,
#    'head': None,
#    'branch': None,
#    'history': '',
#    'mainMemo': '190801_음식종류 변경: 기타 > 카페\r\n200618_메뉴가격 수정, 웹사이트 변경(https://www.facebook.com/urbansource.official > '},
#   'status': 'ACTIVE',
#   'bookStatus': 'APPROVAL',
#   'buzUsername': '',
#   'business': False,
#   'pageView': 856,
#   'orderDescending': 0,
#   'foodTypeDetails': None,
#   'features': None,
#   'countEvaluate': 0,
#   'bookmark': False,
#   'firstImage': {'url': '/images/es_97997a8f07534acc855a82829c6b317d.jpg',
#    'createdDate': 1595826391000,
#    'orderAscending': 0},
#   'foodTypes': ['디저트/차/베이커리', '카페'],
#   '_links': {'self': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29118'},
#    'restaurant': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29118{?projection}',
#     'templated': True},
#    'relativeWriter': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29118/relativeWriter'},
#    'branches': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29118/branches'},
#    'headBranch': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29118/headBranch'},
#    'restaurantFeatures': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29118/restaurantFeatures'},
#    'reports': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29118/reports'},
#    'evaluates': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29118/evaluates'},
#    'foodTypeCategories': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29118/foodTypeCategories'},
#    'relativeBusinessOrder': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29118/relativeBusinessOrder'}}},
#  {'createdDate': 1471233677000,
#   'id': 28629,
#   'headerInfo': {'nameKR': '대림창고',
#    'nameEN': '',
#    'nameCN': '',
#    'nickname': '성수동대림창고갤러리컬럼',
#    'year': '2021',
#    'bookYear': '2021',
#    'ribbonType': 'RIBBON_ONE',
#    'ribbonTypeByOrdinal': 2},
#   'defaultInfo': {'chefName': '',
#    'website': 'https://www.instagram.com/daelim_changgo',
#    'phone': '02-499-9669',
#    'openHours': '11:00',
#    'closeHours': '23:00',
#    'openHoursWeekend': '',
#    'closeHoursWeekend': '',
#    'dayOff': '명절 당일 휴무',
#    'bcPoint': False},
#   'statusInfo': {'storeType': 'NOT',
#    'parking': '불가',
#    'creditCard': 'y',
#    'visit': '성수역 3번 출구에서 우회전',
#    'menu': '베리에이션커피(5천원~1만4천원), 차(8천원), 파스타, 리조토(각 1만7천원~1만9천원), 피자(2만2천원~2만5천원), 맥주(8천원~2만원)',
#    'priceRange': '1만원 미만',
#    'openDate': '201605',
#    'businessHours': '11:00~23:00 ',
#    'openEra': '',
#    'newOpenDate': '2016년 05월 '},
#   'timeInfo': {'mondayByOpen': '',
#    'mondayByClose': '',
#    'tuesdayByOpen': '',
#    'tuesdayByClose': '',
#    'wednesdayByOpen': '',
#    'wednesdayByClose': '',
#    'thursdayByOpen': '',
#    'thursdayByClose': '',
#    'fridayByOpen': '',
#    'fridayByClose': '',
#    'saturdayByOpen': '',
#    'saturdayByClose': '',
#    'sundayByOpen': '',
#    'sundayByClose': '',
#    'holidaysByOpen': '',
#    'holidaysByClose': '',
#    'timeEtc': ''},
#   'juso': {'detailAddress': '',
#    'roadAddrPart1': '서울특별시 성동구 성수이로 78',
#    'roadAddrPart2': ' (성수동2가)',
#    'jibunAddr': '서울특별시 성동구 성수동2가 322-32 대림창고',
#    'engAddr': '78, Seongsui-ro, Seongdong-gu, Seoul',
#    'zipNo': '04784',
#    'admCd': '1120011500',
#    'detBdNmList': '',
#    'bdNm': '대림창고',
#    'siNm': '서울특별시',
#    'sggNm': '성동구',
#    'emdNm': '성수동2가',
#    'liNm': '',
#    'rn': '',
#    'buldMnnm': '78',
#    'buldSlno': '0',
#    'zone2_1': '서울 강북',
#    'zone2_2': '성수동',
#    'map_1': '서울 강북지역',
#    'map_2': 'AL-2. 성수역'},
#   'gps': {'latitude': 37.541826, 'longitude': 127.056293},
#   'review': {'review': '옛 창고 건물을 개조하여 독특한 분위기를 풍기는 카페 겸 갤러리. 높은 층고와 감각적인 분위기가 인상적이다. 커피와 음료를 비롯해 피자, 파스타 등의 요리도 다양하게 선보인다. 맥주와 와인 등도 있어 술 한잔하기에도 좋다. 갤러리를 겸하고 있어 주말에는 입장권을 구매해야 하며 음료 1잔이 포함된다.',
#    'readerAppraisal': '“분위기가 좋다. 서울숲 둘러보고 쉬기 좋은 장소다.”',
#    'readerReview': '',
#    'businessReview': ''},
#   'tags': '',
#   'etcInfo': {'interior': '',
#    'seat': '',
#    'room': '',
#    'toilet': None,
#    'toiletEtc': '',
#    'chain': False,
#    'close': False,
#    'renewal': False,
#    'appYn': False,
#    'reviewerRecommend': False,
#    'onlySiteView': False,
#    'head': None,
#    'branch': None,
#    'history': '',
#    'mainMemo': '170904_전화번호 수정 - 02-498-7474>499-9669'},
#   'status': 'ACTIVE',
#   'bookStatus': 'APPROVAL',
#   'buzUsername': '',
#   'business': False,
#   'pageView': 340,
#   'orderDescending': 0,
#   'foodTypeDetails': None,
#   'features': None,
#   'countEvaluate': 0,
#   'bookmark': False,
#   'firstImage': None,
#   'foodTypes': ['디저트/차/베이커리', '카페'],
#   '_links': {'self': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28629'},
#    'restaurant': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28629{?projection}',
#     'templated': True},
#    'relativeWriter': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28629/relativeWriter'},
#    'branches': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28629/branches'},
#    'headBranch': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28629/headBranch'},
#    'restaurantFeatures': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28629/restaurantFeatures'},
#    'reports': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28629/reports'},
#    'evaluates': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28629/evaluates'},
#    'foodTypeCategories': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28629/foodTypeCategories'},
#    'relativeBusinessOrder': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28629/relativeBusinessOrder'}}},
#  {'createdDate': 1458795153000,
#   'id': 28450,
#   'headerInfo': {'nameKR': '렁팡스',
#    'nameEN': "L'enfance",
#    'nameCN': '',
#    'nickname': '',
#    'year': '2021',
#    'bookYear': '2021',
#    'ribbonType': 'RIBBON_ONE',
#    'ribbonTypeByOrdinal': 2},
#   'defaultInfo': {'chefName': '',
#    'website': 'http://www.lenfance.net',
#    'phone': '02-465-7117',
#    'openHours': '',
#    'closeHours': '',
#    'openHoursWeekend': '',
#    'closeHoursWeekend': '',
#    'dayOff': '일, 월요일, 명절 휴무',
#    'bcPoint': True},
#   'statusInfo': {'storeType': 'NOT',
#    'parking': '불가',
#    'creditCard': 'y',
#    'visit': '건대입구역 6번 출구에서 직진. 성수사거리에서 좌회전 후 IBK기업은행에서 우회전',
#    'menu': '런치메뉴(1만6천원), 채끝등심스테이크(210g 4만5천원), 파스타(2만1천원~2만3천원)',
#    'priceRange': '2~4만원대',
#    'openDate': '201602',
#    'businessHours': '12:00~15:00(마지막 주문 14:00)/18:00~23:00(마지막 주문 21:00) ',
#    'openEra': '',
#    'newOpenDate': '2016년 02월 '},
#   'timeInfo': {'mondayByOpen': '',
#    'mondayByClose': '',
#    'tuesdayByOpen': '',
#    'tuesdayByClose': '',
#    'wednesdayByOpen': '',
#    'wednesdayByClose': '',
#    'thursdayByOpen': '',
#    'thursdayByClose': '',
#    'fridayByOpen': '',
#    'fridayByClose': '',
#    'saturdayByOpen': '',
#    'saturdayByClose': '',
#    'sundayByOpen': '',
#    'sundayByClose': '',
#    'holidaysByOpen': '',
#    'holidaysByClose': '',
#    'timeEtc': ''},
#   'juso': {'detailAddress': '',
#    'roadAddrPart1': '서울특별시 성동구 연무장길 106',
#    'roadAddrPart2': ' (성수동2가)',
#    'jibunAddr': '서울특별시 성동구 성수동2가 272-41',
#    'engAddr': '106, Yeonmujang-gil, Seongdong-gu, Seoul',
#    'zipNo': '04785',
#    'admCd': '1120011500',
#    'detBdNmList': '',
#    'bdNm': '',
#    'siNm': '서울특별시',
#    'sggNm': '성동구',
#    'emdNm': '성수동2가',
#    'liNm': '',
#    'rn': '뚝섬로17길',
#    'buldMnnm': '106',
#    'buldSlno': '0',
#    'zone2_1': '서울 강북',
#    'zone2_2': '성수동',
#    'map_1': '서울 강북지역',
#    'map_2': 'AL-2. 성수역'},
#   'gps': {'latitude': 37.540744672905426, 'longitude': 127.06068068626368},
#   'review': {'review': '성수동에 자리한 프렌치 비스트로. 견과류와 치즈가 올라간 엔다이브와 풍부한 육즙이 인상적인 채끝등심스테이크와 달고기 등이 인기메뉴다. 런치타임에는 파스타와 리조토, 브런치 등을 비교적 저렴한 가격에 주문할 수 있다.',
#    'readerAppraisal': None,
#    'readerReview': '',
#    'businessReview': ''},
#   'tags': '',
#   'etcInfo': {'interior': '클래식한 유럽풍',
#    'seat': '',
#    'room': '',
#    'toilet': None,
#    'toiletEtc': '',
#    'chain': False,
#    'close': False,
#    'renewal': False,
#    'appYn': False,
#    'reviewerRecommend': False,
#    'onlySiteView': False,
#    'head': None,
#    'branch': None,
#    'history': '',
#    'mainMemo': '200611_메뉴 가격 수정'},
#   'status': 'ACTIVE',
#   'bookStatus': 'APPROVAL',
#   'buzUsername': '',
#   'business': False,
#   'pageView': 690,
#   'orderDescending': 0,
#   'foodTypeDetails': None,
#   'features': None,
#   'countEvaluate': 0,
#   'bookmark': False,
#   'firstImage': None,
#   'foodTypes': ['술집', '프렌치펍'],
#   '_links': {'self': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28450'},
#    'restaurant': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28450{?projection}',
#     'templated': True},
#    'relativeWriter': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28450/relativeWriter'},
#    'branches': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28450/branches'},
#    'headBranch': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28450/headBranch'},
#    'restaurantFeatures': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28450/restaurantFeatures'},
#    'reports': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28450/reports'},
#    'evaluates': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28450/evaluates'},
#    'foodTypeCategories': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28450/foodTypeCategories'},
#    'relativeBusinessOrder': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28450/relativeBusinessOrder'}}},
#  {'createdDate': 1515219719000,
#   'id': 29273,
#   'headerInfo': {'nameKR': '밀본',
#    'nameEN': '',
#    'nameCN': '',
#    'nickname': '',
#    'year': '2021',
#    'bookYear': '2021',
#    'ribbonType': 'RIBBON_ONE',
#    'ribbonTypeByOrdinal': 2},
#   'defaultInfo': {'chefName': '',
#    'website': 'https://mealbon.modoo.at/',
#    'phone': '02-499-9801',
#    'openHours': '11:00',
#    'closeHours': '22:00',
#    'openHoursWeekend': '',
#    'closeHoursWeekend': '',
#    'dayOff': '주말, 공휴일 휴무',
#    'bcPoint': False},
#   'statusInfo': {'storeType': 'NOT',
#    'parking': '가능',
#    'creditCard': 'y',
#    'visit': '성수역 1번 출구에서 뚝섬역 방향으로 직진. 삼덕창고에서 우회전 후 좌회전하면 좌측',
#    'menu': '손칼국수, 고기덮밥, 손만두(각 8천원), 녹두전(1만1천원), 매운닭봉(1만6천원), 군만두(1만2천원)',
#    'priceRange': '1만원 미만',
#    'openDate': '2014',
#    'businessHours': '11:00~21:00 ',
#    'openEra': '',
#    'newOpenDate': '2014년 '},
#   'timeInfo': {'mondayByOpen': '',
#    'mondayByClose': '',
#    'tuesdayByOpen': '',
#    'tuesdayByClose': '',
#    'wednesdayByOpen': '',
#    'wednesdayByClose': '',
#    'thursdayByOpen': '',
#    'thursdayByClose': '',
#    'fridayByOpen': '',
#    'fridayByClose': '',
#    'saturdayByOpen': '',
#    'saturdayByClose': '',
#    'sundayByOpen': '',
#    'sundayByClose': '',
#    'holidaysByOpen': '',
#    'holidaysByClose': '',
#    'timeEtc': ''},
#   'juso': {'detailAddress': 'KIMG빌딩 1층',
#    'roadAddrPart1': '서울특별시 성동구 아차산로 67-16',
#    'roadAddrPart2': ' (성수동2가)',
#    'jibunAddr': '서울특별시 성동구 성수동2가 300-80 케이아이엠지빌딩',
#    'engAddr': '67-16, Achasan-ro, Seongdong-gu, Seoul',
#    'zipNo': '04793',
#    'admCd': '1120011500',
#    'detBdNmList': '',
#    'bdNm': '케이아이엠지빌딩',
#    'siNm': '서울특별시',
#    'sggNm': '성동구',
#    'emdNm': '성수동2가',
#    'liNm': '',
#    'rn': '아차산로',
#    'buldMnnm': '67',
#    'buldSlno': '16',
#    'zone2_1': '서울 강북',
#    'zone2_2': '성수동',
#    'map_1': '서울 강북지역',
#    'map_2': 'AL-2. 성수역'},
#   'gps': {'latitude': 37.54647, 'longitude': 127.051394},
#   'review': {'review': '직접 자가제면한 면을 사용하는 칼국숫집. 한우 사골 육수를 사용하는 것이 특징이며 도톰한 면발과 잘 어울린다. 속이 꽉 찬 손만두나 녹두전 등을 곁들이면 더욱 좋다.',
#    'readerAppraisal': '“깔끔하면서도 진하게 다가오는 국물 맛이 좋다. 면도 고기 국물에 잘 어울릴 만한 정도다.”',
#    'readerReview': '',
#    'businessReview': ''},
#   'tags': '',
#   'etcInfo': {'interior': '',
#    'seat': '',
#    'room': '',
#    'toilet': None,
#    'toiletEtc': '',
#    'chain': False,
#    'close': False,
#    'renewal': False,
#    'appYn': False,
#    'reviewerRecommend': False,
#    'onlySiteView': False,
#    'head': None,
#    'branch': None,
#    'history': '',
#    'mainMemo': '200618_영업시간수정'},
#   'status': 'ACTIVE',
#   'bookStatus': 'APPROVAL',
#   'buzUsername': '',
#   'business': False,
#   'pageView': 490,
#   'orderDescending': 0,
#   'foodTypeDetails': None,
#   'features': None,
#   'countEvaluate': 0,
#   'bookmark': False,
#   'firstImage': None,
#   'foodTypes': ['한식(면류)', '만두', '칼국수'],
#   '_links': {'self': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29273'},
#    'restaurant': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29273{?projection}',
#     'templated': True},
#    'relativeWriter': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29273/relativeWriter'},
#    'branches': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29273/branches'},
#    'headBranch': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29273/headBranch'},
#    'restaurantFeatures': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29273/restaurantFeatures'},
#    'reports': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29273/reports'},
#    'evaluates': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29273/evaluates'},
#    'foodTypeCategories': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29273/foodTypeCategories'},
#    'relativeBusinessOrder': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29273/relativeBusinessOrder'}}},
#  {'createdDate': 1494899980000,
#   'id': 29116,
#   'headerInfo': {'nameKR': '살로토봄봄',
#    'nameEN': 'SALOTTO BOMBOM',
#    'nameCN': '',
#    'nickname': '봄봄성수',
#    'year': '2021',
#    'bookYear': '2021',
#    'ribbonType': 'RIBBON_ONE',
#    'ribbonTypeByOrdinal': 2},
#   'defaultInfo': {'chefName': '임도경',
#    'website': 'https://www.salottobombom.com/',
#    'phone': '02-460-8875',
#    'openHours': '11:30',
#    'closeHours': '22:00',
#    'openHoursWeekend': '11:30',
#    'closeHoursWeekend': '22:00',
#    'dayOff': '일요일 휴무',
#    'bcPoint': False},
#   'statusInfo': {'storeType': 'NOT',
#    'parking': '가능',
#    'creditCard': 'y',
#    'visit': '성수역 4번 출구에서 직진하면 좌측',
#    'menu': '피자(2만1천원~2만4천원), 파스타(1만8천원~3만2천원), 리조토(2만2천원~2만4천원), 포르치니채끝등심스테이크(230g 5만5천원), 런치코스(1인 3만5천원)',
#    'priceRange': '4~10만원대',
#    'openDate': '2016',
#    'businessHours': '11:30~15:30/17:00~22:00 | 토요일 11:30~22:00(마지막 주문 21:00) ',
#    'openEra': '',
#    'newOpenDate': '2016년 '},
#   'timeInfo': {'mondayByOpen': '',
#    'mondayByClose': '',
#    'tuesdayByOpen': '',
#    'tuesdayByClose': '',
#    'wednesdayByOpen': '',
#    'wednesdayByClose': '',
#    'thursdayByOpen': '',
#    'thursdayByClose': '',
#    'fridayByOpen': '',
#    'fridayByClose': '',
#    'saturdayByOpen': '',
#    'saturdayByClose': '',
#    'sundayByOpen': '',
#    'sundayByClose': '',
#    'holidaysByOpen': '',
#    'holidaysByClose': '',
#    'timeEtc': ''},
#   'juso': {'detailAddress': '',
#    'roadAddrPart1': '서울특별시 성동구 아차산로 78',
#    'roadAddrPart2': ' (성수동2가)',
#    'jibunAddr': '서울특별시 성동구 성수동2가 302-4 남양에코넷센터',
#    'engAddr': '78, Achasan-ro, Seongdong-gu, Seoul',
#    'zipNo': '04782',
#    'admCd': '1120011500',
#    'detBdNmList': '',
#    'bdNm': '남양에코넷센터',
#    'siNm': '서울특별시',
#    'sggNm': '성동구',
#    'emdNm': '성수동2가',
#    'liNm': '',
#    'rn': '',
#    'buldMnnm': '78',
#    'buldSlno': '0',
#    'zone2_1': '서울 강북',
#    'zone2_2': '성수동',
#    'map_1': '서울 강북지역',
#    'map_2': 'AL-2. 성수역'},
#   'gps': {'latitude': 37.545233, 'longitude': 127.052604},
#   'review': {'review': '제철 재료를 활용한 이탈리아 음식을 선보이는 곳. 다양한 종류의 파스타와 리조토, 피자 등을 선보이며 만족도가 높다. 실내가 넓고 따뜻한 분위기로 꾸몄으며 곳곳에 그림이 걸려 있어 분위기를 더한다.',
#    'readerAppraisal': None,
#    'readerReview': '',
#    'businessReview': ''},
#   'tags': '',
#   'etcInfo': {'interior': '',
#    'seat': '',
#    'room': '',
#    'toilet': None,
#    'toiletEtc': '',
#    'chain': False,
#    'close': False,
#    'renewal': False,
#    'appYn': False,
#    'reviewerRecommend': False,
#    'onlySiteView': False,
#    'head': None,
#    'branch': None,
#    'history': '',
#    'mainMemo': '200619_메뉴가격수정, 영업시간 수정'},
#   'status': 'ACTIVE',
#   'bookStatus': 'APPROVAL',
#   'buzUsername': '',
#   'business': False,
#   'pageView': 608,
#   'orderDescending': 0,
#   'foodTypeDetails': None,
#   'features': None,
#   'countEvaluate': 0,
#   'bookmark': False,
#   'firstImage': None,
#   'foodTypes': ['이탈리아식', '파스타'],
#   '_links': {'self': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29116'},
#    'restaurant': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29116{?projection}',
#     'templated': True},
#    'relativeWriter': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29116/relativeWriter'},
#    'branches': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29116/branches'},
#    'headBranch': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29116/headBranch'},
#    'restaurantFeatures': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29116/restaurantFeatures'},
#    'reports': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29116/reports'},
#    'evaluates': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29116/evaluates'},
#    'foodTypeCategories': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29116/foodTypeCategories'},
#    'relativeBusinessOrder': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29116/relativeBusinessOrder'}}},
#  {'createdDate': 1295497858000,
#   'id': 5905,
#   'headerInfo': {'nameKR': '성수족발',
#    'nameEN': '',
#    'nameCN': '',
#    'nickname': '',
#    'year': '2021',
#    'bookYear': '2021',
#    'ribbonType': 'RIBBON_ONE',
#    'ribbonTypeByOrdinal': 2},
#   'defaultInfo': {'chefName': '',
#    'website': 'https://blog.naver.com/ssjb1983',
#    'phone': '02-464-0425',
#    'openHours': '',
#    'closeHours': '',
#    'openHoursWeekend': '',
#    'closeHoursWeekend': '',
#    'dayOff': '명절 휴무',
#    'bcPoint': False},
#   'statusInfo': {'storeType': 'NOT',
#    'parking': '불가',
#    'creditCard': 'y',
#    'visit': '성수역 1번 출구에서 직진. 첫 번째 골목에서 우회전하면 좌측',
#    'menu': '족발(중 4만원, 대 4만5천원, 특대 5만원), 순댓국(6천원)',
#    'priceRange': '1~2만원대',
#    'openDate': '1983',
#    'businessHours': '12:00~22:00 ',
#    'openEra': '',
#    'newOpenDate': '1983년 '},
#   'timeInfo': {'mondayByOpen': '',
#    'mondayByClose': '',
#    'tuesdayByOpen': '',
#    'tuesdayByClose': '',
#    'wednesdayByOpen': '',
#    'wednesdayByClose': '',
#    'thursdayByOpen': '',
#    'thursdayByClose': '',
#    'fridayByOpen': '',
#    'fridayByClose': '',
#    'saturdayByOpen': '',
#    'saturdayByClose': '',
#    'sundayByOpen': '',
#    'sundayByClose': '',
#    'holidaysByOpen': '',
#    'holidaysByClose': '',
#    'timeEtc': ''},
#   'juso': {'detailAddress': '동진빌딩 1층',
#    'roadAddrPart1': '서울특별시 성동구 아차산로7길 7',
#    'roadAddrPart2': ' (성수동2가)',
#    'jibunAddr': '서울특별시 성동구 성수동2가 289-273',
#    'engAddr': '7, Achasan-ro 7-gil, Seongdong-gu, Seoul',
#    'zipNo': '04793',
#    'admCd': '1120011500',
#    'detBdNmList': '가동',
#    'bdNm': '',
#    'siNm': '서울특별시',
#    'sggNm': '성동구',
#    'emdNm': '성수동2가',
#    'liNm': '',
#    'rn': '아차산로7길',
#    'buldMnnm': '7',
#    'buldSlno': '0',
#    'zone2_1': '서울 강북',
#    'zone2_2': '성수동',
#    'map_1': '서울 강북지역',
#    'map_2': 'AL-2. 성수역'},
#   'gps': {'latitude': 37.54599, 'longitude': 127.0542},
#   'review': {'review': '서울의 3대 족발집 중 하나로 불리는 곳. 자르르 흐르는 윤기처럼 매우 쫄깃한 맛의 족발이다. 살코기와 껍질 부분의 비율이 잘 맞아 너무 느끼하지도, 그렇다고 퍽퍽하지도 않다. 겨울에는 족발 외에 순댓국도 판매한다.',
#    'readerAppraisal': '“담백한 성수족발. 자리가 협소한게 흠이라면 흠이다. 맛있다.” “처음 먹었을 때 족발의 쫄깃함에 놀랐다. 왜 3대 족발인지 알 것 같았다!” “최고의 맛. 최고의 가격. 4인 기준 특대가 최선의 선택!” “성수족발 먹다가 다른 족발 못 먹겠다.” “달착지근하고 짭짤한 맛과 야들한 식감이 특징으로, 처음 먹을 때 임팩트 있게 다가온다. 함께 곁들여 나오는 부추무침이 맛있다.” “서울 3대 족발 중에 부드럽고 가장 달달한 족발인 듯.”',
#    'readerReview': '',
#    'businessReview': ''},
#   'tags': '',
#   'etcInfo': {'interior': '',
#    'seat': '',
#    'room': '',
#    'toilet': None,
#    'toiletEtc': '',
#    'chain': False,
#    'close': False,
#    'renewal': False,
#    'appYn': False,
#    'reviewerRecommend': False,
#    'onlySiteView': False,
#    'head': None,
#    'branch': None,
#    'history': '',
#    'mainMemo': '160520_빌딩명추가 - 동진빌딩 1층 \r\n 150716_전화번호 수정: 02-484-0425 > 02-464-0425'},
#   'status': 'ACTIVE',
#   'bookStatus': 'APPROVAL',
#   'buzUsername': '',
#   'business': False,
#   'pageView': 274,
#   'orderDescending': 0,
#   'foodTypeDetails': None,
#   'features': None,
#   'countEvaluate': 0,
#   'bookmark': False,
#   'firstImage': None,
#   'foodTypes': ['한식(육류)', '족발'],
#   '_links': {'self': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/5905'},
#    'restaurant': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/5905{?projection}',
#     'templated': True},
#    'relativeWriter': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/5905/relativeWriter'},
#    'branches': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/5905/branches'},
#    'headBranch': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/5905/headBranch'},
#    'restaurantFeatures': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/5905/restaurantFeatures'},
#    'reports': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/5905/reports'},
#    'evaluates': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/5905/evaluates'},
#    'foodTypeCategories': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/5905/foodTypeCategories'},
#    'relativeBusinessOrder': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/5905/relativeBusinessOrder'}}},
#  {'createdDate': 1556467162000,
#   'id': 30071,
#   'headerInfo': {'nameKR': '세스크멘슬',
#    'nameEN': 'XESC MENZL',
#    'nameCN': '',
#    'nickname': '',
#    'year': '2021',
#    'bookYear': '2021',
#    'ribbonType': 'RIBBON_ONE',
#    'ribbonTypeByOrdinal': 2},
#   'defaultInfo': {'chefName': '김정현',
#    'website': 'https://www.instagram.com/xescmenzl',
#    'phone': '02-6082-0393',
#    'openHours': '',
#    'closeHours': '',
#    'openHoursWeekend': '',
#    'closeHoursWeekend': '',
#    'dayOff': '월요일 휴무',
#    'bcPoint': False},
#   'statusInfo': {'storeType': 'NOT',
#    'parking': '불가',
#    'creditCard': 'y',
#    'visit': '성수역 3번 출구에서 우회전 후 직진. 동양카센타에서 좌회전',
#    'menu': '위너부어스트, 할라피뇨부어스트(각 100g 5천원), 샌드위치(7천5백원~9천원), 핫플래터, 콜드플래터(각 2만8천원)',
#    'priceRange': '1~2만원대',
#    'openDate': '20190428',
#    'businessHours': '10:00~20:00  | 금, 토, 일요일 11:00~21:00 ',
#    'openEra': '',
#    'newOpenDate': '2019년 04월 28일'},
#   'timeInfo': {'mondayByOpen': '',
#    'mondayByClose': '',
#    'tuesdayByOpen': '',
#    'tuesdayByClose': '',
#    'wednesdayByOpen': '',
#    'wednesdayByClose': '',
#    'thursdayByOpen': '',
#    'thursdayByClose': '',
#    'fridayByOpen': '',
#    'fridayByClose': '',
#    'saturdayByOpen': '',
#    'saturdayByClose': '',
#    'sundayByOpen': '',
#    'sundayByClose': '',
#    'holidaysByOpen': '',
#    'holidaysByClose': '',
#    'timeEtc': ''},
#   'juso': {'detailAddress': '',
#    'roadAddrPart1': '서울특별시 성동구 성수이로14길 7',
#    'roadAddrPart2': ' (성수동2가)',
#    'jibunAddr': '서울특별시 성동구 성수동2가 322-20',
#    'engAddr': '7, Seongsui-ro 14-gil, Seongdong-gu, Seoul',
#    'zipNo': '04784',
#    'admCd': '1120011500',
#    'detBdNmList': '',
#    'bdNm': '',
#    'siNm': '서울특별시',
#    'sggNm': '성동구',
#    'emdNm': '성수동2가',
#    'liNm': '',
#    'rn': '',
#    'buldMnnm': '7',
#    'buldSlno': '0',
#    'zone2_1': '서울 강북',
#    'zone2_2': '성수동',
#    'map_1': '서울 강북지역',
#    'map_2': 'AL-2. 성수역'},
#   'gps': {'latitude': 37.54106033675408, 'longitude': 127.05641286396366},
#   'review': {'review': '스페인과 이탈리아에서 요리 경력을 쌓은 김정현 셰프가 운영하는 샤퀴테리 전문점. 독일 스타일의 소시지를 중심으로 한 육가공품을 선보인다. 다양한 맛의 소시지를 비롯해 쿡 베이컨, 미트로프 등을 다양하게 맛볼 수 있다.',
#    'readerAppraisal': None,
#    'readerReview': '',
#    'businessReview': ''},
#   'tags': '핫플맛집',
#   'etcInfo': {'interior': '',
#    'seat': '',
#    'room': '',
#    'toilet': None,
#    'toiletEtc': '',
#    'chain': False,
#    'close': False,
#    'renewal': False,
#    'appYn': False,
#    'reviewerRecommend': False,
#    'onlySiteView': False,
#    'head': None,
#    'branch': None,
#    'history': '',
#    'mainMemo': '190507_정보 부족. 추후에 다시 업데이트'},
#   'status': 'ACTIVE',
#   'bookStatus': 'APPROVAL',
#   'buzUsername': '',
#   'business': False,
#   'pageView': 232,
#   'orderDescending': 578,
#   'foodTypeDetails': None,
#   'features': None,
#   'countEvaluate': 0,
#   'bookmark': False,
#   'firstImage': {'url': '/images/es_b34bce5260a14948bca9900a21a03c1f.jpg',
#    'createdDate': 1598013651000,
#    'orderAscending': 0},
#   'foodTypes': ['유럽식', '독일식', '기타', '샤퀴테리'],
#   '_links': {'self': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/30071'},
#    'restaurant': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/30071{?projection}',
#     'templated': True},
#    'relativeWriter': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/30071/relativeWriter'},
#    'branches': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/30071/branches'},
#    'headBranch': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/30071/headBranch'},
#    'restaurantFeatures': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/30071/restaurantFeatures'},
#    'reports': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/30071/reports'},
#    'evaluates': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/30071/evaluates'},
#    'foodTypeCategories': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/30071/foodTypeCategories'},
#    'relativeBusinessOrder': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/30071/relativeBusinessOrder'}}},
#  {'createdDate': 1368543600000,
#   'id': 21019,
#   'headerInfo': {'nameKR': '프랑스포차',
#    'nameEN': '',
#    'nameCN': '',
#    'nickname': '',
#    'year': '2021',
#    'bookYear': '2021',
#    'ribbonType': 'RIBBON_ONE',
#    'ribbonTypeByOrdinal': 2},
#   'defaultInfo': {'chefName': '',
#    'website': 'https://francepocha.modoo.at/',
#    'phone': '02-3144-9191',
#    'openHours': '',
#    'closeHours': '',
#    'openHoursWeekend': '',
#    'closeHoursWeekend': '',
#    'dayOff': '명절 휴무',
#    'bcPoint': True},
#   'statusInfo': {'storeType': 'HEAD_STORE',
#    'parking': '불가',
#    'creditCard': 'y',
#    'visit': '성수역 4번 출구에서 성수동우체국 옆 골목으로 직진',
#    'menu': '슈크르트(중 2만3천원, 대 2만9천원), 코코뱅(2만7천원), 부야베스(2만9천원)',
#    'priceRange': '2~4만원대',
#    'openDate': '20120404',
#    'businessHours': '17:30~02:00(익일) | 일요일 17:30~24:00 ',
#    'openEra': '',
#    'newOpenDate': '2012년 04월 04일'},
#   'timeInfo': {'mondayByOpen': '',
#    'mondayByClose': '',
#    'tuesdayByOpen': '',
#    'tuesdayByClose': '',
#    'wednesdayByOpen': '',
#    'wednesdayByClose': '',
#    'thursdayByOpen': '',
#    'thursdayByClose': '',
#    'fridayByOpen': '',
#    'fridayByClose': '',
#    'saturdayByOpen': '',
#    'saturdayByClose': '',
#    'sundayByOpen': '',
#    'sundayByClose': '',
#    'holidaysByOpen': '',
#    'holidaysByClose': '',
#    'timeEtc': ''},
#   'juso': {'detailAddress': '',
#    'roadAddrPart1': '서울특별시 성동구 연무장5가길 20',
#    'roadAddrPart2': ' (성수동2가)',
#    'jibunAddr': '서울특별시 성동구 성수동2가 315-30',
#    'engAddr': '20, Yeonmujang 5ga-gil, Seongdong-gu, Seoul',
#    'zipNo': '04782',
#    'admCd': '1120011500',
#    'detBdNmList': '',
#    'bdNm': '',
#    'siNm': '서울특별시',
#    'sggNm': '성동구',
#    'emdNm': '성수동2가',
#    'liNm': '',
#    'rn': '양화로23길',
#    'buldMnnm': '20',
#    'buldSlno': '0',
#    'zone2_1': '서울 강북',
#    'zone2_2': '성수동',
#    'map_1': '서울 강북지역',
#    'map_2': 'AL-2. 성수역'},
#   'gps': {'latitude': 37.543337, 'longitude': 127.054768},
#   'review': {'review': '프랑스식 요리와 주류를 즐길 수 있는 주점. 소시지와 수육, 그 밑에 감자가 깔려 나오는 슈크르트가 인기메뉴다. 저렴한 가격에 프랑스 가정식을 맛볼 수 있는 곳이다.',
#    'readerAppraisal': '“맛있는 블랑 생맥주나 가성비 좋은 와인 리스트와 함께 하는 괜찮은 프랑스식 요리를 즐길 수 있다.” “가격이 저렴한 게 장점입니다.”',
#    'readerReview': '',
#    'businessReview': ''},
#   'tags': '',
#   'etcInfo': {'interior': '',
#    'seat': '',
#    'room': '',
#    'toilet': None,
#    'toiletEtc': '',
#    'chain': False,
#    'close': False,
#    'renewal': False,
#    'appYn': False,
#    'reviewerRecommend': False,
#    'onlySiteView': False,
#    'head': None,
#    'branch': None,
#    'history': '',
#    'mainMemo': '190802_가격 수정/휴무일 변경:  일요일 휴무>명절 휴무\r\n               _웹사이트 변경: http://francepocha.blog.me/30169425663 > https://francepocha.modoo.at/\r\n181004_영업시간/휴무 수정\r\n180914_매장 이전; 가격 수정 '},
#   'status': 'ACTIVE',
#   'bookStatus': 'APPROVAL',
#   'buzUsername': '',
#   'business': False,
#   'pageView': 453,
#   'orderDescending': 0,
#   'foodTypeDetails': None,
#   'features': None,
#   'countEvaluate': 0,
#   'bookmark': False,
#   'firstImage': {'url': '/images/21019_thumb.jpg',
#    'createdDate': 1601732444000,
#    'orderAscending': 0},
#   'foodTypes': ['유럽식', '프랑스식', '술집', '프렌치펍'],
#   '_links': {'self': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/21019'},
#    'restaurant': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/21019{?projection}',
#     'templated': True},
#    'relativeWriter': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/21019/relativeWriter'},
#    'branches': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/21019/branches'},
#    'headBranch': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/21019/headBranch'},
#    'restaurantFeatures': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/21019/restaurantFeatures'},
#    'reports': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/21019/reports'},
#    'evaluates': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/21019/evaluates'},
#    'foodTypeCategories': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/21019/foodTypeCategories'},
#    'relativeBusinessOrder': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/21019/relativeBusinessOrder'}}},
#  {'createdDate': 1450331088000,
#   'id': 28321,
#   'headerInfo': {'nameKR': '피어커피로스터스',
#    'nameEN': 'Peer Coffee Roasters',
#    'nameCN': '',
#    'nickname': '',
#    'year': '2021',
#    'bookYear': '2021',
#    'ribbonType': 'RIBBON_ONE',
#    'ribbonTypeByOrdinal': 2},
#   'defaultInfo': {'chefName': '',
#    'website': 'http://peercoffee.co.kr',
#    'phone': '02-474-1464',
#    'openHours': '',
#    'closeHours': '',
#    'openHoursWeekend': '',
#    'closeHoursWeekend': '',
#    'dayOff': '명절 휴무',
#    'bcPoint': False},
#   'statusInfo': {'storeType': 'NOT',
#    'parking': '불가',
#    'creditCard': '',
#    'visit': '치과의사회관앞삼거리에서 송정제방공원방향으로 직진. 센스빌오피스텔 맞은편 골목으로 좌회전. 큰사거리골목이 나오면 우회전후 직진하면 좌측.',
#    'menu': '에스프레소(5천원), 아메리카노(4천5백원), 라테, 플렛화이트(각 5천원), 바닐라라테 (5천5백원), 쏠티카라멜라테(8천원), 브루잉커피(6천원~1만원), 쇼콜라라테(6천5백원)',
#    'priceRange': '1만원 미만',
#    'openDate': '201410',
#    'businessHours': '10:00~17:00 |주말, 공휴일 12:00~20:00 ',
#    'openEra': '',
#    'newOpenDate': '2014년 10월 '},
#   'timeInfo': {'mondayByOpen': '',
#    'mondayByClose': '',
#    'tuesdayByOpen': '',
#    'tuesdayByClose': '',
#    'wednesdayByOpen': '',
#    'wednesdayByClose': '',
#    'thursdayByOpen': '',
#    'thursdayByClose': '',
#    'fridayByOpen': '',
#    'fridayByClose': '',
#    'saturdayByOpen': '',
#    'saturdayByClose': '',
#    'sundayByOpen': '',
#    'sundayByClose': '',
#    'holidaysByOpen': '',
#    'holidaysByClose': '',
#    'timeEtc': ''},
#   'juso': {'detailAddress': '',
#    'roadAddrPart1': '서울특별시 성동구 광나루로4가길 24',
#    'roadAddrPart2': ' (성수동2가)',
#    'jibunAddr': '서울특별시 성동구 성수동2가 299-39',
#    'engAddr': '24, Gwangnaru-ro 4ga-gil, Seongdong-gu, Seoul',
#    'zipNo': '04792',
#    'admCd': '1120011500',
#    'detBdNmList': '',
#    'bdNm': '',
#    'siNm': '서울특별시',
#    'sggNm': '성동구',
#    'emdNm': '성수동2가',
#    'liNm': '',
#    'rn': '이태원로54길',
#    'buldMnnm': '24',
#    'buldSlno': '0',
#    'zone2_1': '서울 강북',
#    'zone2_2': '성수동',
#    'map_1': '서울 강북지역',
#    'map_2': 'AL-2. 성수역'},
#   'gps': {'latitude': 37.5489241684925, 'longitude': 127.054880332448},
#   'review': {'review': '감각적으로 꾸민 커피 전문점으로 품질과 감성을 만족시키는 곳이다. 싱글 오리진 원두를 사용한 다양한 종류의 커피를 맛볼 수 있으며 자리에서 직접 내리는 핸드드립 커피를 추천할 만하다. 함께 곁들이면 좋은 디저트도 훌륭한 편. 맞은편에 2호점을 오픈했다.',
#    'readerAppraisal': None,
#    'readerReview': '',
#    'businessReview': ''},
#   'tags': '',
#   'etcInfo': {'interior': '',
#    'seat': '',
#    'room': '',
#    'toilet': None,
#    'toiletEtc': '',
#    'chain': False,
#    'close': False,
#    'renewal': False,
#    'appYn': False,
#    'reviewerRecommend': False,
#    'onlySiteView': False,
#    'head': None,
#    'branch': None,
#    'history': '200826_심재범 작가 추천',
#    'mainMemo': '200806_이전: 용산구 이태원로54길 58-3 > 성동구 광나루로4가길 24 / 메뉴 수정, 영업시간수정, 휴무 수정\r\n200617_성수동으로 이전'},
#   'status': 'ACTIVE',
#   'bookStatus': 'APPROVAL',
#   'buzUsername': '',
#   'business': False,
#   'pageView': 31,
#   'orderDescending': 0,
#   'foodTypeDetails': None,
#   'features': None,
#   'countEvaluate': 0,
#   'bookmark': False,
#   'firstImage': None,
#   'foodTypes': ['디저트/차/베이커리', '디저트카페', '커피전문점'],
#   '_links': {'self': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28321'},
#    'restaurant': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28321{?projection}',
#     'templated': True},
#    'relativeWriter': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28321/relativeWriter'},
#    'branches': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28321/branches'},
#    'headBranch': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28321/headBranch'},
#    'restaurantFeatures': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28321/restaurantFeatures'},
#    'reports': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28321/reports'},
#    'evaluates': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28321/evaluates'},
#    'foodTypeCategories': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28321/foodTypeCategories'},
#    'relativeBusinessOrder': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28321/relativeBusinessOrder'}}},
#  {'createdDate': 1485848468000,
#   'id': 29022,
#   'headerInfo': {'nameKR': '훔볼트',
#    'nameEN': 'Humbolt',
#    'nameCN': '',
#    'nickname': '',
#    'year': '2021',
#    'bookYear': '2021',
#    'ribbonType': 'RIBBON_ONE',
#    'ribbonTypeByOrdinal': 2},
#   'defaultInfo': {'chefName': '',
#    'website': 'https://www.instagram.com/humbolt.cafe/',
#    'phone': '02-462-9301',
#    'openHours': '',
#    'closeHours': '',
#    'openHoursWeekend': '',
#    'closeHoursWeekend': '',
#    'dayOff': '연중무휴',
#    'bcPoint': False},
#   'statusInfo': {'storeType': 'NOT',
#    'parking': '가능',
#    'creditCard': '',
#    'visit': '성수역 3번 출구에서 한강 방향으로 직진하면 좌측',
#    'menu': '수제바닐라라테(4천8백원), 아인슈페너(6천원), 카푸치노(4천3백원), 롱블랙(3천8백원), 에그타르트(3천1백원), 딸기티라미스(7천원), 청포도데니시(3천5백원)',
#    'priceRange': '1만원 미만',
#    'openDate': '201701',
#    'businessHours': '07:00~22:00 | 주말 10:00~22:00 (마지막 주문 21:30) ',
#    'openEra': '',
#    'newOpenDate': '2017년 01월 '},
#   'timeInfo': {'mondayByOpen': '',
#    'mondayByClose': '',
#    'tuesdayByOpen': '',
#    'tuesdayByClose': '',
#    'wednesdayByOpen': '',
#    'wednesdayByClose': '',
#    'thursdayByOpen': '',
#    'thursdayByClose': '',
#    'fridayByOpen': '',
#    'fridayByClose': '',
#    'saturdayByOpen': '',
#    'saturdayByClose': '',
#    'sundayByOpen': '',
#    'sundayByClose': '',
#    'holidaysByOpen': '',
#    'holidaysByClose': '',
#    'timeEtc': ''},
#   'juso': {'detailAddress': '',
#    'roadAddrPart1': '서울특별시 성동구 성수이로 58',
#    'roadAddrPart2': ' (성수동2가)',
#    'jibunAddr': '서울특별시 성동구 성수동2가 325-17 P-Tower',
#    'engAddr': '58, Seongsui-ro, Seongdong-gu, Seoul',
#    'zipNo': '04784',
#    'admCd': '1120011500',
#    'detBdNmList': '',
#    'bdNm': 'P-Tower',
#    'siNm': '서울특별시',
#    'sggNm': '성동구',
#    'emdNm': '성수동2가',
#    'liNm': '',
#    'rn': '성수이로',
#    'buldMnnm': '58',
#    'buldSlno': '0',
#    'zone2_1': '서울 강북',
#    'zone2_2': '성수동',
#    'map_1': '서울 강북지역',
#    'map_2': 'AL-2. 성수역'},
#   'gps': {'latitude': 37.540122, 'longitude': 127.055588},
#   'review': {'review': '들어서자마자 보이는 화려한 샹들리에가 인상적인 곳으로, 다양한 베이커리와 커피 메뉴를 선보인다. 수제바닐라라테와 아인슈페너, 카푸치노 등이 대표 메뉴. 테이크아웃 시에는 할인된 가격으로 음료를 맛볼 수 있다.',
#    'readerAppraisal': None,
#    'readerReview': '',
#    'businessReview': ''},
#   'tags': '',
#   'etcInfo': {'interior': '',
#    'seat': '',
#    'room': '',
#    'toilet': None,
#    'toiletEtc': '',
#    'chain': False,
#    'close': False,
#    'renewal': False,
#    'appYn': False,
#    'reviewerRecommend': False,
#    'onlySiteView': False,
#    'head': None,
#    'branch': None,
#    'history': '',
#    'mainMemo': '181002_영업시간 수정, 빵 메뉴 추가/ 전화번호 수정(02-465-5122 > 02-462-9301)'},
#   'status': 'ACTIVE',
#   'bookStatus': 'APPROVAL',
#   'buzUsername': '',
#   'business': False,
#   'pageView': 56,
#   'orderDescending': 0,
#   'foodTypeDetails': None,
#   'features': None,
#   'countEvaluate': 0,
#   'bookmark': False,
#   'firstImage': None,
#   'foodTypes': ['디저트/차/베이커리', '디저트카페'],
#   '_links': {'self': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29022'},
#    'restaurant': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29022{?projection}',
#     'templated': True},
#    'relativeWriter': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29022/relativeWriter'},
#    'branches': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29022/branches'},
#    'headBranch': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29022/headBranch'},
#    'restaurantFeatures': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29022/restaurantFeatures'},
#    'reports': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29022/reports'},
#    'evaluates': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29022/evaluates'},
#    'foodTypeCategories': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29022/foodTypeCategories'},
#    'relativeBusinessOrder': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/29022/relativeBusinessOrder'}}},
#  {'createdDate': 1587691988000,
#   'id': 30804,
#   'headerInfo': {'nameKR': '고기다',
#    'nameEN': '',
#    'nameCN': '',
#    'nickname': '',
#    'year': '0',
#    'bookYear': None,
#    'ribbonType': 'NOT',
#    'ribbonTypeByOrdinal': 3},
#   'defaultInfo': {'chefName': '',
#    'website': '',
#    'phone': '02-544-9209',
#    'openHours': '',
#    'closeHours': '',
#    'openHoursWeekend': '',
#    'closeHoursWeekend': '',
#    'dayOff': '연중무휴',
#    'bcPoint': False},
#   'statusInfo': {'storeType': 'NOT',
#    'parking': '발레 파킹 ',
#    'creditCard': 'y',
#    'visit': '성수역 1번 출구에서 직진. 태화약국에서 우회전 후 직진하다 신한은행에서 좌회전하면 좌측 ',
#    'menu': '고기다특수부위(100g 3만원), 고기다모둠(100g 3만2천원), 등심(150g 3만5천원), 안심(150g 3만7천원), 채끝 (150g 3만2천원), 살치, 안창살(각 150g 4만원), 드라이에이징등심(150g 4만원), 드라이에이징채끝(150g 3만7천원), 웻에이징삼겹살, 목살(각 200g 1만3천원)',
#    'priceRange': '4~10만원대',
#    'openDate': '2017',
#    'businessHours': '11:00~22:00',
#    'openEra': '',
#    'newOpenDate': '2017년 '},
#   'timeInfo': {'mondayByOpen': '',
#    'mondayByClose': '',
#    'tuesdayByOpen': '',
#    'tuesdayByClose': '',
#    'wednesdayByOpen': '',
#    'wednesdayByClose': '',
#    'thursdayByOpen': '',
#    'thursdayByClose': '',
#    'fridayByOpen': '',
#    'fridayByClose': '',
#    'saturdayByOpen': '',
#    'saturdayByClose': '',
#    'sundayByOpen': '',
#    'sundayByClose': '',
#    'holidaysByOpen': '',
#    'holidaysByClose': '',
#    'timeEtc': ''},
#   'juso': {'detailAddress': '',
#    'roadAddrPart1': '서울특별시 성동구 성수일로12길 20',
#    'roadAddrPart2': ' (성수동2가)',
#    'jibunAddr': '서울특별시 성동구 성수동2가 284-22 성동안심상가',
#    'engAddr': '20, Seongsuil-ro 12-gil, Seongdong-gu, Seoul',
#    'zipNo': '04793',
#    'admCd': '1120011500',
#    'detBdNmList': '',
#    'bdNm': '성동안심상가',
#    'siNm': '서울특별시',
#    'sggNm': '성동구',
#    'emdNm': '성수동2가',
#    'liNm': '',
#    'rn': '',
#    'buldMnnm': '20',
#    'buldSlno': '0',
#    'zone2_1': '서울 강북',
#    'zone2_2': '성수동',
#    'map_1': '서울 강북지역',
#    'map_2': 'AK-2. 성수역'},
#   'gps': {'latitude': 37.5481744730279, 'longitude': 127.0532504713},
#   'review': {'review': '드라이에이징, 워터에이징 방식으로 숙성한 한우를 맛볼 수 있는 곳이다. 고기는 마장동에서 공급받는다. 메뉴는 그날그날 주방장이 엄선한 좋은 부위로 내어주는 모둠이 인기다. 고기를 다 먹은 후 깍두기 볶음밥으로 마무리하면 좋다. ',
#    'readerAppraisal': '',
#    'readerReview': '',
#    'businessReview': ''},
#   'tags': '',
#   'etcInfo': {'interior': '',
#    'seat': '',
#    'room': '',
#    'toilet': None,
#    'toiletEtc': '',
#    'chain': False,
#    'close': False,
#    'renewal': False,
#    'appYn': False,
#    'reviewerRecommend': False,
#    'onlySiteView': False,
#    'head': '',
#    'branch': '',
#    'history': '200511_압구정동에서 최근에 성수동으로 이전, 대표자 바뀜',
#    'mainMemo': ''},
#   'status': 'ACTIVE',
#   'bookStatus': 'INACTIVE',
#   'buzUsername': '',
#   'business': False,
#   'pageView': 60,
#   'orderDescending': 1156,
#   'foodTypeDetails': None,
#   'features': None,
#   'countEvaluate': 0,
#   'bookmark': False,
#   'firstImage': {'url': '/images/es_e7209a6fa87045fcb3a3819a816ca8f9.jpg',
#    'createdDate': 1593664924000,
#    'orderAscending': 0},
#   'foodTypes': ['한식(육류)', '돼지고기구이', '소고기구이'],
#   '_links': {'self': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/30804'},
#    'restaurant': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/30804{?projection}',
#     'templated': True},
#    'relativeWriter': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/30804/relativeWriter'},
#    'branches': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/30804/branches'},
#    'headBranch': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/30804/headBranch'},
#    'restaurantFeatures': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/30804/restaurantFeatures'},
#    'reports': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/30804/reports'},
#    'evaluates': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/30804/evaluates'},
#    'foodTypeCategories': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/30804/foodTypeCategories'},
#    'relativeBusinessOrder': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/30804/relativeBusinessOrder'}}},
#  {'createdDate': 1518502265000,
#   'id': 29322,
#   'headerInfo': {'nameKR': '그레이스톤',
#    'nameEN': 'graystone',
#    'nameCN': '',
#    'nickname': '',
#    'year': '0',
#    'bookYear': None,
#    'ribbonType': 'NOT',
#    'ribbonTypeByOrdinal': 3},
#   'defaultInfo': {'chefName': '',
#    'website': 'https://www.instagram.com/graystone.flowercafe/',
#    'phone': '02-498-7878',
#    'openHours': '09:00',
#    'closeHours': '22:30',
#    'openHoursWeekend': '12:00',
#    'closeHoursWeekend': '22:30',
#    'dayOff': '명절 휴무',
#    'bcPoint': False},
#   'statusInfo': {'storeType': 'NOT',
#    'parking': '가능',
#    'creditCard': 'y',
#    'visit': '성수역 4번 출구에서 성수동우체국 옆 골목으로 직진. 서울숲코오롱디지털타워 2차 건물 1층',
#    'menu': '베리에이션커피(3천원~5천5백원), 오렌지라테, 아몬드라테(각 5천원), ㅏㅊ(4천5백원~5천5백원), 크루아상샌드위치(6천원)',
#    'priceRange': '1만원 미만',
#    'openDate': '2015',
#    'businessHours': '09:00~22:30 | 주말 12:00~22:30',
#    'openEra': '',
#    'newOpenDate': '2015년 '},
#   'timeInfo': {'mondayByOpen': '',
#    'mondayByClose': '',
#    'tuesdayByOpen': '',
#    'tuesdayByClose': '',
#    'wednesdayByOpen': '',
#    'wednesdayByClose': '',
#    'thursdayByOpen': '',
#    'thursdayByClose': '',
#    'fridayByOpen': '',
#    'fridayByClose': '',
#    'saturdayByOpen': '',
#    'saturdayByClose': '',
#    'sundayByOpen': '',
#    'sundayByClose': '',
#    'holidaysByOpen': '',
#    'holidaysByClose': '',
#    'timeEtc': ''},
#   'juso': {'detailAddress': '',
#    'roadAddrPart1': '서울특별시 성동구 성수이로7길 27',
#    'roadAddrPart2': ' (성수동2가)',
#    'jibunAddr': '서울특별시 성동구 성수동2가 333-140 서울숲코오롱디지탈타워',
#    'engAddr': '27, Seongsui-ro 7-gil, Seongdong-gu, Seoul',
#    'zipNo': '04780',
#    'admCd': '1120011500',
#    'detBdNmList': '',
#    'bdNm': '서울숲코오롱디지탈타워',
#    'siNm': '서울특별시',
#    'sggNm': '성동구',
#    'emdNm': '성수동2가',
#    'liNm': '',
#    'rn': '',
#    'buldMnnm': '27',
#    'buldSlno': '0',
# ...
#    'restaurant': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28187{?projection}',
#     'templated': True},
#    'relativeWriter': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28187/relativeWriter'},
#    'branches': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28187/branches'},
#    'headBranch': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28187/headBranch'},
#    'restaurantFeatures': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28187/restaurantFeatures'},
#    'reports': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28187/reports'},
#    'evaluates': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28187/evaluates'},
#    'foodTypeCategories': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28187/foodTypeCategories'},
#    'relativeBusinessOrder': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/28187/relativeBusinessOrder'}}},
#  {'createdDate': 1576552603000,
#   'id': 30556,
#   'headerInfo': {'nameKR': '전자방',
#    'nameEN': '',
#    'nameCN': ' 田子坊',
#    'nickname': '',
#    'year': '2021',
#    'bookYear': '2021',
#    'ribbonType': 'NOT',
#    'ribbonTypeByOrdinal': 3},
#   'defaultInfo': {'chefName': '계형우',
#    'website': 'http://instagram.com/junjabang.sungsu',
#    'phone': '02-420-1193',
#    'openHours': '',
#    'closeHours': '',
#    'openHoursWeekend': '',
#    'closeHoursWeekend': '',
#    'dayOff': '월요일 휴무',
#    'bcPoint': False},
#   'statusInfo': {'storeType': 'NOT',
#    'parking': '불가',
#    'creditCard': 'y',
#    'visit': '성수역 1번 출구에서 직진. 태화약국에서 우회전 후 직진하다가 롯데슈퍼에서 자회전 후 사거리 내',
#    'menu': '마라감바스&계란볶음밥(3만1천원), 고추잡채&화권(2만3천원), 블랙페퍼찹스테이크(2만3천원), 베리베리탕수육(1만9천원), 쿵파오치킨(1만9천원), 유림기(1만9천원), 곱창탕면(1만8천원)',
#    'priceRange': '1~2만원대',
#    'openDate': '20170707',
#    'businessHours': '11:00~14:00/ 17:00~22:00 | 토, 일요일 12:00~21:00 ',
#    'openEra': '',
#    'newOpenDate': '2017년 07월 07일'},
#   'timeInfo': {'mondayByOpen': '',
#    'mondayByClose': '',
#    'tuesdayByOpen': '',
#    'tuesdayByClose': '',
#    'wednesdayByOpen': '',
#    'wednesdayByClose': '',
#    'thursdayByOpen': '',
#    'thursdayByClose': '',
#    'fridayByOpen': '',
#    'fridayByClose': '',
#    'saturdayByOpen': '',
#    'saturdayByClose': '',
#    'sundayByOpen': '',
#    'sundayByClose': '',
#    'holidaysByOpen': '',
#    'holidaysByClose': '',
#    'timeEtc': ''},
#   'juso': {'detailAddress': '',
#    'roadAddrPart1': '서울특별시 성동구 성수일로12길 23',
#    'roadAddrPart2': ' (성수동2가)',
#    'jibunAddr': '서울특별시 성동구 성수동2가 299-157',
#    'engAddr': '23, Seongsuil-ro 12-gil, Seongdong-gu, Seoul',
#    'zipNo': '04792',
#    'admCd': '1120011500',
#    'detBdNmList': '',
#    'bdNm': '',
#    'siNm': '서울특별시',
#    'sggNm': '성동구',
#    'emdNm': '성수동2가',
#    'liNm': '',
#    'rn': '',
#    'buldMnnm': '23',
#    'buldSlno': '0',
#    'zone2_1': '서울 강북',
#    'zone2_2': '성수동',
#    'map_1': '서울 강북지역',
#    'map_2': 'AL-2. 성수역'},
#   'gps': {'latitude': 37.54830923383195, 'longitude': 127.05371147824512},
#   'review': {'review': '다양한 중식을 즐길 수 있는 뉴차이니즈 중식당. 베리베리탕수육과 마라감바스 & 계란볶음밥이 대표 메뉴다. 기본으로 제공되는 자차이가 맛깔스럽다. 칼칼하고 진한 맛을 자랑하는 곱창탕면도 선보인다.',
#    'readerAppraisal': None,
#    'readerReview': '',
#    'businessReview': ''},
#   'tags': '',
#   'etcInfo': {'interior': '',
#    'seat': '',
#    'room': '',
#    'toilet': None,
#    'toiletEtc': '',
#    'chain': False,
#    'close': False,
#    'renewal': False,
#    'appYn': False,
#    'reviewerRecommend': False,
#    'onlySiteView': False,
#    'head': None,
#    'branch': None,
#    'history': '',
#    'mainMemo': ''},
#   'status': 'ACTIVE',
#   'bookStatus': 'APPROVAL',
#   'buzUsername': '',
#   'business': True,
#   'pageView': 190,
#   'orderDescending': 951,
#   'foodTypeDetails': None,
#   'features': None,
#   'countEvaluate': 0,
#   'bookmark': False,
#   'firstImage': {'url': '/images/es_a8253fdb80cb406cbd7d84a8211f21c5.jpg',
#    'createdDate': 1577774361000,
#    'orderAscending': 0},
#   'foodTypes': ['중식', '일반중식'],
#   '_links': {'self': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/30556'},
#    'restaurant': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/30556{?projection}',
#     'templated': True},
#    'relativeWriter': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/30556/relativeWriter'},
#    'branches': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/30556/branches'},
#    'headBranch': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/30556/headBranch'},
#    'restaurantFeatures': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/30556/restaurantFeatures'},
#    'reports': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/30556/reports'},
#    'evaluates': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/30556/evaluates'},
#    'foodTypeCategories': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/30556/foodTypeCategories'},
#    'relativeBusinessOrder': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/30556/relativeBusinessOrder'}}},
#  {'createdDate': 1338643345000,
#   'id': 7168,
#   'headerInfo': {'nameKR': '콩빠두',
#    'nameEN': '',
#    'nameCN': '',
#    'nickname': '',
#    'year': '2016',
#    'bookYear': None,
#    'ribbonType': 'NOT',
#    'ribbonTypeByOrdinal': 3},
#   'defaultInfo': {'chefName': '',
#    'website': 'https://kongppadu.modoo.at/',
#    'phone': '02-2282-1464',
#    'openHours': '1100',
#    'closeHours': '2100',
#    'openHoursWeekend': None,
#    'closeHoursWeekend': None,
#    'dayOff': '일요일 휴무',
#    'bcPoint': False},
#   'statusInfo': {'storeType': 'HEAD_STORE',
#    'parking': '가능',
#    'creditCard': 'y',
#    'visit': '옥수역 6번 출구로 나와 골목으로 직진하면 우측',
#    'menu': '콩빠두(8천원), 콩죽(6천원), 하얀순두부, 얼큰순두부(각 7천원), 콩국수(8천원), 정식(1만원~1만3천원), 제육볶음&두부김치(1만4천원), 두부스테이크(1만원)',
#    'priceRange': '1만원 미만',
#    'openDate': '201003',
#    'businessHours': '11:00~21:00',
#    'openEra': None,
#    'newOpenDate': '2010년 03월 '},
#   'timeInfo': None,
#   'juso': {'detailAddress': None,
#    'roadAddrPart1': '서울특별시 성동구 한림말1길 8',
#    'roadAddrPart2': ' (옥수동)',
#    'jibunAddr': '서울특별시 성동구 옥수동 365-15',
#    'engAddr': '8, Hallimmal 1-gil, Seongdong-gu, Seoul',
#    'zipNo': '04735',
#    'admCd': '1120011300',
#    'detBdNmList': '',
#    'bdNm': '',
#    'siNm': '서울특별시',
#    'sggNm': '성동구',
#    'emdNm': '옥수동',
#    'liNm': '',
#    'rn': '한림말1길',
#    'buldMnnm': '8',
#    'buldSlno': '0',
#    'zone2_1': '서울 강북',
#    'zone2_2': '한남동/옥수동/금호동',
#    'map_1': '서울 강북지역',
#    'map_2': 'AK-2. 성수역'},
#   'gps': {'latitude': 37.54196, 'longitude': 127.0165},
#   'review': {'review': '신선한 콩을 갈아서 만든 콩물, 순두부 등을 맛볼 수 있다. 매일 아침 직접 두부를 만드는 것이 특징. 정식을 시키면 콩물부터 콩국수, 두부샐러드, 두부제육볶음 등 다양한 두부요리를 즐길 수 있다.',
#    'readerAppraisal': '“직접 만든 콩국물과 순두부라 담백하니 맛있어요~”',
#    'readerReview': None,
#    'businessReview': None},
#   'tags': '',
#   'etcInfo': {'interior': None,
#    'seat': None,
#    'room': None,
#    'toilet': None,
#    'toiletEtc': None,
#    'chain': False,
#    'close': False,
#    'renewal': False,
#    'appYn': False,
#    'reviewerRecommend': False,
#    'onlySiteView': False,
#    'head': None,
#    'branch': '김해장유점(055-325-0821), 창원상남점(055-239-2880), 부산명지점(051-207-0821), 김해진영점(055-342-3363)',
#    'history': None,
#    'mainMemo': ''},
#   'status': 'ACTIVE',
#   'bookStatus': 'INACTIVE',
#   'buzUsername': None,
#   'business': False,
#   'pageView': 72,
#   'orderDescending': 0,
#   'foodTypeDetails': None,
#   'features': None,
#   'countEvaluate': 0,
#   'bookmark': False,
#   'firstImage': None,
#   'foodTypes': ['한식(일반한식)', '두부'],
#   '_links': {'self': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/7168'},
#    'restaurant': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/7168{?projection}',
#     'templated': True},
#    'relativeWriter': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/7168/relativeWriter'},
#    'branches': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/7168/branches'},
#    'headBranch': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/7168/headBranch'},
#    'restaurantFeatures': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/7168/restaurantFeatures'},
#    'reports': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/7168/reports'},
#    'evaluates': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/7168/evaluates'},
#    'foodTypeCategories': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/7168/foodTypeCategories'},
#    'relativeBusinessOrder': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/7168/relativeBusinessOrder'}}},
#  {'createdDate': 1598761262000,
#   'id': 31225,
#   'headerInfo': {'nameKR': '마리오네',
#    'nameEN': 'MARIONE',
#    'nameCN': '',
#    'nickname': '',
#    'year': '9999',
#    'bookYear': None,
#    'ribbonType': 'NEW',
#    'ribbonTypeByOrdinal': 5},
#   'defaultInfo': {'chefName': '김주영',
#    'website': 'https://www.instagram.com/marione_ss/',
#    'phone': '02-466-6777',
#    'openHours': '',
#    'closeHours': '',
#    'openHoursWeekend': '',
#    'closeHoursWeekend': '',
#    'dayOff': '월요일 휴무',
#    'bcPoint': False},
#   'statusInfo': {'storeType': 'NOT',
#    'parking': '가능',
#    'creditCard': 'y',
#    'visit': '성수역 3번 출구에서 성수동카페거리로 직진후 쇼콜라티에 코리아 골목 진입하면 좌측',
#    'menu': '피자(1만1천원~2만2천원), 파스타(1만7천원~2만4천원), 안티파스토(6천원~2만2천원), 음료(2천5백원~4천원), 리퀴어(1만1천원), 맥주(7천5백원~1만원), 와인(글래스 8천원, 보틀39만원~65만원)',
#    'priceRange': '1만원 미만',
#    'openDate': '20200530',
#    'businessHours': '11:30~15:00(마지막 주문14:00)/17:00~21:00(마지막 주문20:00) | 주말12:00~15:30/17:00~22:00',
#    'openEra': '',
#    'newOpenDate': '2020년 05월 30일'},
#   'timeInfo': {'mondayByOpen': '',
#    'mondayByClose': '',
#    'tuesdayByOpen': '',
#    'tuesdayByClose': '',
#    'wednesdayByOpen': '',
#    'wednesdayByClose': '',
#    'thursdayByOpen': '',
#    'thursdayByClose': '',
#    'fridayByOpen': '',
#    'fridayByClose': '',
#    'saturdayByOpen': '',
#    'saturdayByClose': '',
#    'sundayByOpen': '',
#    'sundayByClose': '',
#    'holidaysByOpen': '',
#    'holidaysByClose': '',
#    'timeEtc': ''},
#   'juso': {'detailAddress': '1층',
#    'roadAddrPart1': '서울특별시 성동구 성수이로12길 15',
#    'roadAddrPart2': ' (성수동2가)',
#    'jibunAddr': '서울특별시 성동구 성수동2가 269-107',
#    'engAddr': '15, Seongsui-ro 12-gil, Seongdong-gu, Seoul',
#    'zipNo': '04784',
#    'admCd': '1120011500',
#    'detBdNmList': '',
#    'bdNm': '',
#    'siNm': '서울특별시',
#    'sggNm': '성동구',
#    'emdNm': '성수동2가',
#    'liNm': '',
#    'rn': '',
#    'buldMnnm': '15',
#    'buldSlno': '0',
#    'zone2_1': '서울 강북',
#    'zone2_2': '성수동',
#    'map_1': '서울 강북지역',
#    'map_2': 'AL-2. 성수역'},
#   'gps': {'latitude': 37.5397433768049, 'longitude': 127.056910522064},
#   'review': {'review': '이탈리아 남부 나폴리 피자와 파스타 와인, 맥주를 즐겁게 편하게 즐길 수 있는 공간. 국내외 나폴리피자장인 대회를 휩쓴 셰프가 운영하고 있다. 주방에는 세계 최고 등급의 피자화덕 스테파노페라라가 설치되어 있다. ',
#    'readerAppraisal': '',
#    'readerReview': '',
#    'businessReview': '2020년 나폴리 피자 세계 챔피언 핏자이올로가 운영하는 피제리아. 나폴리와 나고야에서 피자를 배워 다양한 피자를 맛볼수있는 피제리아\r\n피자뿐만 아니라 나폴리에서 맛볼수있는 봉골레,라구나폴레타나 등 나폴리지방 음식들도 선보인다. '},
#   'tags': '피맥',
#   'etcInfo': {'interior': '',
#    'seat': '',
#    'room': '',
#    'toilet': None,
#    'toiletEtc': '',
#    'chain': False,
#    'close': False,
#    'renewal': False,
#    'appYn': False,
#    'reviewerRecommend': False,
#    'onlySiteView': False,
#    'head': '',
#    'branch': '',
#    'history': '',
#    'mainMemo': ''},
#   'status': 'ACTIVE',
#   'bookStatus': 'COVER',
#   'buzUsername': '',
#   'business': True,
#   'pageView': 62,
#   'orderDescending': 0,
#   'foodTypeDetails': None,
#   'features': None,
#   'countEvaluate': 0,
#   'bookmark': False,
#   'firstImage': {'url': '/images/bluer_05f32bca2f634756beb30711e481aa67.jpg',
#    'createdDate': 1605311780000,
#    'orderAscending': 0},
#   'foodTypes': ['이탈리아식', '파스타', '피자', '술집', '펍'],
#   '_links': {'self': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/31225'},
#    'restaurant': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/31225{?projection}',
#     'templated': True},
#    'relativeWriter': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/31225/relativeWriter'},
#    'branches': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/31225/branches'},
#    'headBranch': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/31225/headBranch'},
#    'restaurantFeatures': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/31225/restaurantFeatures'},
#    'reports': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/31225/reports'},
#    'evaluates': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/31225/evaluates'},
#    'foodTypeCategories': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/31225/foodTypeCategories'},
#    'relativeBusinessOrder': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/31225/relativeBusinessOrder'}}},
#  {'createdDate': 1584259914000,
#   'id': 30739,
#   'headerInfo': {'nameKR': '중앙감속기',
#    'nameEN': '',
#    'nameCN': '',
#    'nickname': '',
#    'year': '2021',
#    'bookYear': '2021',
#    'ribbonType': 'NEW',
#    'ribbonTypeByOrdinal': 5},
#   'defaultInfo': {'chefName': '최현석',
#    'website': '',
#    'phone': '02-466-9628',
#    'openHours': '',
#    'closeHours': '',
#    'openHoursWeekend': '',
#    'closeHoursWeekend': '',
#    'dayOff': '월요일 휴무',
#    'bcPoint': False},
#   'statusInfo': {'storeType': 'NOT',
#    'parking': '불가',
#    'creditCard': 'y',
#    'visit': '뚝섬역 5번 출구 앞 스타벅스에서 우회전 후 세븐일레븐에서 좌회전 후 직진하면 좌측',
#    'menu': '유로피안동파육(2만5천원), 해산물바질짬뽕(각 1만7천원), 마라크림새우리조토(2만6천원), 볼로냐두부, 발사믹궈바로우(각 1만8천원), 차돌마라크림짬뽕(1만9천원), 새우바질춘권(1만2천원)',
#    'priceRange': '2~4만원대',
#    'openDate': '201912',
#    'businessHours': '12:00~15:00(마지막 주문 14:30)/17:30~21:00(마지막 주문 20:30) ',
#    'openEra': '',
#    'newOpenDate': '2019년 12월 '},
#   'timeInfo': {'mondayByOpen': '',
#    'mondayByClose': '',
#    'tuesdayByOpen': '',
#    'tuesdayByClose': '',
#    'wednesdayByOpen': '',
#    'wednesdayByClose': '',
#    'thursdayByOpen': '',
#    'thursdayByClose': '',
#    'fridayByOpen': '',
#    'fridayByClose': '',
#    'saturdayByOpen': '',
#    'saturdayByClose': '',
#    'sundayByOpen': '',
#    'sundayByClose': '',
#    'holidaysByOpen': '',
#    'holidaysByClose': '',
#    'timeEtc': ''},
#   'juso': {'detailAddress': '',
#    'roadAddrPart1': '서울특별시 성동구 성수일로6길 7-1',
#    'roadAddrPart2': ' (성수동2가)',
#    'jibunAddr': '서울특별시 성동구 성수동2가 301-98',
#    'engAddr': '7-1, Seongsuil-ro 6-gil, Seongdong-gu, Seoul',
#    'zipNo': '04782',
#    'admCd': '1120011500',
#    'detBdNmList': '',
#    'bdNm': '',
#    'siNm': '서울특별시',
#    'sggNm': '성동구',
#    'emdNm': '성수동2가',
#    'liNm': '',
#    'rn': '',
#    'buldMnnm': '7',
#    'buldSlno': '1',
#    'zone2_1': '서울 강북',
#    'zone2_2': '성수동',
#    'map_1': '서울 강북지역',
#    'map_2': 'AL-2. 성수역'},
#   'gps': {'latitude': 37.5455735247076, 'longitude': 127.051086163784},
#   'review': {'review': '최현셕 셰프가 운영하는 캐주얼한 퓨전 레스토랑으로, 중식과 이탈리안을 접목한 독특한 요리를 만나볼 수 있다. 발사믹궈바로우와 바질새우춘권이 인기메뉴다. 레스토랑 이름은 원래 있었던 공장 이름을 이어받았다.',
#    'readerAppraisal': '“새로운 장소, 새로운 시도, 새로운 경험.”',
#    'readerReview': '',
#    'businessReview': ''},
#   'tags': '',
#   'etcInfo': {'interior': '',
#    'seat': '',
#    'room': '',
#    'toilet': None,
#    'toiletEtc': '',
#    'chain': False,
#    'close': False,
#    'renewal': False,
#    'appYn': False,
#    'reviewerRecommend': False,
#    'onlySiteView': False,
#    'head': '',
#    'branch': '',
#    'history': '',
#    'mainMemo': ''},
#   'status': 'ACTIVE',
#   'bookStatus': 'APPROVAL',
#   'buzUsername': '',
#   'business': False,
#   'pageView': 293,
#   'orderDescending': 1105,
#   'foodTypeDetails': None,
#   'features': None,
#   'countEvaluate': 0,
#   'bookmark': False,
#   'firstImage': {'url': '/images/es_6ab5d8f5763e4c04be66320dd363694b.jpg',
#    'createdDate': 1605081888000,
#    'orderAscending': 0},
#   'foodTypes': ['중식', '퓨전중식'],
#   '_links': {'self': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/30739'},
#    'restaurant': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/30739{?projection}',
#     'templated': True},
#    'relativeWriter': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/30739/relativeWriter'},
#    'branches': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/30739/branches'},
#    'headBranch': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/30739/headBranch'},
#    'restaurantFeatures': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/30739/restaurantFeatures'},
#    'reports': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/30739/reports'},
#    'evaluates': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/30739/evaluates'},
#    'foodTypeCategories': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/30739/foodTypeCategories'},
#    'relativeBusinessOrder': {'href': 'https://www.bluer.co.kr/api/v1/restaurants/30739/relativeBusinessOrder'}}}]

# %%
len(response.json()['_embedded']['restaurants'])
# Out:
# 28

# %% [markdown]
# #### info

# %%
response.json()['_embedded']['restaurants'][25]['headerInfo']
# Out:
# {'nameKR': '콩빠두',
#  'nameEN': '',
#  'nameCN': '',
#  'nickname': '',
#  'year': '2016',
#  'bookYear': None,
#  'ribbonType': 'NOT',
#  'ribbonTypeByOrdinal': 3}

# %%
response.json()['_embedded']['restaurants'][25]['statusInfo']
# Out:
# {'storeType': 'HEAD_STORE',
#  'parking': '가능',
#  'creditCard': 'y',
#  'visit': '옥수역 6번 출구로 나와 골목으로 직진하면 우측',
#  'menu': '콩빠두(8천원), 콩죽(6천원), 하얀순두부, 얼큰순두부(각 7천원), 콩국수(8천원), 정식(1만원~1만3천원), 제육볶음&두부김치(1만4천원), 두부스테이크(1만원)',
#  'priceRange': '1만원 미만',
#  'openDate': '201003',
#  'businessHours': '11:00~21:00',
#  'openEra': None,
#  'newOpenDate': '2010년 03월 '}

# %% [markdown]
# #### station ls

# %%
query_ls = pd.read_excel('./data/seoul_subway_station_v2.xlsx')
query_ls = query_ls['전철역명']

# %%
chunk = pd.DataFrame(response.json()['_embedded']['restaurants'])
len(chunk['headerInfo'])
# Out:
# 28

# %%
response.json()['_embedded']['restaurants'][25]['statusInfo']['menu']
# Out:
# '콩빠두(8천원), 콩죽(6천원), 하얀순두부, 얼큰순두부(각 7천원), 콩국수(8천원), 정식(1만원~1만3천원), 제육볶음&두부김치(1만4천원), 두부스테이크(1만원)'

# %%
response.json()['_embedded']['restaurants'][25]['defaultInfo']['phone']
# Out:
# '02-2282-1464'

# %% [markdown]
# #### func

# %%
# %%writefile bluer.py

def bluer():
    import requests
    import pandas as pd
    import time
    query_ls = pd.read_csv('./crawling/seoul_subway_station_v2.csv')
    query_ls = query_ls['전철역명']
    
    start = time.time()
    
    datas = []
    
    for query in query_ls:
        url = f'https://www.bluer.co.kr/api/v1/restaurants?page=0&size=30&query={query}'
        response = requests.get(url)
        chunk = response.json()['_embedded']['restaurants']
        
        for i in range(len(chunk)):
            data = {
                'station':query,
                'id':chunk[i]['id'],
                'name':chunk[i]['headerInfo']['nameKR'],
                'category':chunk[i]['foodTypes'],
                'menu':chunk[i]['statusInfo']['menu'],
                'tel':chunk[i]['defaultInfo']['phone'],
                # 'addr':chunk[i]['juso']['jibunAddr'],
                'addr':chunk[i]['juso']['roadAddrPart1'],
                'lat':chunk[i]['gps']['latitude'],
                'lng':chunk[i]['gps']['longitude'],
                'ribbonType':chunk[i]['headerInfo']['ribbonType'],
                'menu':chunk[i]['statusInfo']['menu'],
                'priceRange':chunk[i]['statusInfo']['priceRange']
            }
            
            datas.append(data)
            
    df = pd.DataFrame(datas)
    df.to_csv('./bluer.csv')
    print(time.time() - start, 'sec')
    return df

bluer = bluer()
# Out:
# Overwriting bluer.py

# %%
import requests
import json
import datetime

url = f'https://www.bluer.co.kr/api/v1/restaurants?page=0&size=30&query=성수역'
response = requests.get(url)
chunk = response.json()['_embedded']['restaurants']

# %%
'https://www.bluer.co.kr' + chunk[0]['firstImage']['url']
# Out:
# 'https://www.bluer.co.kr/images/es_5aebde5e547643709f43c31c344d70f9.jpg'

# %%
# %%writefile bluer.py
#!/usr/bin/env python

import requests
import json
import datetime

def send_msg(msg, WEBHOOK_URL="https://hooks.slack.com/services/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"):
    payload = {
        "channel": "#dss_prjt_crawling",
        "username": "dss_prjt_crawling",
        "text": msg,
    }
    requests.post(WEBHOOK_URL, data=json.dumps(payload))
    
    

def bluer():
    now = datetime.datetime.now()
    send_msg("{}크롤링 시작".format(now.strftime('%Y-%m-%d_%H-%M')))

    import requests
    import pandas as pd
    import time
    query_ls = pd.read_csv('./data/seoul_subway_station.csv')
    query_ls = query_ls['전철역명']
        
    datas = []
    
    for query in query_ls:
        url = f'https://www.bluer.co.kr/api/v1/restaurants?page=0&size=30&query={query}'
        response = requests.get(url)
        chunk = response.json()['_embedded']['restaurants']
        
        for i in range(len(chunk)):
            data = {
                'station':query,
                # 'thumbnail':'https://www.bluer.co.kr' + chunk[i]['firstImage']['url'],
                'id':chunk[i]['id'],
                'name':chunk[i]['headerInfo']['nameKR'],
                'category':chunk[i]['foodTypes'],
                'menu':chunk[i]['statusInfo']['menu'],
                'tel':chunk[i]['defaultInfo']['phone'],
                'addr':chunk[i]['juso']['jibunAddr'],
#                 'addr':chunk[i]['juso']['roadAddrPart1'],
                'lat':chunk[i]['gps']['latitude'],
                'lng':chunk[i]['gps']['longitude'],
                'ribbonType':chunk[i]['headerInfo']['ribbonType'],
                'menu':chunk[i]['statusInfo']['menu'],
                'priceRange':chunk[i]['statusInfo']['priceRange']
            }
            
            datas.append(data)
            
    df = pd.DataFrame(datas)
    df.to_csv('./bluer.csv')
    
    msg2 = "{}/{}개의 맛집 크롤링 완료".format(now.strftime('%Y-%m-%d_%H-%M'), len(df))
    send_msg(msg2)
    return df

bluer()
# Out:
# Writing bluer.py

# %%
# coding: utf-8

# %%
import requests
import json
import datetime

def send_msg(msg, WEBHOOK_URL="https://hooks.slack.com/services/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"):
    payload = {
        "channel": "#dss_prjt_crawling",
        "username": "dss_prjt_crawling",
        "text": msg,
    }
    requests.post(WEBHOOK_URL, data=json.dumps(payload))
    
    

def bluer():
    now = datetime.datetime.now()
    send_msg("{}크롤링 시작".format(now.strftime('%Y-%m-%d_%H-%M')))

    import requests
    import pandas as pd
    import time
    query_ls = pd.read_csv('./data/seoul_subway_station_v2.csv')
    query_ls = query_ls['전철역명']
        
    datas = []
    
    for query in query_ls:
        url = f'https://www.bluer.co.kr/api/v1/restaurants?page=0&size=30&query={query}'
        response = requests.get(url)
        chunk = response.json()['_embedded']['restaurants']
        
        for i in range(len(chunk)):
            data = {
                'station':query,
                'name':chunk[i]['headerInfo']['nameKR'],
                'category':chunk[i]['foodTypes'],
                'menu':chunk[i]['statusInfo']['menu'],
                'tel':chunk[i]['defaultInfo']['phone'],
                # 'addr':chunk[i]['juso']['jibunAddr'],
                'addr':chunk[i]['juso']['roadAddrPart1'],
                'lat':chunk[i]['gps']['latitude'],
                'lng':chunk[i]['gps']['longitude'],
                'ribbonType':chunk[i]['headerInfo']['ribbonType'],
                'menu':chunk[i]['statusInfo']['menu'],
                'priceRange':chunk[i]['statusInfo']['priceRange']
            }
            
            datas.append(data)
            
    df = pd.DataFrame(datas)
    df.to_csv('./bluer.csv')
    
    msg2 = "{}/{}개의 맛집 크롤링 완료".format(now.strftime('%Y-%m-%d_%H-%M'), len(df))
    send_msg(msg2)
    return df

bluer()
