# %% [markdown]
# ### kakao rest api_1
# - 주소값으로 위도, 경도, 우편번호 가져오기
# - 카카오 번역

# %% [markdown]
# #### 1. 카카오 로컬 api
# - https://developers.kakao.com
# - 주소 > 위도,경도,우편번호
# - 문서 > 로컬 > 개발가이드 > Sample

# %%
app_key = "748cc99b687225fc43a1774cbe3755dd"
headers = { "Authorization": "KakaoAK {}".format(app_key) }
query = "성수역 맛집"
page = 1
url = "https://dapi.kakao.com/v2/local/search/keyword.json?query={}&page={}".format(query,page)
response = requests.get(url, headers=headers)
response
# Out:
# <Response [200]>

# %%
def search():
    app_key = "748cc99b687225fc43a1774cbe3755dd"
    headers = { "Authorization": "KakaoAK {}".format(app_key) }
    query = "성수역 맛집"
    page = list(range(15+1))
    url = "https://dapi.kakao.com/v2/local/search/keyword.json?query={}&page={}".format(query,page)
    response = requests.get(url, headers=headers)

# %%
app_key = "748cc99b687225fc43a1774cbe3755dd"
headers = { "Authorization": "KakaoAK {}".format(app_key) }
query = "성수역 맛집"
pages = range(45)
url = "https://dapi.kakao.com/v2/local/search/keyword.json?query={}&pages={}".format(query,pages)
data = []
for page in pages:
    response = requests.get(url, headers=headers)
    data.append(response.json()["documents"])

# %%
# page 45, size 15 -> total 675
data
# Out:
# [[{'address_name': '서울 성동구 성수동2가 309-133',
#    'category_group_code': 'CE7',
#    'category_group_name': '카페',
#    'category_name': '음식점 > 카페 > 테마카페 > 디저트카페',
#    'distance': '',
#    'id': '1301973155',
#    'phone': '010-3934-2301',
#    'place_name': '할아버지공장',
#    'place_url': 'http://place.map.kakao.com/1301973155',
#    'road_address_name': '서울 성동구 성수이로7가길 9',
#    'x': '127.054835558322',
#    'y': '37.5410980207173'},
#   {'address_name': '서울 성동구 성수동2가 277-135',
#    'category_group_code': 'CE7',
#    'category_group_name': '카페',
#    'category_name': '음식점 > 카페 > 테마카페 > 디저트카페',
#    'distance': '',
#    'id': '145791269',
#    'phone': '',
#    'place_name': '어니언',
#    'place_url': 'http://place.map.kakao.com/145791269',
#    'road_address_name': '서울 성동구 아차산로9길 8',
#    'x': '127.05821260799398',
#    'y': '37.54478599695387'},
#   {'address_name': '서울 성동구 성수동2가 315-100',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
# ...

# %%
data[0][0]['id'], data[0][0]['place_name']
# Out:
# ('1301973155', '할아버지공장')

# %%
id = 1301973155
url2 = 'https://place.map.kakao.com/{}'.format(id)
response2 = requests.get(url2, headers=headers)
response2.json()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-16-9ace76321bee> in <module>
#       2 url2 = 'https://place.map.kakao.com/{}'.format(id)
#       3 response2 = requests.get(url2, headers=headers)
# ----> 4 response2.json()
#
# ~\anaconda3\lib\site-packages\requests\models.py in json(self, **kwargs)
#     898                     # used.
#     899                     pass
# --> 900         return complexjson.loads(self.text, **kwargs)
#     901
#     902     @property
#
# ~\anaconda3\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
# ...

# %%
# from bs4 import BeautifulSoup
# link = f'https://place.map.kakao.com/20304491'
# response = requests.get(link, headers=headers)
# dom = BeautifulSoup(response.text, 'html.parser')
# selector = '#mArticle > div.cont_evaluation > div.ahead_info > div > em'
# element = dom.select_one(selector)
# element

# %%
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-123-9370c36a363e> in <module>
# ----> 1 response2.json()
#
# ~\anaconda3\lib\site-packages\requests\models.py in json(self, **kwargs)
#     898                     # used.
#     899                     pass
# --> 900         return complexjson.loads(self.text, **kwargs)
#     901
#     902     @property
#
# ~\anaconda3\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# ~\anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# ...

# %%
response = requests.get(url, headers=headers)
response
# Out:
# <Response [200]>

# %%
data = response.json()["documents"][0]

# %%
lat, lon, zip_code = data["x"], data["y"], data["road_address"]["zone_no"]
lat, lon, zip_code
# Out:
# ('127.057127702049', '37.5451422412538', '04794')

# %% [markdown]
# #### 2. 카카오 번역 API
# - 문서 -> 번역API가이드 -> 개발가이드 -> Sample

# %%
app_key = "748cc99b687225fc43a1774cbe3755dd"

# %%
headers = {"Authorization": "KakaoAK {}".format(app_key)}

# %%
params = {
    "query": ["패스트 캠퍼스", "데이터 사이언스는 재미있습니다."],
    "src_lang": "kr",
    "target_lang": "en",
}

# %%
url = "https://kapi.kakao.com/v1/translation/translate?query={}&src_lang={}&target_lang={}".format(
    params["query"], params["src_lang"], params["target_lang"]
)
url
# Out:
# "https://kapi.kakao.com/v1/translation/translate?query=['패스트 캠퍼스', '데이터 사이언스는 재미있습니다.']&src_lang=kr&target_lang=en"

# %%
response = requests.get(url, 'Cookie': 'webid=b329e0b00ca711ebbca2000af759d7a0; webid_ts=1602519996988; __T_=1; _kadu=Oja8xf4V67uG7flP_1605451601870; kd_lang=ko; _ga=GA1.2.406740629.1605676677; _csrf=WD-q7ACq6a5PSL1PfOGm5Y5-; _kdt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJkZXZlbG9wZXJJZCI6MzU2NjE4LCJhY2NvdW50SWQiOjU2MTYyNTMwLCJlbWFpbCI6Impvb245MEBnbWFpbC5jb20iLCJ0b2tlbiI6ImYxZjkwYzdhOTU3MjMyYmFkZDAxNzUxNTA3ZDlkY2ZjNzE2NDljZTFkZDJhZjBlMGQ0NWI3MWIxNjQ2Y2I4OWYifQ.DKLIqTDCdcxZVBCeSJerBxjeDp1j6aoboG8FUr3ZE1k; TIARA=5KmsVJHQnxEMaVOr8fuI7tptV89yX6wRRgy31Zcb5aTJwxFtgyfjDw3xVap9VFGqga.dfoVe6MUEYy5gpIxfug00; _gid=GA1.2.1324815935.1606182892; _kawlt=lHe-mDTvBe5p82gHNlmDzBgq7mBQAONK_cCvxiF0yQ7ae9z6KokyN0f7Hbcg41lOYIr-9oQawv0TyqsyOeaMY4_w3n_B8_JT2MR6Bv3CMTECmdVJCQKt_Il2dDpvAoQo; _kawltea=1606258499; _karmt=S_KvEVp6FSo6FW08w5w1WSonAZhxn4qaq2oCl3BnnBECCaGRTGB01Pxvi46zBnf4; _karmtea=1606269299; JSESSIONID=F3FF030FCC96732C044CAED002FE59FE; __T_=1; _T_ANO='}
)
response
# Out:
# <Response [200]>

# %%
response.json()["translated_text"]
# Out:
# [["['Fast Campus', 'Data Science is fun.']"]]
