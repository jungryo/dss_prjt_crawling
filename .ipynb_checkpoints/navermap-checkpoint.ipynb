# %%
from scrapy.http import TextResponse

# %%
# 역이름
station = "여의도역"
url = "https://map.naver.com/v5/api/search?caller=pcweb&query={} 맛집&type=all&searchCoord=126.71639442443849;37.508432213060516&page=1&displayCount=20&isPlaceRecommendationReplace=true&lang=ko".format(station)
print(url)
response = requests.get(url)
response.json()
# Out:
# https://map.naver.com/v5/api/search?caller=pcweb&query=여의도역 맛집&type=all&searchCoord=126.71639442443849;37.508432213060516&page=1&displayCount=20&isPlaceRecommendationReplace=true&lang=ko
# {'result': {'type': 'place',
#   'metaInfo': {'pageId': '54f55ffa-fbc2-482f-85d2-0aac859d8ab1',
#    'sessionId': None,
#    'rcode': '11237592',
#    'searchedQuery': '여의도역 맛집',
#    'correction': None,
#    'displayCorrectAnswer': False},
#   'address': None,
#   'place': {'page': 1,
#    'totalCount': 2965,
#    'boundary': ['126.9198605', '37.5255747', '126.9294212', '37.5204236'],
#    'feedback': ["<strong>'여의도역 5호선'</strong>", "근처 <strong>'맛집'</strong>"],
#    'options': {'sort': '0', 'toggleLocation': '0', 'rank': '1'},
#    'filters': {'restaurant': {'category': 'all',
#      'selectedCategoryCodeList': ['all'],
#      'selectedThemeCodeList': ['all'],
#      'selectedAgeCodeList': ['all'],
#      'categoryList': [{'code': 'all', 'name': '전체'},
#       {'code': 'korean', 'name': '한식'},
#       {'code': 'japanese', 'name': '일식'},
#       {'code': 'chinese', 'name': '중식'},
#       {'code': 'asian', 'name': '아시아 음식'},
#       {'code': 'buffet', 'name': '뷔페'},
#       {'code': 'koreanSnack', 'name': '분식'},
#       {'code': 'cafe', 'name': '카페'},
#       {'code': 'theOthers', 'name': '기타'}],
#      'themeList': [{'code': 'all', 'name': '전체'},
#       {'code': 'calm', 'name': '조용한 분위기'},
#       {'code': 'casual', 'name': '젊고 캐쥬얼한'},
#       {'code': 'children', 'name': '아이와 함께'},
#       {'code': 'community', 'name': '모임하기 좋은'},
#       {'code': 'special', 'name': '특별한 날'}],
#      'ageList': [{'code': 'all', 'name': '전체'},
#       {'code': '10', 'name': '10대'},
#       {'code': '20', 'name': '20대'},
#       {'code': '30', 'name': '30대'},
#       {'code': '40', 'name': '40대'},
#       {'code': '50', 'name': '50대'}]}},
#    'reSearch': None,
#    'isSiteSortAvailable': False,
#    'specializedSearch': 'restaurant',
#    'hasPollingPlace': False,
#    'isAdultKeyword': False,
#    'containAdultContents': False,
#    'address': None,
#    'brandPromotion': None,
#    'list': [{'index': '0',
#      'rank': '1',
#      'id': '1251024640',
#      'name': '아루히',
#      'tel': '02-780-3903',
#      'isCallLink': False,
#      'virtualTel': '',
#      'ppc': '1',
#      'category': ['일식', '일식당'],
#      'categoryPath': [['220036', '220038', '220081', '220804'],
#       ['222606', '222607', '1004452']],
#      'address': '서울특별시 영등포구 여의도동 35-5',
#      'roadAddress': '서울특별시 영등포구 여의나루로 42 2층',
#      'abbrAddress': '여의도동 35-5',
#      'shortAddress': ['서울 영등포구', '여의나루로 42', '2층'],
#      'display': '아루히',
#      'telDisplay': '02-780-3903',
#      'context': [],
#      'reviewCount': 586,
#      'ktCallMd': 'd922b24a6b816844740eedc691cc6a78',
#      'coupon': '0',
#      'thumUrl': 'https://ldb-phinf.pstatic.net/20190227_268/15512563826654E3P4_JPEG/W09GhSwxyXXkx1z0q744tJBG.jpg',
#      'type': 's',
#      'isSite': '1',
#      'posExact': '1',
#      'x': '126.9249813',
#      'y': '37.5214725',
#      'itemLevel': '8',
#      'isAdultBusiness': False,
#      'streetPanorama': {'id': '+9RWNvH6ApOfUpiTC5paOw==',
#       'pan': '40.33',
#       'tilt': '10.00',
#       'lng': '126.9247758',
#       'lat': '37.5212303',
#       'fov': '120'},
#      'skyPanorama': {'id': 'qDBSTxwmtQw17Cu92NL0aQ==',
#       'pan': '-173.80',
#       'tilt': '-30.00',
#       'lng': '126.9251251',
#       'lat': '37.5227776',
#       'fov': '124'},
#      'insidePanorama': None,
#      'interiorPanorama': None,
#      'indoorPanorama': None,
#      'theme': None,
#      'poiInfo': {'relation': None,
#       'hasRelation': False,
#       'road': {'poiShapeType': '1',
#        'shapeKey': None,
#        'boundary': None,
#        'detail': None},
#       'hasRoad': False,
#       'land': None,
#       'hasLand': False,
#       'polygon': None,
#       'hasPolygon': False},
#      'homePage': 'http://www.instagram.com/aruhi_specialday',
#      'description': '',
#      'entranceCoords': {'car': [{'rep': True, 'x': 126.925, 'y': 37.521884},
#        {'rep': False, 'x': 126.9251363, 'y': 37.5210919}],
#       'walk': [{'rep': True, 'x': 126.9248586, 'y': 37.5218122},
#        {'rep': False, 'x': 126.9249882, 'y': 37.5212405}]},
#      'isPollingPlace': False,
#      'bizhourInfo': '매일 11:30~21:30 (월~일/ Break Time 15:00~17:30)',
#      'menuInfo': '오마카세 런치 33,000 | 오마카세 디너 35,000',
#      'petrolInfo': None,
#      'couponUrl': None,
#      'couponUrlMobile': None,
#      'hasCardBenefit': False,
#      'menuExist': '1',
#      'hasNaverBooking': False,
#      'naverBookingUrl': 'https://booking.naver.com/booking/6/bizes/223362',
#      'naverEasyOrderUrl': None,
#      'hasNaverSmartOrder': False,
#      'reservationLabel': {'standard': False,
#       'preOrder': False,
#       'table': False,
#       'takeout': False},
#      'reservation': {'benefit': ''},
#      'hasBroadcastInfo': False,
#      'broadcastInfo': None,
#      'shopWindowInfo': None,
#      'hasNPay': False,
#      'carWash': '',
#      'parkingPrice': '-1',
#      'card': '',
#      'distance': '18470.18',
#      'marker': 'nres://marker/00064-00122',
#      'markerSelected': 'nres://marker/00064-00276',
#      'microReview': ['수강신청보다 힘들다는 여의도 스시',
#       '여의도 스시 오마카세 가성비 훌륭한 스시',
#       '가성비 내리는 여의도 스시',
#       '가성비 좋기로 유명한 스시집',
#       '스시 오마카세 또 없을 것 같은 곳'],
#      'michelinGuide': None,
#      'indoor': None,
#      'markerLabel': None,
#      'subway': None,
#      'evChargerInfo': {'summary': {'quickEvCharger': {'chargingSpeed': '급속',
#         'availability': '',
#         'names': ''},
#        'slowEvCharger': {'chargingSpeed': '완속',
#         'availability': '',
#         'names': ''}},
#       'evChargerList': []}},
#     {'index': '1',
#      'rank': '2',
#      'id': '1483440401',
#      'name': '후라토식당 여의도직영점',
#      'tel': '02-780-7090',
#      'isCallLink': False,
#      'virtualTel': '0507-1331-2710',
#      'ppc': '1',
#      'category': ['일식', '일식당'],
#      'categoryPath': [['220036', '220038', '220081', '220804'],
#       ['222606', '222607', '1004380', '1002043']],
#      'address': '서울특별시 영등포구 여의도동 23-8',
#      'roadAddress': '서울특별시 영등포구 국제금융로2길 32 3층 후라토식당',
#      'abbrAddress': '여의도동 23-8',
#      'shortAddress': ['서울 영등포구', '국제금융로2길 32', '3층 후라토식당'],
#      'display': '후라토<b>식당</b> 여의도직영점',
#      'telDisplay': '02-780-7090',
#      'context': [],
#      'reviewCount': 71,
#      'ktCallMd': '2b13b866933565a885bc378ce4263731',
#      'coupon': '0',
#      'thumUrl': 'https://ldb-phinf.pstatic.net/20200827_39/1598524974638OStx8_JPEG/YjuHsmWJcmWi-PzvJ9GgilDX.jpg',
#      'type': 's',
#      'isSite': '1',
#      'posExact': '1',
#      'x': '126.9240106',
#      'y': '37.5238663',
#      'itemLevel': '12',
#      'isAdultBusiness': False,
#      'streetPanorama': {'id': 'xPRpBkfVY8ZqB37kvbHZmQ==',
#       'pan': '-44.72',
#       'tilt': '10.00',
#       'lng': '126.9244651',
#       'lat': '37.5234069',
#       'fov': '120'},
#      'skyPanorama': {'id': 'gWYp9/93ngHhoLy6UWKQlA==',
#       'pan': '-4.04',
#       'tilt': '-30.00',
#       'lng': '126.9240875',
#       'lat': '37.5227776',
#       'fov': '124'},
#      'insidePanorama': None,
#      'interiorPanorama': None,
#      'indoorPanorama': None,
#      'theme': None,
#      'poiInfo': {'relation': None,
#       'hasRelation': False,
#       'road': {'poiShapeType': '1',
#        'shapeKey': None,
#        'boundary': None,
#        'detail': None},
#       'hasRoad': False,
#       'land': None,
#       'hasLand': False,
#       'polygon': None,
#       'hasPolygon': False},
#      'homePage': 'https://www.instagram.com/furato_yeouido/',
#      'description': '',
#      'entranceCoords': {'car': [{'rep': True,
#         'x': 126.9244334,
#         'y': 37.523588}],
#       'walk': [{'rep': True, 'x': 126.9244334, 'y': 37.523588}]},
#      'isPollingPlace': False,
#      'bizhourInfo': '평일 11:00~21:30 Break time, 15:00~17:00 Last order 20:30 | 주말 11:30~22:00 No break, Last order 21:00',
#      'menuInfo': '규카츠 15,000 | 반숙 오므라이스 11,000 | 스테키 정식 14,000 | 스테키 덮밥 15,000 | 야마가타 민치카레 12,000 | 우삼겹 덮밥 12,000 | 니꾸 온우동 9,000',
#      'petrolInfo': None,
#      'couponUrl': None,
#      'couponUrlMobile': None,
#      'hasCardBenefit': False,
#      'menuExist': '1',
#      'hasNaverBooking': True,
#      'naverBookingUrl': 'https://booking.naver.com/booking/6/bizes/409957',
#      'naverEasyOrderUrl': None,
#      'hasNaverSmartOrder': False,
#      'reservationLabel': {'standard': True,
#       'preOrder': False,
#       'table': False,
#       'takeout': False},
#      'reservation': {'benefit': '네이버예약으로 방문해주시는 고객님께 미니 치킨가라아게 증정 !'},
#      'hasBroadcastInfo': False,
#      'broadcastInfo': None,
#      'shopWindowInfo': None,
#      'hasNPay': False,
#      'carWash': '',
#      'parkingPrice': '-1',
#      'card': '',
#      'distance': '18407.41',
#      'marker': 'nres://marker/00064-00122',
#      'markerSelected': 'nres://marker/00064-00276',
#      'microReview': [],
#      'michelinGuide': None,
#      'indoor': None,
#      'markerLabel': None,
#      'subway': None,
#      'evChargerInfo': {'summary': {'quickEvCharger': {'chargingSpeed': '급속',
#         'availability': '',
#         'names': ''},
#        'slowEvCharger': {'chargingSpeed': '완속',
#         'availability': '',
#         'names': ''}},
#       'evChargerList': []}},
#     {'index': '2',
#      'rank': '3',
#      'id': '1891132344',
#      'name': '미도인 파이낸스여의도',
#      'tel': '02-780-1995',
#      'isCallLink': False,
#      'virtualTel': '',
#      'ppc': '1',
#      'category': ['음식점', '양식'],
#      'categoryPath': [['220036', '220044', '220126']],
#      'address': '서울특별시 영등포구 여의도동 23-8 파이낸스타워 2층 202, 203호',
#      'roadAddress': '서울특별시 영등포구 국제금융로2길 32 파이낸스타워 2층 202, 203호',
#      'abbrAddress': '여의도동 23-8 파이낸스타워 2층 202, 203호',
#      'shortAddress': ['서울 영등포구', '국제금융로2길 32', '파이낸스타워 2층 202, 203호'],
#      'display': '미도인 파이낸스여의도',
#      'telDisplay': '02-780-1995',
#      'context': [],
#      'reviewCount': 69,
#      'ktCallMd': 'a86e9780c5aaa559eab2316426d9f12c',
#      'coupon': '0',
#      'thumUrl': 'https://ldb-phinf.pstatic.net/20201020_160/1603172734300y6ngI_JPEG/KOg7lz8ox0WYBHIlowdBPIAN.jpg',
#      'type': 's',
#      'isSite': '1',
#      'posExact': '1',
#      'x': '126.9241380',
#      'y': '37.5238818',
#      'itemLevel': '12',
#      'isAdultBusiness': False,
#      'streetPanorama': {'id': 'Su7tpzAHQFC3bC+pjWeEog==',
#       'pan': '-45.62',
#       'tilt': '10.00',
#       'lng': '126.9245621',
#       'lat': '37.5234665',
#       'fov': '120'},
#      'skyPanorama': {'id': 'gWYp9/93ngHhoLy6UWKQlA==',
#       'pan': '2.62',
#       'tilt': '-30.00',
#       'lng': '126.9240875',
#       'lat': '37.5227776',
#       'fov': '124'},
#      'insidePanorama': None,
#      'interiorPanorama': None,
#      'indoorPanorama': None,
#      'theme': None,
#      'poiInfo': {'relation': None,
#       'hasRelation': False,
#       'road': {'poiShapeType': '1',
#        'shapeKey': None,
#        'boundary': None,
#        'detail': None},
#       'hasRoad': False,
#       'land': None,
#       'hasLand': False,
#       'polygon': None,
#       'hasPolygon': False},
#      'homePage': '',
#      'description': '',
#      'entranceCoords': {'car': [{'rep': True,
#         'x': 126.9244334,
#         'y': 37.523588}],
#       'walk': [{'rep': True, 'x': 126.9244334, 'y': 37.523588}]},
#      'isPollingPlace': False,
#      'bizhourInfo': '매일 11:00~21:00 라스트 오더 20:10 / 브레이크타임 평일 14:40~17:00, 주말 15:30~17:00',
#      'menuInfo': '400 등심 스테이크 덮밥 (하루 7그릇 한정) 14,700 | 미도인 구첩 반상 (스테이크 구첩, 대창구첩) 15,900 | 곱창 등심 스테이크 (한정메뉴) 17,300 | 곱창 대창 덮밥 (곱대) 14,800 | 가정식 부챗살 스테이크 12,300 | 미도인 등심 스테이크 13,300 | 트리플 스테이크 14,300 | 돈테키 차슈덮밥 8,800 | 화산 불백 덮밥 9,300 | 미도인 스테이크 덮밥 9,800 | 대창 덮밥 10,500 | 큐브 스테이크 덮밥 10,900 | 대창 큐브 스테이크 덮밥 13,800 | 곱창 대창 큐브스테이크 덮밥 (한정메뉴) 16,800 | 청두 사천 탄탄멘 8,500 | 돈코츠 차슈 라멘 8,800 | 카라 돈코츠 라면 9,300 | 미도인 곱창 라멘 (한정메뉴) 12,800 | 미도인 우실장 떡볶이 8,800 | 미도인 곱창 떡볶이(한정메뉴) 13,900 | 미도인 스카치 에그(한정메뉴) 4,800 | 마리네이드 토마토 사라다 6,500 | 음료/주류 6,500',
#      'petrolInfo': None,
#      'couponUrl': None,
#      'couponUrlMobile': None,
#      'hasCardBenefit': False,
#      'menuExist': '1',
#      'hasNaverBooking': False,
#      'naverBookingUrl': '',
#      'naverEasyOrderUrl': None,
#      'hasNaverSmartOrder': False,
#      'reservationLabel': {'standard': False,
#       'preOrder': False,
#       'table': False,
#       'takeout': False},
#      'reservation': {'benefit': ''},
#      'hasBroadcastInfo': False,
#      'broadcastInfo': None,
#      'shopWindowInfo': None,
#      'hasNPay': False,
#      'carWash': '',
#      'parkingPrice': '-1',
#      'card': '',
#      'distance': '18418.77',
#      'marker': 'nres://marker/00064-00122',
#      'markerSelected': 'nres://marker/00064-00276',
#      'microReview': [],
#      'michelinGuide': None,
#      'indoor': None,
#      'markerLabel': None,
#      'subway': None,
#      'evChargerInfo': {'summary': {'quickEvCharger': {'chargingSpeed': '급속',
#         'availability': '',
#         'names': ''},
#        'slowEvCharger': {'chargingSpeed': '완속',
#         'availability': '',
#         'names': ''}},
#       'evChargerList': []}},
#     {'index': '3',
#      'rank': '4',
#      'id': '37392371',
#      'name': '세상의모든아침',
#      'tel': '02-2055-4442',
#      'isCallLink': False,
#      'virtualTel': '',
#      'ppc': '1',
#      'category': ['음식점', '브런치'],
#      'categoryPath': [['220036', '220044', '220133', '220932']],
#      'address': '서울특별시 영등포구 여의도동 28-1 전경련회관 50층, 51층',
#      'roadAddress': '서울특별시 영등포구 여의대로 24 전경련회관 50층, 51층',
#      'abbrAddress': '여의도동 28-1 전경련회관 50층, 51층',
#      'shortAddress': ['서울 영등포구', '여의대로 24', '전경련회관 50층, 51층'],
#      'display': '세상의모든아침',
#      'telDisplay': '02-2055-4442',
#      'context': ['브런치카페', '이탈리안레스토랑', '야경', '아기자기', '데이트'],
#      'reviewCount': 2872,
#      'ktCallMd': '033586c7c9c03dd14a65cf33ad81b2e2',
#      'coupon': '0',
#      'thumUrl': 'https://ldb-phinf.pstatic.net/20181017_241/1539764319378JWCuj_JPEG/ui8XrZvo9ePR2xwtFLTqshda.jpg',
#      'type': 's',
#      'isSite': '1',
#      'posExact': '1',
#      'x': '126.9198605',
#      'y': '37.5222482',
#      'itemLevel': '12',
#      'isAdultBusiness': False,
#      'streetPanorama': {'id': 'ogRwCqORqdpEO3ec6RCZuQ==',
#       'pan': '138.27',
#       'tilt': '10.00',
#       'lng': '126.9196230',
#       'lat': '37.5225138',
#       'fov': '120'},
#      'skyPanorama': {'id': 'qPuEa32mZLQbNcMJt5qp9Q==',
#       'pan': '157.43',
#       'tilt': '-30.00',
#       'lng': '126.9196396',
#       'lat': '37.5227776',
#       'fov': '124'},
#      'insidePanorama': None,
#      'interiorPanorama': None,
#      'indoorPanorama': None,
#      'theme': None,
#      'poiInfo': {'relation': {'poiShapeType': '1',
#        'shapeKey': {'typeName': 'RELA', 'wsid': '1.0', 'shapeID': '37392371'},
#        'boundary': {'minX': '117.9926027',
#         'minY': '19.6944771',
#         'maxX': '117.9926027',
#         'maxY': '19.6944771'},
#        'detail': [{'type': '1',
#          'sid': '1332868203',
#          'fullName': '전경련회관입구',
#          'name': '입구',
#          'category': '입구(사람+차량)',
#          'xPos': '126.9207119',
#          'yPos': '37.5219431'},
#         {'type': '5',
#          'sid': '1062587861',
#          'fullName': '전경련회관입구',
#          'name': '입구',
#          'category': '입구(사람)',
#          'xPos': '126.9197084',
#          'yPos': '37.5224230'}]},
#       'hasRelation': True,
#       'road': {'poiShapeType': '1',
#        'shapeKey': None,
#        'boundary': None,
#        'detail': None},
#       'hasRoad': False,
#       'land': None,
#       'hasLand': False,
#       'polygon': None,
#       'hasPolygon': False},
#      'homePage': 'http://www.theskyfarm.co.kr/',
#      'description': '',
#      'entranceCoords': {'car': [{'rep': True,
#         'x': 126.9207119,
#         'y': 37.5219431}],
#       'walk': [{'rep': True, 'x': 126.9197084, 'y': 37.522423}]},
#      'isPollingPlace': False,
#      'bizhourInfo': '매일 10:00~22:00 Break time 16:00~17:00',
#      'menuInfo': '바게트 프렌치 토스트 24,000 | 샥슈카 29,000 | 트러플 블랙 리조또 29,000 | 킹프라운 토마토 링귀니 27,000 | 뉴욕 스트립 스테이크 42,000',
#      'petrolInfo': None,
#      'couponUrl': None,
#      'couponUrlMobile': None,
#      'hasCardBenefit': False,
#      'menuExist': '1',
#      'hasNaverBooking': False,
#      'naverBookingUrl': '',
#      'naverEasyOrderUrl': None,
#      'hasNaverSmartOrder': False,
#      'reservationLabel': {'standard': False,
#       'preOrder': False,
#       'table': False,
#       'takeout': False},
#      'reservation': {'benefit': ''},
#      'hasBroadcastInfo': True,
#      'broadcastInfo': {'name': '생방송투데이', 'menu': '스페니쉬오믈렛/크로크무슈/먹물리조또'},
#      'shopWindowInfo': None,
#      'hasNPay': False,
#      'carWash': '',
#      'parkingPrice': '-1',
#      'card': '',
#      'distance': '18026.64',
#      'marker': 'nres://marker/00064-00122',
#      'markerSelected': 'nres://marker/00064-00276',
#      'microReview': ['전경련회관 50층에서 여의도 전망 바라보며 브런치',
#       '전경련 회관 50층 한강이 내려다보이는 전망 좋은 레스토랑',
#       '여의도 브런치 파스타 분위기 전망 좋은 레스토랑',
#       '창가석 전망 뷰가 멋진 여의도 브런치카페 레스토랑',
#       '꼬맹이생일파티 여의도야경예쁜레스토랑'],
#      'michelinGuide': None,
#      'indoor': None,
#      'markerLabel': None,
#      'subway': None,
#      'evChargerInfo': {'summary': {'quickEvCharger': {'chargingSpeed': '급속',
#         'availability': '',
#         'names': ''},
#        'slowEvCharger': {'chargingSpeed': '완속',
#         'availability': '',
#         'names': ''}},
#       'evChargerList': []}},
#     {'index': '4',
#      'rank': '5',
#      'id': '33879318',
#      'name': '콘래드서울 제스트',
#      'tel': '02-6137-7100',
#      'isCallLink': False,
#      'virtualTel': '0507-1361-7100',
#      'ppc': '1',
#      'category': ['음식점', '뷔페'],
#      'categoryPath': [['220036', '220046', '220164'], ['220036', '231737']],
#      'address': '서울특별시 영등포구 여의도동 23',
#      'roadAddress': '서울특별시 영등포구 국제금융로 10 콘래드서울 2층',
#      'abbrAddress': '여의도동 23',
#      'shortAddress': ['서울 영등포구', '국제금융로 10', '콘래드서울 2층'],
#      'display': '콘래드서울 제스트',
#      'telDisplay': '02-6137-7100',
#      'context': ['이탈리안레스토랑', '디저트뷔페', '대게찜', '고급스러운', '결혼기념일'],
#      'reviewCount': 681,
#      'ktCallMd': '3ad8b129fe4f5012c7a3445bf931051c',
#      'coupon': '0',
#      'thumUrl': 'https://ldb-phinf.pstatic.net/20151209_281/14496316940364DiQP_JPEG/167159525832755_1.jpg',
#      'type': 's',
#      'isSite': '1',
#      'posExact': '1',
#      'x': '126.9269606',
#      'y': '37.5252463',
#      'itemLevel': '8',
#      'isAdultBusiness': False,
#      'streetPanorama': {'id': '1RMtgqDVvkStROm4yUcr6w==',
#       'pan': '-52.53',
#       'tilt': '10.00',
#       'lng': '126.9271733',
#       'lat': '37.5250831',
#       'fov': '120'},
#      'skyPanorama': {'id': 'J+LoR5zLzqhkEe/oRZsyBg==',
#       'pan': '139.32',
#       'tilt': '-30.00',
#       'lng': '126.9262314',
#       'lat': '37.5260925',
#       'fov': '124'},
#      'insidePanorama': None,
#      'interiorPanorama': None,
#      'indoorPanorama': None,
#      'theme': None,
#      'poiInfo': {'relation': {'poiShapeType': '1',
#        'shapeKey': {'typeName': 'RELA', 'wsid': '1.0', 'shapeID': '33879318'},
#        'boundary': {'minX': '117.9926027',
#         'minY': '19.6944771',
#         'maxX': '117.9926027',
#         'maxY': '19.6944771'},
#        'detail': [{'type': '5',
#          'sid': '37704911',
#          'fullName': '콘래드 서울 호텔입구',
#          'name': '콘래드 서울 호텔입구',
#          'category': '입구(사람)',
#          'xPos': '126.9266963',
#          'yPos': '37.5257913'},
#         {'type': '1',
#          'sid': '31059272',
#          'fullName': '콘래드서울호텔입구',
#          'name': '콘래드서울호텔입구',
#          'category': '입구(사람+차량)',
#          'xPos': '126.9269093',
#          'yPos': '37.5250788'}]},
#       'hasRelation': True,
#       'road': {'poiShapeType': '1',
#        'shapeKey': None,
#        'boundary': None,
#        'detail': None},
#       'hasRoad': False,
#       'land': None,
#       'hasLand': False,
#       'polygon': None,
#       'hasPolygon': False},
#      'homePage': 'http://www.conradseoul.co.kr/food/#zest',
#      'description': '',
#      'entranceCoords': {'car': [{'rep': True,
#         'x': 126.9269093,
#         'y': 37.5250788}],
#       'walk': [{'rep': True, 'x': 126.9266963, 'y': 37.5257913}]},
#      'isPollingPlace': False,
#      'bizhourInfo': '매일 06:30~10:30 | 매일 11:30~14:30 | 평일 18:00~21:30 | 토요일 17:30~22:00 2부제 운영 (1부 17:30 ~ 19:30, 2부 20:00 ~ 22:00) | 일요일 18:00~21:30',
#      'menuInfo': '성인 아침 (평일, 주말) 50,000 | 성인 평일 점심 85,000 | 어린이 평일 점심 42,500 | 성인 평일 저녁 100,000 | 어린이 평일 저녁 50,000 | 성인 주말 점심 100,000 | 어린이 주말 점심 50,000 | 성인 주말 저녁 110,000 | 어린이 주말 저녁 55,000',
#      'petrolInfo': None,
#      'couponUrl': None,
#      'couponUrlMobile': None,
#      'hasCardBenefit': False,
#      'menuExist': '1',
#      'hasNaverBooking': True,
#      'naverBookingUrl': 'http://booking.naver.com/booking/6/bizes/93652',
#      'naverEasyOrderUrl': None,
#      'hasNaverSmartOrder': False,
#      'reservationLabel': {'standard': True,
#       'preOrder': False,
#       'table': False,
#       'takeout': False},
#      'reservation': None,
#      'hasBroadcastInfo': True,
#      'broadcastInfo': {'name': '2014테이스티로드', 'menu': '뷔페'},
#      'shopWindowInfo': None,
#      'hasNPay': True,
#      'carWash': '',
#      'parkingPrice': '-1',
#      'card': '',
#      'distance': '18681.28',
#      'marker': 'nres://marker/00063-00122',
#      'markerSelected': 'nres://marker/00063-00276',
#      'microReview': ['여의도 콘래드 호텔의 분위기 좋은 뷔페',
#       '여의도 맛있는뷔페',
#       '여의도 고급스러운 호텔뷔페',
#       '특별한 날 가기 좋은 콘래드 뷔페',
#       '다국적 요리를 즐길 수 있는 뷔페 레스토랑'],
#      'michelinGuide': None,
#      'indoor': None,
#      'markerLabel': None,
#      'subway': None,
#      'evChargerInfo': {'summary': {'quickEvCharger': {'chargingSpeed': '급속',
#         'availability': '',
#         'names': ''},
#        'slowEvCharger': {'chargingSpeed': '완속',
#         'availability': '',
#         'names': ''}},
#       'evChargerList': []}},
#     {'index': '5',
#      'rank': '6',
#      'id': '1343621328',
#      'name': '함루 여의도점',
#      'tel': '02-2070-2030',
#      'isCallLink': False,
#      'virtualTel': '',
#      'ppc': '1',
#      'category': ['일식', '일식당'],
#      'categoryPath': [['220036', '220038', '220081', '220804'],
#       ['222606', '222607', '1004380', '1002043']],
#      'address': '서울특별시 영등포구 여의도동 23-8',
#      'roadAddress': '서울특별시 영등포구 국제금융로2길 32 파이낸스타워 3층 302호',
#      'abbrAddress': '여의도동 23-8',
#      'shortAddress': ['서울 영등포구', '국제금융로2길 32', '파이낸스타워 3층 302호'],
#      'display': '함루 여의도점',
#      'telDisplay': '02-2070-2030',
#      'context': [],
#      'reviewCount': 12,
#      'ktCallMd': '8131dba515376763cd0c58a47e7d772a',
#      'coupon': '0',
#      'thumUrl': 'https://ldb-phinf.pstatic.net/20201021_197/16032915817234Gnpm_JPEG/1rvFsmoI8pM-N0lMJSGPS3_L.jpg',
#      'type': 's',
#      'isSite': '1',
#      'posExact': '1',
#      'x': '126.9241380',
#      'y': '37.5238818',
#      'itemLevel': '8',
#      'isAdultBusiness': False,
#      'streetPanorama': {'id': 'Su7tpzAHQFC3bC+pjWeEog==',
#       'pan': '-45.62',
#       'tilt': '10.00',
#       'lng': '126.9245621',
#       'lat': '37.5234665',
#       'fov': '120'},
#      'skyPanorama': {'id': 'gWYp9/93ngHhoLy6UWKQlA==',
#       'pan': '2.62',
#       'tilt': '-30.00',
#       'lng': '126.9240875',
#       'lat': '37.5227776',
#       'fov': '124'},
#      'insidePanorama': None,
#      'interiorPanorama': None,
#      'indoorPanorama': None,
#      'theme': None,
#      'poiInfo': {'relation': None,
#       'hasRelation': False,
#       'road': {'poiShapeType': '1',
#        'shapeKey': None,
#        'boundary': None,
#        'detail': None},
#       'hasRoad': False,
#       'land': None,
#       'hasLand': False,
#       'polygon': None,
#       'hasPolygon': False},
#      'homePage': '',
#      'description': '',
#      'entranceCoords': {'car': [{'rep': True,
#         'x': 126.9244334,
#         'y': 37.523588}],
#       'walk': [{'rep': True, 'x': 126.9244334, 'y': 37.523588}]},
#      'isPollingPlace': False,
#      'bizhourInfo': '평일 11:00~21:30 일요일휴무',
#      'menuInfo': '히츠마부시 보통 1마리 37,000 | 히츠마부시 특 1.5마리 46,000 | 한우 큐브스테이크 35,000 | 장어 계란말이 15,000 | 우나동 37,000',
#      'petrolInfo': None,
#      'couponUrl': None,
#      'couponUrlMobile': None,
#      'hasCardBenefit': False,
#      'menuExist': '1',
#      'hasNaverBooking': False,
#      'naverBookingUrl': '',
#      'naverEasyOrderUrl': None,
#      'hasNaverSmartOrder': False,
#      'reservationLabel': {'standard': False,
#       'preOrder': False,
#       'table': False,
#       'takeout': False},
#      'reservation': {'benefit': ''},
#      'hasBroadcastInfo': False,
#      'broadcastInfo': None,
#      'shopWindowInfo': None,
#      'hasNPay': False,
#      'carWash': '',
#      'parkingPrice': '-1',
#      'card': '',
#      'distance': '18418.77',
#      'marker': 'nres://marker/00064-00122',
#      'markerSelected': 'nres://marker/00064-00276',
#      'microReview': [],
#      'michelinGuide': None,
#      'indoor': None,
#      'markerLabel': None,
#      'subway': None,
#      'evChargerInfo': {'summary': {'quickEvCharger': {'chargingSpeed': '급속',
#         'availability': '',
#         'names': ''},
#        'slowEvCharger': {'chargingSpeed': '완속',
#         'availability': '',
#         'names': ''}},
#       'evChargerList': []}},
#     {'index': '6',
#      'rank': '7',
#      'id': '1978405203',
#      'name': '오복수산참치',
#      'tel': '02-783-9988',
#      'isCallLink': False,
#      'virtualTel': '0507-1485-9989',
#      'ppc': '1',
#      'category': ['한식', '생선회'],
#      'categoryPath': [['220036', '220037', '220076', '220792', '221630'],
#       ['222606', '222607', '1004452']],
#      'address': '서울특별시 영등포구 여의도동 23-6',
#      'roadAddress': '서울특별시 영등포구 의사당대로 83 오투타워 2층',
#      'abbrAddress': '여의도동 23-6',
#      'shortAddress': ['서울 영등포구', '의사당대로 83', '오투타워 2층'],
#      'display': '오복수산참치',
#      'telDisplay': '02-783-9988',
#      'context': [],
#      'reviewCount': 250,
#      'ktCallMd': 'd1bda44b32c651c29d166ee2c5600ab6',
#      'coupon': '0',
#      'thumUrl': 'https://ldb-phinf.pstatic.net/20200713_157/1594645335223g3Brh_JPEG/X3kpsL_v2PrgvgLUIaCqsxUx.jpeg.jpg',
#      'type': 's',
#      'isSite': '1',
#      'posExact': '1',
#      'x': '126.9234407',
#      'y': '37.5233663',
#      'itemLevel': '8',
#      'isAdultBusiness': False,
#      'streetPanorama': {'id': 'QsOO32nGpUYxxopzoldxtw==',
#       'pan': '62.81',
#       'tilt': '10.00',
#       'lng': '126.9230272',
#       'lat': '37.5231536',
#       'fov': '120'},
#      'skyPanorama': {'id': 'z/54yLPQ81dFNkSevgVPDg==',
#       'pan': '42.32',
#       'tilt': '-30.00',
#       'lng': '126.9229050',
#       'lat': '37.5227776',
#       'fov': '124'},
#      'insidePanorama': None,
#      'interiorPanorama': None,
#      'indoorPanorama': None,
#      'theme': None,
#      'poiInfo': {'relation': None,
#       'hasRelation': False,
#       'road': {'poiShapeType': '1',
#        'shapeKey': None,
#        'boundary': None,
#        'detail': None},
#       'hasRoad': False,
#       'land': None,
#       'hasLand': False,
#       'polygon': None,
#       'hasPolygon': False},
#      'homePage': '',
#      'description': '',
#      'entranceCoords': {'car': [{'rep': True, 'x': 126.923842, 'y': 37.52319}],
#       'walk': [{'rep': True, 'x': 126.923842, 'y': 37.52319}]},
#      'isPollingPlace': False,
#      'bizhourInfo': '평일 11:00~22:00 준비시간 오후3시~오후5시 라스트 오더 런치  2시30분 디너 8시 | 주말 12:00~22:00 | 공휴일 12:00~22:00',
#      'menuInfo': '생참치사시미 55,000 | 코스요리 55,000 | 카이센동 18,000 | 우니동 38,000 | 우니 이쿠라동 33,000 | 우니 호다테 이쿠라동 30,000 | 우니 도로 이쿠라 에비 호다테동 35,000 | 한국식 회덮밥 13,000',
#      'petrolInfo': None,
#      'couponUrl': None,
#      'couponUrlMobile': None,
#      'hasCardBenefit': False,
#      'menuExist': '1',
#      'hasNaverBooking': False,
#      'naverBookingUrl': '',
#      'naverEasyOrderUrl': None,
#      'hasNaverSmartOrder': False,
#      'reservationLabel': {'standard': False,
#       'preOrder': False,
#       'table': False,
#       'takeout': False},
#      'reservation': {'benefit': ''},
#      'hasBroadcastInfo': False,
#      'broadcastInfo': None,
#      'shopWindowInfo': None,
#      'hasNPay': False,
#      'carWash': '',
#      'parkingPrice': '-1',
#      'card': '',
#      'distance': '18352.26',
#      'marker': 'nres://marker/00064-00122',
#      'markerSelected': 'nres://marker/00064-00276',
#      'microReview': [],
#      'michelinGuide': None,
#      'indoor': None,
#      'markerLabel': None,
#      'subway': None,
#      'evChargerInfo': {'summary': {'quickEvCharger': {'chargingSpeed': '급속',
#         'availability': '',
#         'names': ''},
#        'slowEvCharger': {'chargingSpeed': '완속',
#         'availability': '',
#         'names': ''}},
#       'evChargerList': []}},
#     {'index': '7',
#      'rank': '8',
#      'id': '11678773',
#      'name': '진주집',
#      'tel': '02-780-6108',
#      'isCallLink': False,
#      'virtualTel': '',
#      'ppc': '1',
#      'category': ['한식', '국수'],
#      'categoryPath': [['220036', '220037', '220062', '220628'],
#       ['222606', '222607', '1004452']],
#      'address': '서울특별시 영등포구 여의도동 36-2',
#      'roadAddress': '서울특별시 영등포구 국제금융로6길 33',
#      'abbrAddress': '여의도동 36-2',
#      'shortAddress': ['서울 영등포구', '국제금융로6길 33'],
#      'display': '진주집',
#      'telDisplay': '02-780-6108',
#      'context': ['닭칼국수', '비빔국수', '콩국수', '심플한', '데이트'],
#      'reviewCount': 2394,
#      'ktCallMd': 'c617d691729ca847e6415e7acb95ae91',
#      'coupon': '0',
#      'thumUrl': 'https://ldb-phinf.pstatic.net/20150817_105/1439805626093qwrM1_JPEG/166767593044276_0.jpg',
#      'type': 's',
#      'isSite': '1',
#      'posExact': '1',
#      'x': '126.9268251',
#      'y': '37.5206924',
#      'itemLevel': '12',
#      'isAdultBusiness': False,
#      'streetPanorama': {'id': 'yG7olVJihzfh9ft/W5ctIg==',
#       'pan': '55.61',
#       'tilt': '10.00',
#       'lng': '126.9266342',
#       'lat': '37.5205616',
#       'fov': '120'},
#      'skyPanorama': {'id': 'Hl8uGMXPQylFNK1teScQhw==',
#       'pan': '173.66',
#       'tilt': '-30.00',
#       'lng': '126.9265900',
#       'lat': '37.5227776',
#       'fov': '124'},
#      'insidePanorama': None,
#      'interiorPanorama': None,
#      'indoorPanorama': None,
#      'theme': None,
#      'poiInfo': {'relation': None,
#       'hasRelation': False,
#       'road': {'poiShapeType': '1',
#        'shapeKey': None,
#        'boundary': None,
#        'detail': None},
#       'hasRoad': False,
#       'land': None,
#       'hasLand': False,
#       'polygon': None,
#       'hasPolygon': False},
#      'homePage': '',
#      'description': '',
#      'entranceCoords': {'car': [{'rep': True,
#         'x': 126.9270052,
#         'y': 37.5211441}],
#       'walk': [{'rep': True, 'x': 126.9266366, 'y': 37.5211656}]},
#      'isPollingPlace': False,
#      'bizhourInfo': '평일 10:00~20:00 | 토요일 10:00~19:00 | 일요일 휴무 | 공휴일 휴무',
#      'menuInfo': '냉콩국수 11,000 | 비빔국수 9,000 | 닭칼국수 9,000 | 육개장칼국수 9,000 | 접시만두 9,000',
#      'petrolInfo': None,
#      'couponUrl': None,
#      'couponUrlMobile': None,
#      'hasCardBenefit': False,
#      'menuExist': '1',
#      'hasNaverBooking': False,
#      'naverBookingUrl': 'https://booking.naver.com/booking/6/bizes/143264',
#      'naverEasyOrderUrl': None,
#      'hasNaverSmartOrder': False,
#      'reservationLabel': {'standard': False,
#       'preOrder': False,
#       'table': False,
#       'takeout': False},
#      'reservation': {'benefit': ''},
#      'hasBroadcastInfo': True,
#      'broadcastInfo': {'name': '생방송투데이', 'menu': '콩국수'},
#      'shopWindowInfo': None,
#      'hasNPay': False,
#      'carWash': '',
#      'parkingPrice': '-1',
#      'card': '',
#      'distance': '18625.98',
#      'marker': 'nres://marker/00064-00122',
#      'markerSelected': 'nres://marker/00064-00276',
#      'microReview': ['이영자 맛집리스트에도 올라와있는 콩국수 닭칼국수',
#       '닭칼국수 콩국수가 유명한 이영자 맛집',
#       '여의도 두 번 먹어도 안 질리는 콩국수 만두 맛집',
#       '영자로드에 나온  여의도 콩국수 맛집',
#       '여의도 점심 더울때 더 맛있는 콩국수'],
#      'michelinGuide': None,
#      'indoor': None,
#      'markerLabel': None,
#      'subway': None,
#      'evChargerInfo': {'summary': {'quickEvCharger': {'chargingSpeed': '급속',
#         'availability': '',
#         'names': ''},
#        'slowEvCharger': {'chargingSpeed': '완속',
#         'availability': '',
#         'names': ''}},
#       'evChargerList': []}},
#     {'index': '8',
#      'rank': '9',
#      'id': '34033812',
#      'name': '콘래드서울 37그릴앤바',
#      'tel': '02-6137-7110',
#      'isCallLink': False,
#      'virtualTel': '',
#      'ppc': '1',
#      'category': ['음식점', '양식'],
#      'categoryPath': [['220036', '220044', '220126'], ['220036', '231737']],
#      'address': '서울특별시 영등포구 여의도동 23',
#      'roadAddress': '서울특별시 영등포구 국제금융로 10 서울 국제금융 센터',
#      'abbrAddress': '여의도동 23',
#      'shortAddress': ['서울 영등포구', '국제금융로 10', '서울 국제금융 센터'],
#      'display': '콘래드서울 37그릴앤바',
#      'telDisplay': '02-6137-7110',
#      'context': ['와인바', '레스토랑', '브런치뷔페', '고급스러운', '데이트'],
#      'reviewCount': 577,
#      'ktCallMd': '3f47b5740b03b370309dfe5194335e41',
#      'coupon': '0',
#      'thumUrl': 'http://ldb.phinf.naver.net/20151209_205/1449631690758L3hp0_JPEG/167159525828997_8.jpg',
#      'type': 's',
#      'isSite': '1',
#      'posExact': '1',
#      'x': '126.9261959',
#      'y': '37.5255747',
#      'itemLevel': '8',
#      'isAdultBusiness': False,
#      'streetPanorama': {'id': '6pu62l4ccnM+QwAtj4MIdg==',
#       'pan': '-107.94',
#       'tilt': '10.00',
#       'lng': '126.9262650',
#       'lat': '37.5255970',
#       'fov': '120'},
#      'skyPanorama': {'id': 'J+LoR5zLzqhkEe/oRZsyBg==',
#       'pan': '-176.17',
#       'tilt': '-30.00',
#       'lng': '126.9262314',
#       'lat': '37.5260925',
#       'fov': '124'},
#      'insidePanorama': None,
#      'interiorPanorama': None,
#      'indoorPanorama': None,
#      'theme': None,
#      'poiInfo': {'relation': None,
#       'hasRelation': False,
#       'road': {'poiShapeType': '1',
#        'shapeKey': None,
#        'boundary': None,
#        'detail': None},
#       'hasRoad': False,
#       'land': None,
#       'hasLand': False,
#       'polygon': None,
#       'hasPolygon': False},
#      'homePage': 'http://www.conradseoul.co.kr/food/#grill37',
#      'description': '',
#      'entranceCoords': None,
#      'isPollingPlace': False,
#      'bizhourInfo': '매일 11:30~14:30 | 매일 18:00~22:30 | 주말 11:00~14:30 주말브런치',
#      'menuInfo': '테이스팅 메뉴 155,000 | 주말 브런치 79,000 | 모듬 육류구이 140,000 | 포르투칼식 해산물 꼬치구이 130,000',
#      'petrolInfo': None,
#      'couponUrl': None,
#      'couponUrlMobile': None,
#      'hasCardBenefit': False,
#      'menuExist': '1',
#      'hasNaverBooking': True,
#      'naverBookingUrl': 'https://booking.naver.com/booking/6/bizes/182477',
#      'naverEasyOrderUrl': None,
#      'hasNaverSmartOrder': False,
#      'reservationLabel': {'standard': True,
#       'preOrder': False,
#       'table': False,
#       'takeout': False},
#      'reservation': None,
#      'hasBroadcastInfo': False,
#      'broadcastInfo': None,
#      'shopWindowInfo': None,
#      'hasNPay': True,
#      'carWash': '',
#      'parkingPrice': '-1',
#      'card': '',
#      'distance': '18617.79',
#      'marker': 'nres://marker/00063-00122',
#      'markerSelected': 'nres://marker/00063-00276',
#      'microReview': ['전망과 야경이 끝내주는 로맨틱한 호텔 레스토랑',
#       '야경좋은 레스토랑',
#       '크리스마스 이브에 맛있게 즐기는 브런치',
#       '한강이 내려다보이는 37층 전망 좋은 레스토랑',
#       '서울 야경이 멋진 와인바'],
#      'michelinGuide': None,
#      'indoor': None,
#      'markerLabel': None,
#      'subway': None,
#      'evChargerInfo': {'summary': {'quickEvCharger': {'chargingSpeed': '급속',
#         'availability': '',
#         'names': ''},
#        'slowEvCharger': {'chargingSpeed': '완속',
#         'availability': '',
#         'names': ''}},
#       'evChargerList': []}},
#     {'index': '9',
#      'rank': '10',
#      'id': '1670537887',
#      'name': '단아',
#      'tel': '02-780-8711',
#      'isCallLink': False,
#      'virtualTel': '0507-1357-8711',
#      'ppc': '1',
#      'category': ['음식점', '한식'],
#      'categoryPath': [['220036', '220037', '220053'],
#       ['222606', '222607', '1004452']],
#      'address': '서울특별시 영등포구 여의도동 44-25',
#      'roadAddress': '서울특별시 영등포구 여의대방로67길 21 정곡빌딩 3층',
#      'abbrAddress': '여의도동 44-25',
#      'shortAddress': ['서울 영등포구', '여의대방로67길 21', '정곡빌딩 3층'],
#      'display': '단아',
#      'telDisplay': '02-780-8711',
#      'context': [],
#      'reviewCount': 37,
#      'ktCallMd': 'df7469f541f04f0ff5bc64aee3e36715',
#      'coupon': '0',
#      'thumUrl': 'https://ldb-phinf.pstatic.net/20200414_222/1586847257310CqrxV_JPEG/%C5%A9%B1%E2%BA%AF%C8%AFKakaoTalk_20200414_094830237_19.jpg',
#      'type': 's',
#      'isSite': '1',
#      'posExact': '1',
#      'x': '126.9294212',
#      'y': '37.5205737',
#      'itemLevel': '8',
#      'isAdultBusiness': False,
#      'streetPanorama': {'id': '6y8jaYiO4v1iwzfY4Ximuw==',
#       'pan': '-119.74',
#       'tilt': '10.00',
#       'lng': '126.9296754',
#       'lat': '37.5207186',
#       'fov': '120'},
#      'skyPanorama': {'id': 'dKNrnffGrsBKgJJ+XCS+3A==',
#       'pan': '-169.13',
#       'tilt': '-30.00',
#       'lng': '126.9298477',
#       'lat': '37.5227776',
#       'fov': '124'},
#      'insidePanorama': None,
#      'interiorPanorama': None,
#      'indoorPanorama': None,
#      'theme': None,
#      'poiInfo': {'relation': None,
#       'hasRelation': False,
#       'road': {'poiShapeType': '1',
#        'shapeKey': None,
#        'boundary': None,
#        'detail': None},
#       'hasRoad': False,
#       'land': None,
#       'hasLand': False,
#       'polygon': None,
#       'hasPolygon': False},
#      'homePage': 'http://dana7808711.modoo.at',
#      'description': '',
#      'entranceCoords': {'car': [{'rep': True,
#         'x': 126.9295426,
#         'y': 37.5207395}],
#       'walk': [{'rep': True, 'x': 126.9295426, 'y': 37.5207395}]},
#      'isPollingPlace': False,
#      'bizhourInfo': '금요일 11:30~23:00 공휴일 휴무 | 목요일 11:30~23:00 공휴일 휴무 | 수요일 11:30~23:00 공휴일 휴무 | 화요일 11:30~23:00 공휴일 휴무 | 월요일 11:30~23:00 공휴일 휴무 | 토요일 휴무 공휴일 휴무 | 일요일 휴무 공휴일 휴무',
#      'menuInfo': '[점심] 맑은 민어탕 정식 30,000 | [점심] 연저육 솥밥 세트 25,000 | [점심] 박대 구이 세트 23,000 | [점심] 명란 버섯 솥밥 정식 18,000 | [점심] 전복 해초 솥밥 정식 20,000 | [점심 추가 단품] 제육볶음 추가 15,000 | [점심 추가 단품] 연저육 추가 20,000 | [점심 추가 단품] 제철 숙성회 한 접시 30,000 | [저녁] 2인 한상차림 78,000 | [저녁] 3~4인 한상차림 155,000 | [저녁] 5~6인 한상차림 280,000 | [저녁] 단 아 한 상차림 380,000 | [저녁] 해양 심층수 손두부 13,000 | [저녁] 두부와 김치 18,000 | [저녁] 두부 삼합 35,000 | [저녁] 두부 사합 40,000 | [저녁] 명란 바삭 愛 감자전 28,000 | [저녁] 명란 치즈 愛 감자전 30,000 | [저녁] 돌문어 해물파전 30,000 | [저녁] 전복 김치전 30,000 | [저녁] 갓김치 육전 38,000 | [저녁] 모둠전 40,000 | [저녁] 낙지 볶음 28,000 | [저녁] 해산물 황태 강정 30,000 | [저녁] 산낙지 25,000 | [저녁] 돌문어 한마리 50,000 | [저녁] 해산물 모둠 中 55,000 | [저녁] 해산물 모둠 大 75,000 | [저녁] 모둠 회 中 65,000 | [저녁] 모둠 회 大 85,000 | [저녁] 모둠 생선포 15,000 | [저녁] 추정미 솥밥 8,000 | [저녁] 명란 버섯 솥밥 13,000 | [저녁]  전복 해초 솥밥 15,000 | [저녁] 산낙지 두 마리 전골 40,000 | [저녁] 차돌 해물 얼큰탕 40,000 | [저녁] 맑은 민어 전골 60,000 | [점심] 추정미 솥밥 정식 15,000 | [저녁] 오늘이 회 한 접시 변동가격(업주문의) | [저녁] 1인 모둠회 & 해산물 35,000',
#      'petrolInfo': None,
#      'couponUrl': None,
#      'couponUrlMobile': None,
#      'hasCardBenefit': False,
#      'menuExist': '1',
#      'hasNaverBooking': True,
#      'naverBookingUrl': 'https://booking.naver.com/booking/6/bizes/334627',
#      'naverEasyOrderUrl': None,
#      'hasNaverSmartOrder': False,
#      'reservationLabel': {'standard': True,
#       'preOrder': False,
#       'table': False,
#       'takeout': False},
#      'reservation': {'benefit': ''},
#      'hasBroadcastInfo': False,
#      'broadcastInfo': None,
#      'shopWindowInfo': None,
#      'hasNPay': False,
#      'carWash': '',
#      'parkingPrice': '-1',
#      'card': '',
#      'distance': '18853.61',
#      'marker': 'nres://marker/00064-00122',
#      'markerSelected': 'nres://marker/00064-00276',
#      'microReview': [],
#      'michelinGuide': None,
#      'indoor': None,
#      'markerLabel': None,
#      'subway': None,
#      'evChargerInfo': {'summary': {'quickEvCharger': {'chargingSpeed': '급속',
#         'availability': '',
#         'names': ''},
#        'slowEvCharger': {'chargingSpeed': '완속',
#         'availability': '',
#         'names': ''}},
#       'evChargerList': []}},
#     {'index': '10',
#      'rank': '11',
#      'id': '31570129',
#      'name': '본보야지',
#      'tel': '02-782-8889',
#      'isCallLink': False,
#      'virtualTel': '0507-1429-8889',
#      'ppc': '1',
#      'category': ['음식점', '이탈리아음식'],
#      'categoryPath': [['220036', '220044', '220127', '220913'],
#       ['222606', '222607', '1004452']],
#      'address': '서울특별시 영등포구 여의도동 24',
#      'roadAddress': '서울특별시 영등포구 국제금융로2길 7 한주빌딩 2층',
#      'abbrAddress': '여의도동 24',
#      'shortAddress': ['서울 영등포구', '국제금융로2길 7', '한주빌딩 2층'],
#      'display': '본보야지',
#      'telDisplay': '02-782-8889',
#      'context': ['스테이크', '크림파스타', '이탈리안레스토랑', '고급스러운', '데이트'],
#      'reviewCount': 863,
#      'ktCallMd': '5e3b9779f519862cb84de28fbd5bc8a6',
#      'coupon': '0',
#      'thumUrl': 'https://ldb-phinf.pstatic.net/20200324_21/1585039332979XsTjC_JPEG/s8SV4-Mbv4pLPFsjvN73f_zW.jpeg.jpg',
#      'type': 's',
#      'isSite': '1',
#      'posExact': '1',
#      'x': '126.9267148',
#      'y': '37.5245769',
#      'itemLevel': '8',
#      'isAdultBusiness': False,
#      'streetPanorama': {'id': '5znDjxirY9wcdt/vhlYDYQ==',
#       'pan': '140.43',
#       'tilt': '10.00',
#       'lng': '126.9265930',
#       'lat': '37.5247239',
#       'fov': '120'},
#      'skyPanorama': {'id': 'J+LoR5zLzqhkEe/oRZsyBg==',
#       'pan': '162.39',
#       'tilt': '-30.00',
#       'lng': '126.9262314',
#       'lat': '37.5260925',
#       'fov': '124'},
#      'insidePanorama': None,
#      'interiorPanorama': None,
#      'indoorPanorama': None,
#      'theme': None,
#      'poiInfo': {'relation': None,
#       'hasRelation': False,
#       'road': {'poiShapeType': '1',
#        'shapeKey': None,
#        'boundary': None,
#        'detail': None},
#       'hasRoad': False,
#       'land': None,
#       'hasLand': False,
#       'polygon': None,
#       'hasPolygon': False},
#      'homePage': 'http://blog.naver.com/ifcbona8',
#      'description': '',
#      'entranceCoords': {'car': [{'rep': True,
#         'x': 126.9268136,
#         'y': 37.5244001}],
#       'walk': [{'rep': True, 'x': 126.9267572, 'y': 37.524741}]},
#      'isPollingPlace': False,
#      'bizhourInfo': '매일 11:30~23:00 (11:30-22:00)코로나로 인해 한시적 단축 운영 / 연중무휴 | 매일 15:00~17:30 브레이크타임',
#      'menuInfo': '에피-깔라마리 19,000 | 에피-망고살사&새우구이 19,000 | 해산물리조또 24,000 | 피자-마르게리따 25,000 | 채끝스테이크 47,000 | 푸아그라&안심스테이크 55,000 | 소갈빗살로제파스타 25,000 | 트러플알리오올리오 22,000 | 아메리카노 5,000 | 타라파카 까베르네쇼비뇽(레드와인) 39,000',
#      'petrolInfo': None,
#      'couponUrl': None,
#      'couponUrlMobile': None,
#      'hasCardBenefit': False,
#      'menuExist': '1',
#      'hasNaverBooking': False,
#      'naverBookingUrl': '',
#      'naverEasyOrderUrl': None,
#      'hasNaverSmartOrder': False,
#      'reservationLabel': {'standard': False,
#       'preOrder': False,
#       'table': False,
#       'takeout': False},
#      'reservation': {'benefit': ''},
#      'hasBroadcastInfo': False,
#      'broadcastInfo': None,
#      'shopWindowInfo': None,
#      'hasNPay': False,
#      'carWash': '',
#      'parkingPrice': '-1',
#      'card': '',
#      'distance': '18652.46',
#      'marker': 'nres://marker/00064-00122',
#      'markerSelected': 'nres://marker/00064-00276',
#      'microReview': ['스테이크와 파스타가 맛있는 분위기 있는 레스토랑',
#       '피자가 맛있는 여의도이탈리안레스토랑',
#       '파스타가 정말 맛있는 이탈리안 레스토랑',
#       'ifc몰 맛집 점심먹기좋은 여의도 파스타',
#       '여의도맛집 보나베띠 ifc점에서 맛있는 스테이크와 리조또'],
#      'michelinGuide': None,
#      'indoor': None,
#      'markerLabel': None,
#      'subway': None,
#      'evChargerInfo': {'summary': {'quickEvCharger': {'chargingSpeed': '급속',
#         'availability': '',
#         'names': ''},
#        'slowEvCharger': {'chargingSpeed': '완속',
#         'availability': '',
#         'names': ''}},
#       'evChargerList': []}},
#     {'index': '11',
#      'rank': '12',
#      'id': '1974070800',
#      'name': '진가와 여의도점',
#      'tel': '02-782-9072',
#      'isCallLink': False,
#      'virtualTel': '0507-1311-9072',
#      'ppc': '1',
#      'category': ['일식', '일식당'],
#      'categoryPath': [['220036', '220038', '220081', '1002185'],
#       ['222606', '222607', '1004380', '1002043']],
#      'address': '서울특별시 영등포구 여의도동 25 씨티플라자 3층',
#      'roadAddress': '서울특별시 영등포구 국제금융로2길 17 씨티플라자 3층',
#      'abbrAddress': '여의도동 25 씨티플라자 3층',
#      'shortAddress': ['서울 영등포구', '국제금융로2길 17', '씨티플라자 3층'],
#      'display': '진가와 여의도점',
#      'telDisplay': '02-782-9072',
#      'context': [],
#      'reviewCount': 362,
#      'ktCallMd': '414981fa3770e574f31e8f693d0c810d',
#      'coupon': '0',
#      'thumUrl': 'https://ldb-phinf.pstatic.net/20181102_230/1541151668589eBPvf_JPEG/o-HjhXZdmG5nYEJ0GlVJFvio.jpg',
#      'type': 's',
#      'isSite': '1',
#      'posExact': '1',
#      'x': '126.9260364',
#      'y': '37.5240423',
#      'itemLevel': '12',
#      'isAdultBusiness': False,
#      'streetPanorama': {'id': 'o+OW3qd+SArsLiemIJNUqQ==',
#       'pan': '133.05',
#       'tilt': '10.00',
#       'lng': '126.9258215',
#       'lat': '37.5242427',
#       'fov': '120'},
#      'skyPanorama': {'id': 'Hl8uGMXPQylFNK1teScQhw==',
#       'pan': '-23.65',
#       'tilt': '-30.00',
#       'lng': '126.9265900',
#       'lat': '37.5227776',
#       'fov': '124'},
#      'insidePanorama': None,
#      'interiorPanorama': None,
#      'indoorPanorama': None,
#      'theme': None,
#      'poiInfo': {'relation': None,
#       'hasRelation': False,
#       'road': {'poiShapeType': '1',
#        'shapeKey': None,
#        'boundary': None,
#        'detail': None},
#       'hasRoad': False,
#       'land': None,
#       'hasLand': False,
#       'polygon': None,
#       'hasPolygon': False},
#      'homePage': 'http://www.instagram.com/jinkawa_korea',
#      'description': '',
#      'entranceCoords': {'car': [{'rep': True, 'x': 126.926024, 'y': 37.52425}],
#       'walk': [{'rep': True, 'x': 126.926024, 'y': 37.52425},
#        {'rep': False, 'x': 126.925923, 'y': 37.523881}]},
#      'isPollingPlace': False,
#      'bizhourInfo': '평일 11:00~22:00 브레이크타임 : 14:30~17:30, Last order 21:00 | 주말 11:30~21:00 브레이크타임 : 15:00~17:00,Last order 20:00',
#      'menuInfo': '진가와 가이세키 44,000 | 사시미스시정식 28,000 | 스끼야끼나베 33,000 | 삼미소면 15,000 | 붓카케 우동 12,000 | 냉메밀 정식 18,000 | 스키야끼동정식 20,000 | 사케동정식 17,000 | 진가와 소바마끼 11,000 | 치킨 가라아게 18,000 | 한우채끝 타다끼 25,000 | 사바학고 스시 20,000 | 모듬 스시 22,000 | 모듬 튀김 28,000 | 모듬 사시미 변동가격(업주문의) | 마구로 사시미 48,000',
#      'petrolInfo': None,
#      'couponUrl': None,
#      'couponUrlMobile': None,
#      'hasCardBenefit': False,
#      'menuExist': '1',
#      'hasNaverBooking': False,
#      'naverBookingUrl': '',
#      'naverEasyOrderUrl': None,
#      'hasNaverSmartOrder': False,
#      'reservationLabel': {'standard': False,
#       'preOrder': False,
#       'table': False,
#       'takeout': False},
#      'reservation': {'benefit': ''},
#      'hasBroadcastInfo': False,
#      'broadcastInfo': None,
#      'shopWindowInfo': None,
#      'hasNPay': False,
#      'carWash': '',
#      'parkingPrice': '-1',
#      'card': '',
#      'distance': '18587.26',
#      'marker': 'nres://marker/00064-00122',
#      'markerSelected': 'nres://marker/00064-00276',
#      'microReview': [],
#      'michelinGuide': None,
#      'indoor': None,
#      'markerLabel': None,
#      'subway': None,
#      'evChargerInfo': {'summary': {'quickEvCharger': {'chargingSpeed': '급속',
#         'availability': '',
#         'names': ''},
#        'slowEvCharger': {'chargingSpeed': '완속',
#         'availability': '',
#         'names': ''}},
#       'evChargerList': []}},
#     {'index': '12',
#      'rank': '13',
#      'id': '37420412',
#      'name': '사대부집 곳간',
#      'tel': '02-2055-4441',
#      'isCallLink': False,
#      'virtualTel': '',
#      'ppc': '1',
#      'category': ['음식점', '한식'],
#      'categoryPath': [['220036', '220037', '220053']],
#      'address': '서울특별시 영등포구 여의도동 28-1',
#      'roadAddress': '서울특별시 영등포구 여의대로 24 전경련회관 50, 51F',
#      'abbrAddress': '여의도동 28-1',
#      'shortAddress': ['서울 영등포구', '여의대로 24', '전경련회관 50, 51F'],
#      'display': '사대부집 곳간',
#      'telDisplay': '02-2055-4441',
#      'context': ['한식당', '한식뷔페', '이탈리안레스토랑', '고급스러운', '경치'],
#      'reviewCount': 509,
#      'ktCallMd': 'ed891a564456a03874a3dd2034105917',
#      'coupon': '0',
#      'thumUrl': 'https://ldb-phinf.pstatic.net/20180129_79/1517217497087suI72_JPEG/pXPKxMkOBnsCRnJBppNwlwsr.jpg',
#      'type': 's',
#      'isSite': '1',
#      'posExact': '1',
#      'x': '126.9202079',
#      'y': '37.5221961',
#      'itemLevel': '8',
#      'isAdultBusiness': False,
#      'streetPanorama': {'id': '3R2Vk+xX0WwtaerI2C8gKQ==',
#       'pan': '-49.58',
#       'tilt': '10.00',
#       'lng': '126.9206956',
#       'lat': '37.5217804',
#       'fov': '120'},
#      'skyPanorama': {'id': 'pOE0T4Ed249sSaRslvt5AA==',
#       'pan': '-145.01',
#       'tilt': '-30.00',
#       'lng': '126.9206161',
#       'lat': '37.5227776',
#       'fov': '124'},
#      'insidePanorama': None,
#      'interiorPanorama': None,
#      'indoorPanorama': None,
#      'theme': None,
#      'poiInfo': {'relation': None,
#       'hasRelation': False,
#       'road': {'poiShapeType': '1',
#        'shapeKey': None,
#        'boundary': None,
#        'detail': None},
#       'hasRoad': False,
#       'land': None,
#       'hasLand': False,
#       'polygon': None,
#       'hasPolygon': False},
#      'homePage': 'http://www.theskyfarm.co.kr/',
#      'description': '',
#      'entranceCoords': {'car': [{'rep': True,
#         'x': 126.9207173,
#         'y': 37.5219423}],
#       'walk': [{'rep': True, 'x': 126.9197117, 'y': 37.5224266}]},
#      'isPollingPlace': False,
#      'bizhourInfo': '평일 11:30~21:30 Break Time 15:00~17:00 | 주말 11:30~21:30 Break Time 15:00~17:00',
#      'menuInfo': '한방오리탕 반상 36,000 | 제주 은갈치구이 반상 34,000 | 주꾸미 연포탕 반상 33,000 | 재첩부빔밥 반상 28,000',
#      'petrolInfo': None,
# ...
#      'indoorPanorama': None,
#      'theme': None,
#      'poiInfo': {'relation': None,
#       'hasRelation': False,
#       'road': {'poiShapeType': '1',
#        'shapeKey': None,
#        'boundary': None,
#        'detail': None},
#       'hasRoad': False,
#       'land': None,
#       'hasLand': False,
#       'polygon': None,
#       'hasPolygon': False},
#      'homePage': 'https://openyeouido.modoo.at',
#      'description': '',
#      'entranceCoords': {'car': [{'rep': True,
#         'x': 126.925668,
#         'y': 37.522278}],
#       'walk': [{'rep': True, 'x': 126.925668, 'y': 37.522278}]},
#      'isPollingPlace': False,
#      'bizhourInfo': '평일 11:00~23:00 월~금 영업시간 / 라스트 오더 21:30 | 주말 12:00~23:00 토,일 영업시간 / 라스트 오더 21:30 | 평일 15:00~17:00 월~금 브레이크타임 | 주말 16:00~17:00 토,일 브레이크타임',
#      'menuInfo': '런치 스페셜 A 29,000 | 도쿄 스페셜 A 69,000 | 워터에이징 한우 등심 49,500 | 워터에이징 한우 안심 49,500 | 콜키지프리 1',
#      'petrolInfo': None,
#      'couponUrl': None,
#      'couponUrlMobile': None,
#      'hasCardBenefit': False,
#      'menuExist': '1',
#      'hasNaverBooking': True,
#      'naverBookingUrl': 'https://booking.naver.com/booking/6/bizes/164459',
#      'naverEasyOrderUrl': None,
#      'hasNaverSmartOrder': False,
#      'reservationLabel': {'standard': True,
#       'preOrder': False,
#       'table': False,
#       'takeout': False},
#      'reservation': {'benefit': ''},
#      'hasBroadcastInfo': False,
#      'broadcastInfo': None,
#      'shopWindowInfo': None,
#      'hasNPay': False,
#      'carWash': '',
#      'parkingPrice': '-1',
#      'card': '',
#      'distance': '18532.03',
#      'marker': 'nres://marker/00064-00122',
#      'markerSelected': 'nres://marker/00064-00276',
#      'microReview': ['가족 여의도 데이트 맛있는 소고기 도쿄등심',
#       '여의도 데이트 모임장소로 추천하는 도쿄등심 한우',
#       '여의도회식 여직원 취향저격 장소 원한다면 도쿄등심',
#       '한우오마카세맛있는집 도쿄등심',
#       '도쿄등심 여의도 파란색 색감 독특한 ifc몰 맛집'],
#      'michelinGuide': None,
#      'indoor': None,
#      'markerLabel': None,
#      'subway': None,
#      'evChargerInfo': {'summary': {'quickEvCharger': {'chargingSpeed': '급속',
#         'availability': '',
#         'names': ''},
#        'slowEvCharger': {'chargingSpeed': '완속',
#         'availability': '',
#         'names': ''}},
#       'evChargerList': []}},
#     {'index': '16',
#      'rank': '17',
#      'id': '1732363102',
#      'name': '히노노리',
#      'tel': '02-6747-0773',
#      'isCallLink': False,
#      'virtualTel': '0507-1367-0773',
#      'ppc': '1',
#      'category': ['일식', '일식당'],
#      'categoryPath': [['220036', '220038', '220081', '220804']],
#      'address': '서울특별시 영등포구 여의도동 23-6',
#      'roadAddress': '서울특별시 영등포구 의사당대로 83 103호',
#      'abbrAddress': '여의도동 23-6',
#      'shortAddress': ['서울 영등포구', '의사당대로 83', '103호'],
#      'display': '히노노리',
#      'telDisplay': '02-6747-0773',
#      'context': [],
#      'reviewCount': 20,
#      'ktCallMd': '4c72bc8353941399d548a0f5cd89846b',
#      'coupon': '0',
#      'thumUrl': 'https://ldb-phinf.pstatic.net/20200914_4/1600073240625oPq0M_JPEG/Asu2uLWSkQXc137Hr8I2otS0.jpg',
#      'type': 's',
#      'isSite': '1',
#      'posExact': '1',
#      'x': '126.9236298',
#      'y': '37.5232307',
#      'itemLevel': '12',
#      'isAdultBusiness': False,
#      'streetPanorama': {'id': '6Ew5lv3Pm3rv/+OxgZVBHw==',
#       'pan': '-54.48',
#       'tilt': '10.00',
#       'lng': '126.9238824',
#       'lat': '37.5230502',
#       'fov': '120'},
#      'skyPanorama': {'id': 'gWYp9/93ngHhoLy6UWKQlA==',
#       'pan': '-45.31',
#       'tilt': '-30.00',
#       'lng': '126.9240875',
#       'lat': '37.5227776',
#       'fov': '124'},
#      'insidePanorama': None,
#      'interiorPanorama': None,
#      'indoorPanorama': None,
#      'theme': None,
#      'poiInfo': {'relation': None,
#       'hasRelation': False,
#       'road': {'poiShapeType': '1',
#        'shapeKey': None,
#        'boundary': None,
#        'detail': None},
#       'hasRoad': False,
#       'land': None,
#       'hasLand': False,
#       'polygon': None,
#       'hasPolygon': False},
#      'homePage': 'http://www.instagram.com/hino.nori/',
#      'description': '',
#      'entranceCoords': {'car': [{'rep': True, 'x': 126.923842, 'y': 37.52319}],
#       'walk': [{'rep': True, 'x': 126.923842, 'y': 37.52319}]},
#      'isPollingPlace': False,
#      'bizhourInfo': '매일 11:00~22:00 Break Time 15시~17시 / Lunch Last order 14:30',
#      'menuInfo': '히노세트 16,000 | 노리세트 22,000 | 새우튀김 4,200',
#      'petrolInfo': None,
#      'couponUrl': None,
#      'couponUrlMobile': None,
#      'hasCardBenefit': False,
#      'menuExist': '1',
#      'hasNaverBooking': False,
#      'naverBookingUrl': '',
#      'naverEasyOrderUrl': None,
#      'hasNaverSmartOrder': False,
#      'reservationLabel': {'standard': False,
#       'preOrder': False,
#       'table': False,
#       'takeout': False},
#      'reservation': {'benefit': ''},
#      'hasBroadcastInfo': False,
#      'broadcastInfo': None,
#      'shopWindowInfo': None,
#      'hasNPay': False,
#      'carWash': '',
#      'parkingPrice': '-1',
#      'card': '',
#      'distance': '18367.54',
#      'marker': 'nres://marker/00064-00122',
#      'markerSelected': 'nres://marker/00064-00276',
#      'microReview': [],
#      'michelinGuide': None,
#      'indoor': None,
#      'markerLabel': None,
#      'subway': None,
#      'evChargerInfo': {'summary': {'quickEvCharger': {'chargingSpeed': '급속',
#         'availability': '',
#         'names': ''},
#        'slowEvCharger': {'chargingSpeed': '완속',
#         'availability': '',
#         'names': ''}},
#       'evChargerList': []}},
#     {'index': '17',
#      'rank': '18',
#      'id': '21052525',
#      'name': '폴앤폴리나 여의도점',
#      'tel': '02-761-1966',
#      'isCallLink': False,
#      'virtualTel': '',
#      'ppc': '1',
#      'category': ['카페,디저트', '베이커리'],
#      'categoryPath': [['220036', '220052', '220564', '221161'],
#       ['222606', '222607', '1004452']],
#      'address': '서울특별시 영등포구 여의도동 37 아일렉스빌딩 1층',
#      'roadAddress': '서울특별시 영등포구 의사당대로 108 아일렉스 상가',
#      'abbrAddress': '여의도동 37 아일렉스빌딩 1층',
#      'shortAddress': ['서울 영등포구', '의사당대로 108', '아일렉스 상가'],
#      'display': '폴앤폴리나 여의도점',
#      'telDisplay': '02-761-1966',
#      'context': ['스콘', '프레즐', '식빵', '화려한', '나들이'],
#      'reviewCount': 293,
#      'ktCallMd': '9e8456bae90e4b7e6385528b557300d9',
#      'coupon': '0',
#      'thumUrl': 'https://ldb-phinf.pstatic.net/20200703_259/1593780644263MJ5Fk_JPEG/gLccoHjYW30bbusRysoj93z8.jpg',
#      'type': 's',
#      'isSite': '1',
#      'posExact': '1',
#      'x': '126.9238941',
#      'y': '37.5210045',
#      'itemLevel': '12',
#      'isAdultBusiness': False,
#      'streetPanorama': {'id': 'EnJKesXoiXr5drp6DUPvvA==',
#       'pan': '-106.83',
#       'tilt': '10.00',
#       'lng': '126.9243896',
#       'lat': '37.5211539',
#       'fov': '120'},
#      'skyPanorama': {'id': 'gWYp9/93ngHhoLy6UWKQlA==',
#       'pan': '-173.86',
#       'tilt': '-30.00',
#       'lng': '126.9240875',
#       'lat': '37.5227776',
#       'fov': '124'},
#      'insidePanorama': None,
#      'interiorPanorama': None,
#      'indoorPanorama': None,
#      'theme': None,
#      'poiInfo': {'relation': None,
#       'hasRelation': False,
#       'road': {'poiShapeType': '1',
#        'shapeKey': None,
#        'boundary': None,
#        'detail': None},
#       'hasRoad': False,
#       'land': None,
#       'hasLand': False,
#       'polygon': None,
#       'hasPolygon': False},
#      'homePage': '',
#      'description': '',
#      'entranceCoords': {'car': None,
#       'walk': [{'rep': True, 'x': 126.9243188, 'y': 37.5212061}]},
#      'isPollingPlace': False,
#      'bizhourInfo': '평일 12:00~19:00 | 일요일 휴무 12월25일, 구정연휴, 추석 | 토요일 11:00~18:00',
#      'menuInfo': '블랙올리브 3,600 | 허브빵 1,700 | 치아바타 3,100 | 화이트 치아바타 2,800',
#      'petrolInfo': None,
#      'couponUrl': None,
#      'couponUrlMobile': None,
#      'hasCardBenefit': False,
#      'menuExist': '1',
#      'hasNaverBooking': False,
#      'naverBookingUrl': '',
#      'naverEasyOrderUrl': None,
#      'hasNaverSmartOrder': False,
#      'reservationLabel': {'standard': False,
#       'preOrder': False,
#       'table': False,
#       'takeout': False},
#      'reservation': {'benefit': ''},
#      'hasBroadcastInfo': False,
#      'broadcastInfo': None,
#      'shopWindowInfo': None,
#      'hasNPay': False,
#      'carWash': '',
#      'parkingPrice': '-1',
#      'card': '',
#      'distance': '18370.52',
#      'marker': 'nres://marker/00064-00013',
#      'markerSelected': 'nres://marker/00064-00166',
#      'microReview': ['제대로 된 깜빠뉴를 내는 여의도 대표 빵집',
#       '수요미식회로 유명한 폴앤폴리나 빵집',
#       '여의도 유명한 빵집',
#       '여의도에서 만난 빵집',
#       '기본에 충실한 빵집'],
#      'michelinGuide': None,
#      'indoor': None,
#      'markerLabel': None,
#      'subway': None,
#      'evChargerInfo': {'summary': {'quickEvCharger': {'chargingSpeed': '급속',
#         'availability': '',
#         'names': ''},
#        'slowEvCharger': {'chargingSpeed': '완속',
#         'availability': '',
#         'names': ''}},
#       'evChargerList': []}},
#     {'index': '18',
#      'rank': '19',
#      'id': '1603372541',
#      'name': '패트릭스와플',
#      'tel': '02-782-8896',
#      'isCallLink': False,
#      'virtualTel': '',
#      'ppc': '1',
#      'category': ['카페,디저트', '와플'],
#      'categoryPath': [['220036', '220052', '220567', '221188'],
#       ['222606', '222607', '1004452']],
#      'address': '서울특별시 영등포구 여의도동 37 아일렉스 지하1층 B06호',
#      'roadAddress': '서울특별시 영등포구 의사당대로 108 아일렉스 지하1층 비06호',
#      'abbrAddress': '여의도동 37 아일렉스 지하1층 B06호',
#      'shortAddress': ['서울 영등포구', '의사당대로 108', '아일렉스 지하1층 비06호'],
#      'display': '패트릭스와플',
#      'telDisplay': '02-782-8896',
#      'context': [],
#      'reviewCount': 83,
#      'ktCallMd': '5aaecbb25fef88a67753c23004f191c3',
#      'coupon': '0',
#      'thumUrl': 'https://ldb-phinf.pstatic.net/20190226_15/1551163260681kUbX5_JPEG/wJMX53DgIED1Fuxg7wXwl3kA.jpeg.jpg',
#      'type': 's',
#      'isSite': '1',
#      'posExact': '1',
#      'x': '126.9238388',
#      'y': '37.5210051',
#      'itemLevel': '12',
#      'isAdultBusiness': False,
#      'streetPanorama': {'id': 'O+vx1pahNOon1DFNlC0bkw==',
#       'pan': '126.60',
#       'tilt': '10.00',
#       'lng': '126.9235554',
#       'lat': '37.5212151',
#       'fov': '120'},
#      'skyPanorama': {'id': 'gWYp9/93ngHhoLy6UWKQlA==',
#       'pan': '-172.10',
#       'tilt': '-30.00',
#       'lng': '126.9240875',
#       'lat': '37.5227776',
#       'fov': '124'},
#      'insidePanorama': None,
#      'interiorPanorama': None,
#      'indoorPanorama': None,
#      'theme': None,
#      'poiInfo': {'relation': None,
#       'hasRelation': False,
#       'road': {'poiShapeType': '1',
#        'shapeKey': None,
#        'boundary': None,
#        'detail': None},
#       'hasRoad': False,
#       'land': None,
#       'hasLand': False,
#       'polygon': None,
#       'hasPolygon': False},
#      'homePage': 'https://www.instagram.com/patrickswaffle02',
#      'description': '',
#      'entranceCoords': {'car': None,
#       'walk': [{'rep': True, 'x': 126.9243188, 'y': 37.5212061}]},
#      'isPollingPlace': False,
#      'bizhourInfo': '일요일 11:00~19:30 Last Order 19:00 / 토요일 휴무 | 평일 11:00~19:30 Last Order 19:00 / 토요일 휴무',
#      'menuInfo': '오리지널 와플 2,600 | 말차 와플 3,300 | 코코넛 와플 3,300 | 아메리카노(Hot/Ice) 2,900 | 라떼(Hot/Ice) 3,800',
#      'petrolInfo': None,
#      'couponUrl': None,
#      'couponUrlMobile': None,
#      'hasCardBenefit': False,
#      'menuExist': '1',
#      'hasNaverBooking': False,
#      'naverBookingUrl': '',
#      'naverEasyOrderUrl': None,
#      'hasNaverSmartOrder': False,
#      'reservationLabel': {'standard': False,
#       'preOrder': False,
#       'table': False,
#       'takeout': False},
#      'reservation': {'benefit': ''},
#      'hasBroadcastInfo': True,
#      'broadcastInfo': {'name': '수요미식회', 'menu': '벨기에와플/말차와플/코코넛와플'},
#      'shopWindowInfo': None,
#      'hasNPay': False,
#      'carWash': '',
#      'parkingPrice': '-1',
#      'card': '',
#      'distance': '18365.66',
#      'marker': 'nres://marker/00064-00013',
#      'markerSelected': 'nres://marker/00064-00166',
#      'microReview': [],
#      'michelinGuide': None,
#      'indoor': None,
#      'markerLabel': None,
#      'subway': None,
#      'evChargerInfo': {'summary': {'quickEvCharger': {'chargingSpeed': '급속',
#         'availability': '',
#         'names': ''},
#        'slowEvCharger': {'chargingSpeed': '완속',
#         'availability': '',
#         'names': ''}},
#       'evChargerList': []}},
#     {'index': '19',
#      'rank': '20',
#      'id': '13391329',
#      'name': '이타마에',
#      'tel': '02-2652-7037',
#      'isCallLink': False,
#      'virtualTel': '0507-1404-7037',
#      'ppc': '1',
#      'category': ['술집', '이자카야'],
#      'categoryPath': [['220036', '220051', '220556', '221121'],
#       ['222606', '222607', '1004452']],
#      'address': '서울특별시 영등포구 여의도동 37',
#      'roadAddress': '서울특별시 영등포구 의사당대로 108 아일렉스빌딩 502호',
#      'abbrAddress': '여의도동 37',
#      'shortAddress': ['서울 영등포구', '의사당대로 108', '아일렉스빌딩 502호'],
#      'display': '이타마에',
#      'telDisplay': '02-2652-7037',
#      'context': ['이자카야', '일식', '초밥', '프라이빗', '데이트'],
#      'reviewCount': 203,
#      'ktCallMd': '2ff68e9c7e059d739d10c4553feb6f7e',
#      'coupon': '0',
#      'thumUrl': 'https://ldb-phinf.pstatic.net/20180424_211/15245489514381VrLa_JPEG/DSC06060.JPG',
#      'type': 's',
#      'isSite': '1',
#      'posExact': '1',
#      'x': '126.9239878',
#      'y': '37.5210130',
#      'itemLevel': '8',
#      'isAdultBusiness': False,
#      'streetPanorama': {'id': 'EnJKesXoiXr5drp6DUPvvA==',
#       'pan': '-109.38',
#       'tilt': '10.00',
#       'lng': '126.9243896',
#       'lat': '37.5211539',
#       'fov': '120'},
#      'skyPanorama': {'id': 'gWYp9/93ngHhoLy6UWKQlA==',
#       'pan': '-176.86',
#       'tilt': '-30.00',
#       'lng': '126.9240875',
#       'lat': '37.5227776',
#       'fov': '124'},
#      'insidePanorama': None,
#      'interiorPanorama': None,
#      'indoorPanorama': None,
#      'theme': None,
#      'poiInfo': {'relation': None,
#       'hasRelation': False,
#       'road': {'poiShapeType': '1',
#        'shapeKey': None,
#        'boundary': None,
#        'detail': None},
#       'hasRoad': False,
#       'land': None,
#       'hasLand': False,
#       'polygon': None,
#       'hasPolygon': False},
#      'homePage': 'http://itamae.modoo.at/',
#      'description': '',
#      'entranceCoords': {'car': None,
#       'walk': [{'rep': True, 'x': 126.9243188, 'y': 37.5212061}]},
#      'isPollingPlace': False,
#      'bizhourInfo': '금요일 11:30~22:00 B.T 15:00~17:00 | 목요일 11:30~22:00 B.T 15:00~17:00 | 수요일 11:30~22:00 B.T 15:00~17:00 | 화요일 11:30~22:00 B.T 15:00~17:00 | 월요일 11:30~22:00 B.T 15:00~17:00 | 토요일 17:30~22:00',
#      'menuInfo': '점심정식 29,000 | 코스요리 40,000~90,000 | 모듬사시미,참치회 33,000~65,000 | 생연어회 30,000 | 북해도산가리비사시미 27,000 | 흰살생선회카르파쵸(광어.농어 등) 23,000 | 참치와 장마 와사비 무침 22,000 | 마구로 낫또 21,000 | 타코와사비 장마어니언샐러드 15,000 | 긴다라데리야끼 28,000 | 카이센 야끼우동 22,000 | 타마고 오코노미야끼 18,000 | 닭다리살 데리야끼 18,000 | 소고기아스파라거스 야채볶음 23,000 | 차돌박이숙주볶음 22,000 | 금일의 추천생선구이/조림 변동가격(업주문의) | 마구로타다키 23,000 | 닭다리살 남방즈케 19,000 | 생연어샐러드 23,000 | 아게다시도후 샐러드 16,000 | 나베,국물류 18,000~33,000 | 금일의 모듬 꼬치구이 23,000 | 새우덴뿌라 20,000 | 토리니쿠 가라아게 15,000 | 이카 가라아게 15,000 | 수제고롯케 16,000 | 모듬생선초밥 22,000~28,000 | 연어뱃살아부리초밥 17,000',
#      'petrolInfo': None,
#      'couponUrl': None,
#      'couponUrlMobile': None,
#      'hasCardBenefit': False,
#      'menuExist': '1',
#      'hasNaverBooking': True,
#      'naverBookingUrl': 'https://booking.naver.com/booking/6/bizes/136029',
#      'naverEasyOrderUrl': None,
#      'hasNaverSmartOrder': False,
#      'reservationLabel': {'standard': True,
#       'preOrder': False,
#       'table': False,
#       'takeout': False},
#      'reservation': {'benefit': ''},
#      'hasBroadcastInfo': False,
#      'broadcastInfo': None,
#      'shopWindowInfo': None,
#      'hasNPay': False,
#      'carWash': '',
#      'parkingPrice': '-1',
#      'card': '',
#      'distance': '18378.84',
#      'marker': 'nres://marker/00064-00119',
#      'markerSelected': 'nres://marker/00064-00273',
#      'microReview': ['식사도 가능한 여의도 이자카야 술집',
#       '여의도술집 조용한 저녁식사장소',
#       '여의도 조용하고 분위기 좋은 룸식 이자카야',
#       '여의도에서 시끄럽지 않은 고급 이자카야',
#       '6번 출구 분위기 좋은 술집'],
#      'michelinGuide': None,
#      'indoor': None,
#      'markerLabel': None,
#      'subway': None,
#      'evChargerInfo': {'summary': {'quickEvCharger': {'chargingSpeed': '급속',
#         'availability': '',
#         'names': ''},
#        'slowEvCharger': {'chargingSpeed': '완속',
#         'availability': '',
#         'names': ''}},
#       'evChargerList': []}}]},
#   'bus': None}}

# %%
r1 = response.json()["result"]["place"]["list"]
r1
# Out:
# [{'index': '0',
#   'rank': '1',
#   'id': '1251024640',
#   'name': '아루히',
#   'tel': '02-780-3903',
#   'isCallLink': False,
#   'virtualTel': '',
#   'ppc': '1',
#   'category': ['일식', '일식당'],
#   'categoryPath': [['220036', '220038', '220081', '220804'],
#    ['222606', '222607', '1004452']],
#   'address': '서울특별시 영등포구 여의도동 35-5',
#   'roadAddress': '서울특별시 영등포구 여의나루로 42 2층',
#   'abbrAddress': '여의도동 35-5',
#   'shortAddress': ['서울 영등포구', '여의나루로 42', '2층'],
#   'display': '아루히',
#   'telDisplay': '02-780-3903',
#   'context': [],
#   'reviewCount': 586,
#   'ktCallMd': 'd922b24a6b816844740eedc691cc6a78',
#   'coupon': '0',
#   'thumUrl': 'https://ldb-phinf.pstatic.net/20190227_268/15512563826654E3P4_JPEG/W09GhSwxyXXkx1z0q744tJBG.jpg',
#   'type': 's',
#   'isSite': '1',
#   'posExact': '1',
#   'x': '126.9249813',
#   'y': '37.5214725',
#   'itemLevel': '8',
#   'isAdultBusiness': False,
#   'streetPanorama': {'id': '+9RWNvH6ApOfUpiTC5paOw==',
#    'pan': '40.33',
#    'tilt': '10.00',
#    'lng': '126.9247758',
#    'lat': '37.5212303',
#    'fov': '120'},
#   'skyPanorama': {'id': 'qDBSTxwmtQw17Cu92NL0aQ==',
#    'pan': '-173.80',
#    'tilt': '-30.00',
#    'lng': '126.9251251',
#    'lat': '37.5227776',
#    'fov': '124'},
#   'insidePanorama': None,
#   'interiorPanorama': None,
#   'indoorPanorama': None,
#   'theme': None,
#   'poiInfo': {'relation': None,
#    'hasRelation': False,
#    'road': {'poiShapeType': '1',
#     'shapeKey': None,
#     'boundary': None,
#     'detail': None},
#    'hasRoad': False,
#    'land': None,
#    'hasLand': False,
#    'polygon': None,
#    'hasPolygon': False},
#   'homePage': 'http://www.instagram.com/aruhi_specialday',
#   'description': '',
#   'entranceCoords': {'car': [{'rep': True, 'x': 126.925, 'y': 37.521884},
#     {'rep': False, 'x': 126.9251363, 'y': 37.5210919}],
#    'walk': [{'rep': True, 'x': 126.9248586, 'y': 37.5218122},
#     {'rep': False, 'x': 126.9249882, 'y': 37.5212405}]},
#   'isPollingPlace': False,
#   'bizhourInfo': '매일 11:30~21:30 (월~일/ Break Time 15:00~17:30)',
#   'menuInfo': '오마카세 런치 33,000 | 오마카세 디너 35,000',
#   'petrolInfo': None,
#   'couponUrl': None,
#   'couponUrlMobile': None,
#   'hasCardBenefit': False,
#   'menuExist': '1',
#   'hasNaverBooking': False,
#   'naverBookingUrl': 'https://booking.naver.com/booking/6/bizes/223362',
#   'naverEasyOrderUrl': None,
#   'hasNaverSmartOrder': False,
#   'reservationLabel': {'standard': False,
#    'preOrder': False,
#    'table': False,
#    'takeout': False},
#   'reservation': {'benefit': ''},
#   'hasBroadcastInfo': False,
#   'broadcastInfo': None,
#   'shopWindowInfo': None,
#   'hasNPay': False,
#   'carWash': '',
#   'parkingPrice': '-1',
#   'card': '',
#   'distance': '18470.18',
#   'marker': 'nres://marker/00064-00122',
#   'markerSelected': 'nres://marker/00064-00276',
#   'microReview': ['수강신청보다 힘들다는 여의도 스시',
#    '여의도 스시 오마카세 가성비 훌륭한 스시',
#    '가성비 내리는 여의도 스시',
#    '가성비 좋기로 유명한 스시집',
#    '스시 오마카세 또 없을 것 같은 곳'],
#   'michelinGuide': None,
#   'indoor': None,
#   'markerLabel': None,
#   'subway': None,
#   'evChargerInfo': {'summary': {'quickEvCharger': {'chargingSpeed': '급속',
#      'availability': '',
#      'names': ''},
#     'slowEvCharger': {'chargingSpeed': '완속', 'availability': '', 'names': ''}},
#    'evChargerList': []}},
#  {'index': '1',
#   'rank': '2',
#   'id': '1483440401',
#   'name': '후라토식당 여의도직영점',
#   'tel': '02-780-7090',
#   'isCallLink': False,
#   'virtualTel': '0507-1331-2710',
#   'ppc': '1',
#   'category': ['일식', '일식당'],
#   'categoryPath': [['220036', '220038', '220081', '220804'],
#    ['222606', '222607', '1004380', '1002043']],
#   'address': '서울특별시 영등포구 여의도동 23-8',
#   'roadAddress': '서울특별시 영등포구 국제금융로2길 32 3층 후라토식당',
#   'abbrAddress': '여의도동 23-8',
#   'shortAddress': ['서울 영등포구', '국제금융로2길 32', '3층 후라토식당'],
#   'display': '후라토<b>식당</b> 여의도직영점',
#   'telDisplay': '02-780-7090',
#   'context': [],
#   'reviewCount': 71,
#   'ktCallMd': '2b13b866933565a885bc378ce4263731',
#   'coupon': '0',
#   'thumUrl': 'https://ldb-phinf.pstatic.net/20200827_39/1598524974638OStx8_JPEG/YjuHsmWJcmWi-PzvJ9GgilDX.jpg',
#   'type': 's',
#   'isSite': '1',
#   'posExact': '1',
#   'x': '126.9240106',
#   'y': '37.5238663',
#   'itemLevel': '12',
#   'isAdultBusiness': False,
#   'streetPanorama': {'id': 'xPRpBkfVY8ZqB37kvbHZmQ==',
#    'pan': '-44.72',
#    'tilt': '10.00',
#    'lng': '126.9244651',
#    'lat': '37.5234069',
#    'fov': '120'},
#   'skyPanorama': {'id': 'gWYp9/93ngHhoLy6UWKQlA==',
#    'pan': '-4.04',
#    'tilt': '-30.00',
#    'lng': '126.9240875',
#    'lat': '37.5227776',
#    'fov': '124'},
#   'insidePanorama': None,
#   'interiorPanorama': None,
#   'indoorPanorama': None,
#   'theme': None,
#   'poiInfo': {'relation': None,
#    'hasRelation': False,
#    'road': {'poiShapeType': '1',
#     'shapeKey': None,
#     'boundary': None,
#     'detail': None},
#    'hasRoad': False,
#    'land': None,
#    'hasLand': False,
#    'polygon': None,
#    'hasPolygon': False},
#   'homePage': 'https://www.instagram.com/furato_yeouido/',
#   'description': '',
#   'entranceCoords': {'car': [{'rep': True, 'x': 126.9244334, 'y': 37.523588}],
#    'walk': [{'rep': True, 'x': 126.9244334, 'y': 37.523588}]},
#   'isPollingPlace': False,
#   'bizhourInfo': '평일 11:00~21:30 Break time, 15:00~17:00 Last order 20:30 | 주말 11:30~22:00 No break, Last order 21:00',
#   'menuInfo': '규카츠 15,000 | 반숙 오므라이스 11,000 | 스테키 정식 14,000 | 스테키 덮밥 15,000 | 야마가타 민치카레 12,000 | 우삼겹 덮밥 12,000 | 니꾸 온우동 9,000',
#   'petrolInfo': None,
#   'couponUrl': None,
#   'couponUrlMobile': None,
#   'hasCardBenefit': False,
#   'menuExist': '1',
#   'hasNaverBooking': True,
#   'naverBookingUrl': 'https://booking.naver.com/booking/6/bizes/409957',
#   'naverEasyOrderUrl': None,
#   'hasNaverSmartOrder': False,
#   'reservationLabel': {'standard': True,
#    'preOrder': False,
#    'table': False,
#    'takeout': False},
#   'reservation': {'benefit': '네이버예약으로 방문해주시는 고객님께 미니 치킨가라아게 증정 !'},
#   'hasBroadcastInfo': False,
#   'broadcastInfo': None,
#   'shopWindowInfo': None,
#   'hasNPay': False,
#   'carWash': '',
#   'parkingPrice': '-1',
#   'card': '',
#   'distance': '18407.41',
#   'marker': 'nres://marker/00064-00122',
#   'markerSelected': 'nres://marker/00064-00276',
#   'microReview': [],
#   'michelinGuide': None,
#   'indoor': None,
#   'markerLabel': None,
#   'subway': None,
#   'evChargerInfo': {'summary': {'quickEvCharger': {'chargingSpeed': '급속',
#      'availability': '',
#      'names': ''},
#     'slowEvCharger': {'chargingSpeed': '완속', 'availability': '', 'names': ''}},
#    'evChargerList': []}},
#  {'index': '2',
#   'rank': '3',
#   'id': '1891132344',
#   'name': '미도인 파이낸스여의도',
#   'tel': '02-780-1995',
#   'isCallLink': False,
#   'virtualTel': '',
#   'ppc': '1',
#   'category': ['음식점', '양식'],
#   'categoryPath': [['220036', '220044', '220126']],
#   'address': '서울특별시 영등포구 여의도동 23-8 파이낸스타워 2층 202, 203호',
#   'roadAddress': '서울특별시 영등포구 국제금융로2길 32 파이낸스타워 2층 202, 203호',
#   'abbrAddress': '여의도동 23-8 파이낸스타워 2층 202, 203호',
#   'shortAddress': ['서울 영등포구', '국제금융로2길 32', '파이낸스타워 2층 202, 203호'],
#   'display': '미도인 파이낸스여의도',
#   'telDisplay': '02-780-1995',
#   'context': [],
#   'reviewCount': 69,
#   'ktCallMd': 'a86e9780c5aaa559eab2316426d9f12c',
#   'coupon': '0',
#   'thumUrl': 'https://ldb-phinf.pstatic.net/20201020_160/1603172734300y6ngI_JPEG/KOg7lz8ox0WYBHIlowdBPIAN.jpg',
#   'type': 's',
#   'isSite': '1',
#   'posExact': '1',
#   'x': '126.9241380',
#   'y': '37.5238818',
#   'itemLevel': '12',
#   'isAdultBusiness': False,
#   'streetPanorama': {'id': 'Su7tpzAHQFC3bC+pjWeEog==',
#    'pan': '-45.62',
#    'tilt': '10.00',
#    'lng': '126.9245621',
#    'lat': '37.5234665',
#    'fov': '120'},
#   'skyPanorama': {'id': 'gWYp9/93ngHhoLy6UWKQlA==',
#    'pan': '2.62',
#    'tilt': '-30.00',
#    'lng': '126.9240875',
#    'lat': '37.5227776',
#    'fov': '124'},
#   'insidePanorama': None,
#   'interiorPanorama': None,
#   'indoorPanorama': None,
#   'theme': None,
#   'poiInfo': {'relation': None,
#    'hasRelation': False,
#    'road': {'poiShapeType': '1',
#     'shapeKey': None,
#     'boundary': None,
#     'detail': None},
#    'hasRoad': False,
#    'land': None,
#    'hasLand': False,
#    'polygon': None,
#    'hasPolygon': False},
#   'homePage': '',
#   'description': '',
#   'entranceCoords': {'car': [{'rep': True, 'x': 126.9244334, 'y': 37.523588}],
#    'walk': [{'rep': True, 'x': 126.9244334, 'y': 37.523588}]},
#   'isPollingPlace': False,
#   'bizhourInfo': '매일 11:00~21:00 라스트 오더 20:10 / 브레이크타임 평일 14:40~17:00, 주말 15:30~17:00',
#   'menuInfo': '400 등심 스테이크 덮밥 (하루 7그릇 한정) 14,700 | 미도인 구첩 반상 (스테이크 구첩, 대창구첩) 15,900 | 곱창 등심 스테이크 (한정메뉴) 17,300 | 곱창 대창 덮밥 (곱대) 14,800 | 가정식 부챗살 스테이크 12,300 | 미도인 등심 스테이크 13,300 | 트리플 스테이크 14,300 | 돈테키 차슈덮밥 8,800 | 화산 불백 덮밥 9,300 | 미도인 스테이크 덮밥 9,800 | 대창 덮밥 10,500 | 큐브 스테이크 덮밥 10,900 | 대창 큐브 스테이크 덮밥 13,800 | 곱창 대창 큐브스테이크 덮밥 (한정메뉴) 16,800 | 청두 사천 탄탄멘 8,500 | 돈코츠 차슈 라멘 8,800 | 카라 돈코츠 라면 9,300 | 미도인 곱창 라멘 (한정메뉴) 12,800 | 미도인 우실장 떡볶이 8,800 | 미도인 곱창 떡볶이(한정메뉴) 13,900 | 미도인 스카치 에그(한정메뉴) 4,800 | 마리네이드 토마토 사라다 6,500 | 음료/주류 6,500',
#   'petrolInfo': None,
#   'couponUrl': None,
#   'couponUrlMobile': None,
#   'hasCardBenefit': False,
#   'menuExist': '1',
#   'hasNaverBooking': False,
#   'naverBookingUrl': '',
#   'naverEasyOrderUrl': None,
#   'hasNaverSmartOrder': False,
#   'reservationLabel': {'standard': False,
#    'preOrder': False,
#    'table': False,
#    'takeout': False},
#   'reservation': {'benefit': ''},
#   'hasBroadcastInfo': False,
#   'broadcastInfo': None,
#   'shopWindowInfo': None,
#   'hasNPay': False,
#   'carWash': '',
#   'parkingPrice': '-1',
#   'card': '',
#   'distance': '18418.77',
#   'marker': 'nres://marker/00064-00122',
#   'markerSelected': 'nres://marker/00064-00276',
#   'microReview': [],
#   'michelinGuide': None,
#   'indoor': None,
#   'markerLabel': None,
#   'subway': None,
#   'evChargerInfo': {'summary': {'quickEvCharger': {'chargingSpeed': '급속',
#      'availability': '',
#      'names': ''},
#     'slowEvCharger': {'chargingSpeed': '완속', 'availability': '', 'names': ''}},
#    'evChargerList': []}},
#  {'index': '3',
#   'rank': '4',
#   'id': '37392371',
#   'name': '세상의모든아침',
#   'tel': '02-2055-4442',
#   'isCallLink': False,
#   'virtualTel': '',
#   'ppc': '1',
#   'category': ['음식점', '브런치'],
#   'categoryPath': [['220036', '220044', '220133', '220932']],
#   'address': '서울특별시 영등포구 여의도동 28-1 전경련회관 50층, 51층',
#   'roadAddress': '서울특별시 영등포구 여의대로 24 전경련회관 50층, 51층',
#   'abbrAddress': '여의도동 28-1 전경련회관 50층, 51층',
#   'shortAddress': ['서울 영등포구', '여의대로 24', '전경련회관 50층, 51층'],
#   'display': '세상의모든아침',
#   'telDisplay': '02-2055-4442',
#   'context': ['브런치카페', '이탈리안레스토랑', '야경', '아기자기', '데이트'],
#   'reviewCount': 2872,
#   'ktCallMd': '033586c7c9c03dd14a65cf33ad81b2e2',
#   'coupon': '0',
#   'thumUrl': 'https://ldb-phinf.pstatic.net/20181017_241/1539764319378JWCuj_JPEG/ui8XrZvo9ePR2xwtFLTqshda.jpg',
#   'type': 's',
#   'isSite': '1',
#   'posExact': '1',
#   'x': '126.9198605',
#   'y': '37.5222482',
#   'itemLevel': '12',
#   'isAdultBusiness': False,
#   'streetPanorama': {'id': 'ogRwCqORqdpEO3ec6RCZuQ==',
#    'pan': '138.27',
#    'tilt': '10.00',
#    'lng': '126.9196230',
#    'lat': '37.5225138',
#    'fov': '120'},
#   'skyPanorama': {'id': 'qPuEa32mZLQbNcMJt5qp9Q==',
#    'pan': '157.43',
#    'tilt': '-30.00',
#    'lng': '126.9196396',
#    'lat': '37.5227776',
#    'fov': '124'},
#   'insidePanorama': None,
#   'interiorPanorama': None,
#   'indoorPanorama': None,
#   'theme': None,
#   'poiInfo': {'relation': {'poiShapeType': '1',
#     'shapeKey': {'typeName': 'RELA', 'wsid': '1.0', 'shapeID': '37392371'},
#     'boundary': {'minX': '117.9926027',
#      'minY': '19.6944771',
#      'maxX': '117.9926027',
#      'maxY': '19.6944771'},
#     'detail': [{'type': '1',
#       'sid': '1332868203',
#       'fullName': '전경련회관입구',
#       'name': '입구',
#       'category': '입구(사람+차량)',
#       'xPos': '126.9207119',
#       'yPos': '37.5219431'},
#      {'type': '5',
#       'sid': '1062587861',
#       'fullName': '전경련회관입구',
#       'name': '입구',
#       'category': '입구(사람)',
#       'xPos': '126.9197084',
#       'yPos': '37.5224230'}]},
#    'hasRelation': True,
#    'road': {'poiShapeType': '1',
#     'shapeKey': None,
#     'boundary': None,
#     'detail': None},
#    'hasRoad': False,
#    'land': None,
#    'hasLand': False,
#    'polygon': None,
#    'hasPolygon': False},
#   'homePage': 'http://www.theskyfarm.co.kr/',
#   'description': '',
#   'entranceCoords': {'car': [{'rep': True, 'x': 126.9207119, 'y': 37.5219431}],
#    'walk': [{'rep': True, 'x': 126.9197084, 'y': 37.522423}]},
#   'isPollingPlace': False,
#   'bizhourInfo': '매일 10:00~22:00 Break time 16:00~17:00',
#   'menuInfo': '바게트 프렌치 토스트 24,000 | 샥슈카 29,000 | 트러플 블랙 리조또 29,000 | 킹프라운 토마토 링귀니 27,000 | 뉴욕 스트립 스테이크 42,000',
#   'petrolInfo': None,
#   'couponUrl': None,
#   'couponUrlMobile': None,
#   'hasCardBenefit': False,
#   'menuExist': '1',
#   'hasNaverBooking': False,
#   'naverBookingUrl': '',
#   'naverEasyOrderUrl': None,
#   'hasNaverSmartOrder': False,
#   'reservationLabel': {'standard': False,
#    'preOrder': False,
#    'table': False,
#    'takeout': False},
#   'reservation': {'benefit': ''},
#   'hasBroadcastInfo': True,
#   'broadcastInfo': {'name': '생방송투데이', 'menu': '스페니쉬오믈렛/크로크무슈/먹물리조또'},
#   'shopWindowInfo': None,
#   'hasNPay': False,
#   'carWash': '',
#   'parkingPrice': '-1',
#   'card': '',
#   'distance': '18026.64',
#   'marker': 'nres://marker/00064-00122',
#   'markerSelected': 'nres://marker/00064-00276',
#   'microReview': ['전경련회관 50층에서 여의도 전망 바라보며 브런치',
#    '전경련 회관 50층 한강이 내려다보이는 전망 좋은 레스토랑',
#    '여의도 브런치 파스타 분위기 전망 좋은 레스토랑',
#    '창가석 전망 뷰가 멋진 여의도 브런치카페 레스토랑',
#    '꼬맹이생일파티 여의도야경예쁜레스토랑'],
#   'michelinGuide': None,
#   'indoor': None,
#   'markerLabel': None,
#   'subway': None,
#   'evChargerInfo': {'summary': {'quickEvCharger': {'chargingSpeed': '급속',
#      'availability': '',
#      'names': ''},
#     'slowEvCharger': {'chargingSpeed': '완속', 'availability': '', 'names': ''}},
#    'evChargerList': []}},
#  {'index': '4',
#   'rank': '5',
#   'id': '33879318',
#   'name': '콘래드서울 제스트',
#   'tel': '02-6137-7100',
#   'isCallLink': False,
#   'virtualTel': '0507-1361-7100',
#   'ppc': '1',
#   'category': ['음식점', '뷔페'],
#   'categoryPath': [['220036', '220046', '220164'], ['220036', '231737']],
#   'address': '서울특별시 영등포구 여의도동 23',
#   'roadAddress': '서울특별시 영등포구 국제금융로 10 콘래드서울 2층',
#   'abbrAddress': '여의도동 23',
#   'shortAddress': ['서울 영등포구', '국제금융로 10', '콘래드서울 2층'],
#   'display': '콘래드서울 제스트',
#   'telDisplay': '02-6137-7100',
#   'context': ['이탈리안레스토랑', '디저트뷔페', '대게찜', '고급스러운', '결혼기념일'],
#   'reviewCount': 681,
#   'ktCallMd': '3ad8b129fe4f5012c7a3445bf931051c',
#   'coupon': '0',
#   'thumUrl': 'https://ldb-phinf.pstatic.net/20151209_281/14496316940364DiQP_JPEG/167159525832755_1.jpg',
#   'type': 's',
#   'isSite': '1',
#   'posExact': '1',
#   'x': '126.9269606',
#   'y': '37.5252463',
#   'itemLevel': '8',
#   'isAdultBusiness': False,
#   'streetPanorama': {'id': '1RMtgqDVvkStROm4yUcr6w==',
#    'pan': '-52.53',
#    'tilt': '10.00',
#    'lng': '126.9271733',
#    'lat': '37.5250831',
#    'fov': '120'},
#   'skyPanorama': {'id': 'J+LoR5zLzqhkEe/oRZsyBg==',
#    'pan': '139.32',
#    'tilt': '-30.00',
#    'lng': '126.9262314',
#    'lat': '37.5260925',
#    'fov': '124'},
#   'insidePanorama': None,
#   'interiorPanorama': None,
#   'indoorPanorama': None,
#   'theme': None,
#   'poiInfo': {'relation': {'poiShapeType': '1',
#     'shapeKey': {'typeName': 'RELA', 'wsid': '1.0', 'shapeID': '33879318'},
#     'boundary': {'minX': '117.9926027',
#      'minY': '19.6944771',
#      'maxX': '117.9926027',
#      'maxY': '19.6944771'},
#     'detail': [{'type': '5',
#       'sid': '37704911',
#       'fullName': '콘래드 서울 호텔입구',
#       'name': '콘래드 서울 호텔입구',
#       'category': '입구(사람)',
#       'xPos': '126.9266963',
#       'yPos': '37.5257913'},
#      {'type': '1',
#       'sid': '31059272',
#       'fullName': '콘래드서울호텔입구',
#       'name': '콘래드서울호텔입구',
#       'category': '입구(사람+차량)',
#       'xPos': '126.9269093',
#       'yPos': '37.5250788'}]},
#    'hasRelation': True,
#    'road': {'poiShapeType': '1',
#     'shapeKey': None,
#     'boundary': None,
#     'detail': None},
#    'hasRoad': False,
#    'land': None,
#    'hasLand': False,
#    'polygon': None,
#    'hasPolygon': False},
#   'homePage': 'http://www.conradseoul.co.kr/food/#zest',
#   'description': '',
#   'entranceCoords': {'car': [{'rep': True, 'x': 126.9269093, 'y': 37.5250788}],
#    'walk': [{'rep': True, 'x': 126.9266963, 'y': 37.5257913}]},
#   'isPollingPlace': False,
#   'bizhourInfo': '매일 06:30~10:30 | 매일 11:30~14:30 | 평일 18:00~21:30 | 토요일 17:30~22:00 2부제 운영 (1부 17:30 ~ 19:30, 2부 20:00 ~ 22:00) | 일요일 18:00~21:30',
#   'menuInfo': '성인 아침 (평일, 주말) 50,000 | 성인 평일 점심 85,000 | 어린이 평일 점심 42,500 | 성인 평일 저녁 100,000 | 어린이 평일 저녁 50,000 | 성인 주말 점심 100,000 | 어린이 주말 점심 50,000 | 성인 주말 저녁 110,000 | 어린이 주말 저녁 55,000',
#   'petrolInfo': None,
#   'couponUrl': None,
#   'couponUrlMobile': None,
#   'hasCardBenefit': False,
#   'menuExist': '1',
#   'hasNaverBooking': True,
#   'naverBookingUrl': 'http://booking.naver.com/booking/6/bizes/93652',
#   'naverEasyOrderUrl': None,
#   'hasNaverSmartOrder': False,
#   'reservationLabel': {'standard': True,
#    'preOrder': False,
#    'table': False,
#    'takeout': False},
#   'reservation': None,
#   'hasBroadcastInfo': True,
#   'broadcastInfo': {'name': '2014테이스티로드', 'menu': '뷔페'},
#   'shopWindowInfo': None,
#   'hasNPay': True,
#   'carWash': '',
#   'parkingPrice': '-1',
#   'card': '',
#   'distance': '18681.28',
#   'marker': 'nres://marker/00063-00122',
#   'markerSelected': 'nres://marker/00063-00276',
#   'microReview': ['여의도 콘래드 호텔의 분위기 좋은 뷔페',
#    '여의도 맛있는뷔페',
#    '여의도 고급스러운 호텔뷔페',
#    '특별한 날 가기 좋은 콘래드 뷔페',
#    '다국적 요리를 즐길 수 있는 뷔페 레스토랑'],
#   'michelinGuide': None,
#   'indoor': None,
#   'markerLabel': None,
#   'subway': None,
#   'evChargerInfo': {'summary': {'quickEvCharger': {'chargingSpeed': '급속',
#      'availability': '',
#      'names': ''},
#     'slowEvCharger': {'chargingSpeed': '완속', 'availability': '', 'names': ''}},
#    'evChargerList': []}},
#  {'index': '5',
#   'rank': '6',
#   'id': '1343621328',
#   'name': '함루 여의도점',
#   'tel': '02-2070-2030',
#   'isCallLink': False,
#   'virtualTel': '',
#   'ppc': '1',
#   'category': ['일식', '일식당'],
#   'categoryPath': [['220036', '220038', '220081', '220804'],
#    ['222606', '222607', '1004380', '1002043']],
#   'address': '서울특별시 영등포구 여의도동 23-8',
#   'roadAddress': '서울특별시 영등포구 국제금융로2길 32 파이낸스타워 3층 302호',
#   'abbrAddress': '여의도동 23-8',
#   'shortAddress': ['서울 영등포구', '국제금융로2길 32', '파이낸스타워 3층 302호'],
#   'display': '함루 여의도점',
#   'telDisplay': '02-2070-2030',
#   'context': [],
#   'reviewCount': 12,
#   'ktCallMd': '8131dba515376763cd0c58a47e7d772a',
#   'coupon': '0',
#   'thumUrl': 'https://ldb-phinf.pstatic.net/20201021_197/16032915817234Gnpm_JPEG/1rvFsmoI8pM-N0lMJSGPS3_L.jpg',
#   'type': 's',
#   'isSite': '1',
#   'posExact': '1',
#   'x': '126.9241380',
#   'y': '37.5238818',
#   'itemLevel': '8',
#   'isAdultBusiness': False,
#   'streetPanorama': {'id': 'Su7tpzAHQFC3bC+pjWeEog==',
#    'pan': '-45.62',
#    'tilt': '10.00',
#    'lng': '126.9245621',
#    'lat': '37.5234665',
#    'fov': '120'},
#   'skyPanorama': {'id': 'gWYp9/93ngHhoLy6UWKQlA==',
#    'pan': '2.62',
#    'tilt': '-30.00',
#    'lng': '126.9240875',
#    'lat': '37.5227776',
#    'fov': '124'},
#   'insidePanorama': None,
#   'interiorPanorama': None,
#   'indoorPanorama': None,
#   'theme': None,
#   'poiInfo': {'relation': None,
#    'hasRelation': False,
#    'road': {'poiShapeType': '1',
#     'shapeKey': None,
#     'boundary': None,
#     'detail': None},
#    'hasRoad': False,
#    'land': None,
#    'hasLand': False,
#    'polygon': None,
#    'hasPolygon': False},
#   'homePage': '',
#   'description': '',
#   'entranceCoords': {'car': [{'rep': True, 'x': 126.9244334, 'y': 37.523588}],
#    'walk': [{'rep': True, 'x': 126.9244334, 'y': 37.523588}]},
#   'isPollingPlace': False,
#   'bizhourInfo': '평일 11:00~21:30 일요일휴무',
#   'menuInfo': '히츠마부시 보통 1마리 37,000 | 히츠마부시 특 1.5마리 46,000 | 한우 큐브스테이크 35,000 | 장어 계란말이 15,000 | 우나동 37,000',
#   'petrolInfo': None,
#   'couponUrl': None,
#   'couponUrlMobile': None,
#   'hasCardBenefit': False,
#   'menuExist': '1',
#   'hasNaverBooking': False,
#   'naverBookingUrl': '',
#   'naverEasyOrderUrl': None,
#   'hasNaverSmartOrder': False,
#   'reservationLabel': {'standard': False,
#    'preOrder': False,
#    'table': False,
#    'takeout': False},
#   'reservation': {'benefit': ''},
#   'hasBroadcastInfo': False,
#   'broadcastInfo': None,
#   'shopWindowInfo': None,
#   'hasNPay': False,
#   'carWash': '',
#   'parkingPrice': '-1',
#   'card': '',
#   'distance': '18418.77',
#   'marker': 'nres://marker/00064-00122',
#   'markerSelected': 'nres://marker/00064-00276',
#   'microReview': [],
#   'michelinGuide': None,
#   'indoor': None,
#   'markerLabel': None,
#   'subway': None,
#   'evChargerInfo': {'summary': {'quickEvCharger': {'chargingSpeed': '급속',
#      'availability': '',
#      'names': ''},
#     'slowEvCharger': {'chargingSpeed': '완속', 'availability': '', 'names': ''}},
#    'evChargerList': []}},
#  {'index': '6',
#   'rank': '7',
#   'id': '1978405203',
#   'name': '오복수산참치',
#   'tel': '02-783-9988',
#   'isCallLink': False,
#   'virtualTel': '0507-1485-9989',
#   'ppc': '1',
#   'category': ['한식', '생선회'],
#   'categoryPath': [['220036', '220037', '220076', '220792', '221630'],
#    ['222606', '222607', '1004452']],
#   'address': '서울특별시 영등포구 여의도동 23-6',
#   'roadAddress': '서울특별시 영등포구 의사당대로 83 오투타워 2층',
#   'abbrAddress': '여의도동 23-6',
#   'shortAddress': ['서울 영등포구', '의사당대로 83', '오투타워 2층'],
#   'display': '오복수산참치',
#   'telDisplay': '02-783-9988',
#   'context': [],
#   'reviewCount': 250,
#   'ktCallMd': 'd1bda44b32c651c29d166ee2c5600ab6',
#   'coupon': '0',
#   'thumUrl': 'https://ldb-phinf.pstatic.net/20200713_157/1594645335223g3Brh_JPEG/X3kpsL_v2PrgvgLUIaCqsxUx.jpeg.jpg',
#   'type': 's',
#   'isSite': '1',
#   'posExact': '1',
#   'x': '126.9234407',
#   'y': '37.5233663',
#   'itemLevel': '8',
#   'isAdultBusiness': False,
#   'streetPanorama': {'id': 'QsOO32nGpUYxxopzoldxtw==',
#    'pan': '62.81',
#    'tilt': '10.00',
#    'lng': '126.9230272',
#    'lat': '37.5231536',
#    'fov': '120'},
#   'skyPanorama': {'id': 'z/54yLPQ81dFNkSevgVPDg==',
#    'pan': '42.32',
#    'tilt': '-30.00',
#    'lng': '126.9229050',
#    'lat': '37.5227776',
#    'fov': '124'},
#   'insidePanorama': None,
#   'interiorPanorama': None,
#   'indoorPanorama': None,
#   'theme': None,
#   'poiInfo': {'relation': None,
#    'hasRelation': False,
#    'road': {'poiShapeType': '1',
#     'shapeKey': None,
#     'boundary': None,
#     'detail': None},
#    'hasRoad': False,
#    'land': None,
#    'hasLand': False,
#    'polygon': None,
#    'hasPolygon': False},
#   'homePage': '',
#   'description': '',
#   'entranceCoords': {'car': [{'rep': True, 'x': 126.923842, 'y': 37.52319}],
#    'walk': [{'rep': True, 'x': 126.923842, 'y': 37.52319}]},
#   'isPollingPlace': False,
#   'bizhourInfo': '평일 11:00~22:00 준비시간 오후3시~오후5시 라스트 오더 런치  2시30분 디너 8시 | 주말 12:00~22:00 | 공휴일 12:00~22:00',
#   'menuInfo': '생참치사시미 55,000 | 코스요리 55,000 | 카이센동 18,000 | 우니동 38,000 | 우니 이쿠라동 33,000 | 우니 호다테 이쿠라동 30,000 | 우니 도로 이쿠라 에비 호다테동 35,000 | 한국식 회덮밥 13,000',
#   'petrolInfo': None,
#   'couponUrl': None,
#   'couponUrlMobile': None,
#   'hasCardBenefit': False,
#   'menuExist': '1',
#   'hasNaverBooking': False,
#   'naverBookingUrl': '',
#   'naverEasyOrderUrl': None,
#   'hasNaverSmartOrder': False,
#   'reservationLabel': {'standard': False,
#    'preOrder': False,
#    'table': False,
#    'takeout': False},
#   'reservation': {'benefit': ''},
#   'hasBroadcastInfo': False,
#   'broadcastInfo': None,
#   'shopWindowInfo': None,
#   'hasNPay': False,
#   'carWash': '',
#   'parkingPrice': '-1',
#   'card': '',
#   'distance': '18352.26',
#   'marker': 'nres://marker/00064-00122',
#   'markerSelected': 'nres://marker/00064-00276',
#   'microReview': [],
#   'michelinGuide': None,
#   'indoor': None,
#   'markerLabel': None,
#   'subway': None,
#   'evChargerInfo': {'summary': {'quickEvCharger': {'chargingSpeed': '급속',
#      'availability': '',
#      'names': ''},
#     'slowEvCharger': {'chargingSpeed': '완속', 'availability': '', 'names': ''}},
#    'evChargerList': []}},
#  {'index': '7',
#   'rank': '8',
#   'id': '11678773',
#   'name': '진주집',
#   'tel': '02-780-6108',
#   'isCallLink': False,
#   'virtualTel': '',
#   'ppc': '1',
#   'category': ['한식', '국수'],
#   'categoryPath': [['220036', '220037', '220062', '220628'],
#    ['222606', '222607', '1004452']],
#   'address': '서울특별시 영등포구 여의도동 36-2',
#   'roadAddress': '서울특별시 영등포구 국제금융로6길 33',
#   'abbrAddress': '여의도동 36-2',
#   'shortAddress': ['서울 영등포구', '국제금융로6길 33'],
#   'display': '진주집',
#   'telDisplay': '02-780-6108',
#   'context': ['닭칼국수', '비빔국수', '콩국수', '심플한', '데이트'],
#   'reviewCount': 2394,
#   'ktCallMd': 'c617d691729ca847e6415e7acb95ae91',
#   'coupon': '0',
#   'thumUrl': 'https://ldb-phinf.pstatic.net/20150817_105/1439805626093qwrM1_JPEG/166767593044276_0.jpg',
#   'type': 's',
#   'isSite': '1',
#   'posExact': '1',
#   'x': '126.9268251',
#   'y': '37.5206924',
#   'itemLevel': '12',
#   'isAdultBusiness': False,
#   'streetPanorama': {'id': 'yG7olVJihzfh9ft/W5ctIg==',
#    'pan': '55.61',
#    'tilt': '10.00',
#    'lng': '126.9266342',
#    'lat': '37.5205616',
#    'fov': '120'},
#   'skyPanorama': {'id': 'Hl8uGMXPQylFNK1teScQhw==',
#    'pan': '173.66',
#    'tilt': '-30.00',
#    'lng': '126.9265900',
#    'lat': '37.5227776',
#    'fov': '124'},
#   'insidePanorama': None,
#   'interiorPanorama': None,
#   'indoorPanorama': None,
#   'theme': None,
#   'poiInfo': {'relation': None,
#    'hasRelation': False,
#    'road': {'poiShapeType': '1',
#     'shapeKey': None,
#     'boundary': None,
#     'detail': None},
#    'hasRoad': False,
#    'land': None,
#    'hasLand': False,
#    'polygon': None,
#    'hasPolygon': False},
#   'homePage': '',
#   'description': '',
#   'entranceCoords': {'car': [{'rep': True, 'x': 126.9270052, 'y': 37.5211441}],
#    'walk': [{'rep': True, 'x': 126.9266366, 'y': 37.5211656}]},
#   'isPollingPlace': False,
#   'bizhourInfo': '평일 10:00~20:00 | 토요일 10:00~19:00 | 일요일 휴무 | 공휴일 휴무',
#   'menuInfo': '냉콩국수 11,000 | 비빔국수 9,000 | 닭칼국수 9,000 | 육개장칼국수 9,000 | 접시만두 9,000',
#   'petrolInfo': None,
#   'couponUrl': None,
#   'couponUrlMobile': None,
#   'hasCardBenefit': False,
#   'menuExist': '1',
#   'hasNaverBooking': False,
#   'naverBookingUrl': 'https://booking.naver.com/booking/6/bizes/143264',
#   'naverEasyOrderUrl': None,
#   'hasNaverSmartOrder': False,
#   'reservationLabel': {'standard': False,
#    'preOrder': False,
#    'table': False,
#    'takeout': False},
#   'reservation': {'benefit': ''},
#   'hasBroadcastInfo': True,
#   'broadcastInfo': {'name': '생방송투데이', 'menu': '콩국수'},
#   'shopWindowInfo': None,
#   'hasNPay': False,
#   'carWash': '',
#   'parkingPrice': '-1',
#   'card': '',
#   'distance': '18625.98',
#   'marker': 'nres://marker/00064-00122',
#   'markerSelected': 'nres://marker/00064-00276',
#   'microReview': ['이영자 맛집리스트에도 올라와있는 콩국수 닭칼국수',
#    '닭칼국수 콩국수가 유명한 이영자 맛집',
#    '여의도 두 번 먹어도 안 질리는 콩국수 만두 맛집',
#    '영자로드에 나온  여의도 콩국수 맛집',
#    '여의도 점심 더울때 더 맛있는 콩국수'],
#   'michelinGuide': None,
#   'indoor': None,
#   'markerLabel': None,
#   'subway': None,
#   'evChargerInfo': {'summary': {'quickEvCharger': {'chargingSpeed': '급속',
#      'availability': '',
#      'names': ''},
#     'slowEvCharger': {'chargingSpeed': '완속', 'availability': '', 'names': ''}},
#    'evChargerList': []}},
#  {'index': '8',
#   'rank': '9',
#   'id': '34033812',
#   'name': '콘래드서울 37그릴앤바',
#   'tel': '02-6137-7110',
#   'isCallLink': False,
#   'virtualTel': '',
#   'ppc': '1',
#   'category': ['음식점', '양식'],
#   'categoryPath': [['220036', '220044', '220126'], ['220036', '231737']],
#   'address': '서울특별시 영등포구 여의도동 23',
#   'roadAddress': '서울특별시 영등포구 국제금융로 10 서울 국제금융 센터',
#   'abbrAddress': '여의도동 23',
#   'shortAddress': ['서울 영등포구', '국제금융로 10', '서울 국제금융 센터'],
#   'display': '콘래드서울 37그릴앤바',
#   'telDisplay': '02-6137-7110',
#   'context': ['와인바', '레스토랑', '브런치뷔페', '고급스러운', '데이트'],
#   'reviewCount': 577,
#   'ktCallMd': '3f47b5740b03b370309dfe5194335e41',
#   'coupon': '0',
#   'thumUrl': 'http://ldb.phinf.naver.net/20151209_205/1449631690758L3hp0_JPEG/167159525828997_8.jpg',
#   'type': 's',
#   'isSite': '1',
#   'posExact': '1',
#   'x': '126.9261959',
#   'y': '37.5255747',
#   'itemLevel': '8',
#   'isAdultBusiness': False,
#   'streetPanorama': {'id': '6pu62l4ccnM+QwAtj4MIdg==',
#    'pan': '-107.94',
#    'tilt': '10.00',
#    'lng': '126.9262650',
#    'lat': '37.5255970',
#    'fov': '120'},
#   'skyPanorama': {'id': 'J+LoR5zLzqhkEe/oRZsyBg==',
#    'pan': '-176.17',
#    'tilt': '-30.00',
#    'lng': '126.9262314',
#    'lat': '37.5260925',
#    'fov': '124'},
#   'insidePanorama': None,
#   'interiorPanorama': None,
#   'indoorPanorama': None,
#   'theme': None,
#   'poiInfo': {'relation': None,
#    'hasRelation': False,
#    'road': {'poiShapeType': '1',
#     'shapeKey': None,
#     'boundary': None,
#     'detail': None},
#    'hasRoad': False,
#    'land': None,
#    'hasLand': False,
#    'polygon': None,
#    'hasPolygon': False},
#   'homePage': 'http://www.conradseoul.co.kr/food/#grill37',
#   'description': '',
#   'entranceCoords': None,
#   'isPollingPlace': False,
#   'bizhourInfo': '매일 11:30~14:30 | 매일 18:00~22:30 | 주말 11:00~14:30 주말브런치',
#   'menuInfo': '테이스팅 메뉴 155,000 | 주말 브런치 79,000 | 모듬 육류구이 140,000 | 포르투칼식 해산물 꼬치구이 130,000',
#   'petrolInfo': None,
#   'couponUrl': None,
#   'couponUrlMobile': None,
#   'hasCardBenefit': False,
#   'menuExist': '1',
#   'hasNaverBooking': True,
#   'naverBookingUrl': 'https://booking.naver.com/booking/6/bizes/182477',
#   'naverEasyOrderUrl': None,
#   'hasNaverSmartOrder': False,
#   'reservationLabel': {'standard': True,
#    'preOrder': False,
#    'table': False,
#    'takeout': False},
#   'reservation': None,
#   'hasBroadcastInfo': False,
#   'broadcastInfo': None,
#   'shopWindowInfo': None,
#   'hasNPay': True,
#   'carWash': '',
#   'parkingPrice': '-1',
#   'card': '',
#   'distance': '18617.79',
#   'marker': 'nres://marker/00063-00122',
#   'markerSelected': 'nres://marker/00063-00276',
#   'microReview': ['전망과 야경이 끝내주는 로맨틱한 호텔 레스토랑',
#    '야경좋은 레스토랑',
#    '크리스마스 이브에 맛있게 즐기는 브런치',
#    '한강이 내려다보이는 37층 전망 좋은 레스토랑',
#    '서울 야경이 멋진 와인바'],
#   'michelinGuide': None,
#   'indoor': None,
#   'markerLabel': None,
#   'subway': None,
#   'evChargerInfo': {'summary': {'quickEvCharger': {'chargingSpeed': '급속',
#      'availability': '',
#      'names': ''},
#     'slowEvCharger': {'chargingSpeed': '완속', 'availability': '', 'names': ''}},
#    'evChargerList': []}},
#  {'index': '9',
#   'rank': '10',
#   'id': '1670537887',
#   'name': '단아',
#   'tel': '02-780-8711',
#   'isCallLink': False,
#   'virtualTel': '0507-1357-8711',
#   'ppc': '1',
#   'category': ['음식점', '한식'],
#   'categoryPath': [['220036', '220037', '220053'],
#    ['222606', '222607', '1004452']],
#   'address': '서울특별시 영등포구 여의도동 44-25',
#   'roadAddress': '서울특별시 영등포구 여의대방로67길 21 정곡빌딩 3층',
#   'abbrAddress': '여의도동 44-25',
#   'shortAddress': ['서울 영등포구', '여의대방로67길 21', '정곡빌딩 3층'],
#   'display': '단아',
#   'telDisplay': '02-780-8711',
#   'context': [],
#   'reviewCount': 37,
#   'ktCallMd': 'df7469f541f04f0ff5bc64aee3e36715',
#   'coupon': '0',
#   'thumUrl': 'https://ldb-phinf.pstatic.net/20200414_222/1586847257310CqrxV_JPEG/%C5%A9%B1%E2%BA%AF%C8%AFKakaoTalk_20200414_094830237_19.jpg',
#   'type': 's',
#   'isSite': '1',
#   'posExact': '1',
#   'x': '126.9294212',
#   'y': '37.5205737',
#   'itemLevel': '8',
#   'isAdultBusiness': False,
#   'streetPanorama': {'id': '6y8jaYiO4v1iwzfY4Ximuw==',
#    'pan': '-119.74',
#    'tilt': '10.00',
#    'lng': '126.9296754',
#    'lat': '37.5207186',
#    'fov': '120'},
#   'skyPanorama': {'id': 'dKNrnffGrsBKgJJ+XCS+3A==',
#    'pan': '-169.13',
#    'tilt': '-30.00',
#    'lng': '126.9298477',
#    'lat': '37.5227776',
#    'fov': '124'},
#   'insidePanorama': None,
#   'interiorPanorama': None,
#   'indoorPanorama': None,
#   'theme': None,
#   'poiInfo': {'relation': None,
#    'hasRelation': False,
#    'road': {'poiShapeType': '1',
#     'shapeKey': None,
#     'boundary': None,
#     'detail': None},
#    'hasRoad': False,
#    'land': None,
#    'hasLand': False,
#    'polygon': None,
#    'hasPolygon': False},
#   'homePage': 'http://dana7808711.modoo.at',
#   'description': '',
#   'entranceCoords': {'car': [{'rep': True, 'x': 126.9295426, 'y': 37.5207395}],
#    'walk': [{'rep': True, 'x': 126.9295426, 'y': 37.5207395}]},
#   'isPollingPlace': False,
#   'bizhourInfo': '금요일 11:30~23:00 공휴일 휴무 | 목요일 11:30~23:00 공휴일 휴무 | 수요일 11:30~23:00 공휴일 휴무 | 화요일 11:30~23:00 공휴일 휴무 | 월요일 11:30~23:00 공휴일 휴무 | 토요일 휴무 공휴일 휴무 | 일요일 휴무 공휴일 휴무',
#   'menuInfo': '[점심] 맑은 민어탕 정식 30,000 | [점심] 연저육 솥밥 세트 25,000 | [점심] 박대 구이 세트 23,000 | [점심] 명란 버섯 솥밥 정식 18,000 | [점심] 전복 해초 솥밥 정식 20,000 | [점심 추가 단품] 제육볶음 추가 15,000 | [점심 추가 단품] 연저육 추가 20,000 | [점심 추가 단품] 제철 숙성회 한 접시 30,000 | [저녁] 2인 한상차림 78,000 | [저녁] 3~4인 한상차림 155,000 | [저녁] 5~6인 한상차림 280,000 | [저녁] 단 아 한 상차림 380,000 | [저녁] 해양 심층수 손두부 13,000 | [저녁] 두부와 김치 18,000 | [저녁] 두부 삼합 35,000 | [저녁] 두부 사합 40,000 | [저녁] 명란 바삭 愛 감자전 28,000 | [저녁] 명란 치즈 愛 감자전 30,000 | [저녁] 돌문어 해물파전 30,000 | [저녁] 전복 김치전 30,000 | [저녁] 갓김치 육전 38,000 | [저녁] 모둠전 40,000 | [저녁] 낙지 볶음 28,000 | [저녁] 해산물 황태 강정 30,000 | [저녁] 산낙지 25,000 | [저녁] 돌문어 한마리 50,000 | [저녁] 해산물 모둠 中 55,000 | [저녁] 해산물 모둠 大 75,000 | [저녁] 모둠 회 中 65,000 | [저녁] 모둠 회 大 85,000 | [저녁] 모둠 생선포 15,000 | [저녁] 추정미 솥밥 8,000 | [저녁] 명란 버섯 솥밥 13,000 | [저녁]  전복 해초 솥밥 15,000 | [저녁] 산낙지 두 마리 전골 40,000 | [저녁] 차돌 해물 얼큰탕 40,000 | [저녁] 맑은 민어 전골 60,000 | [점심] 추정미 솥밥 정식 15,000 | [저녁] 오늘이 회 한 접시 변동가격(업주문의) | [저녁] 1인 모둠회 & 해산물 35,000',
#   'petrolInfo': None,
#   'couponUrl': None,
#   'couponUrlMobile': None,
#   'hasCardBenefit': False,
#   'menuExist': '1',
#   'hasNaverBooking': True,
#   'naverBookingUrl': 'https://booking.naver.com/booking/6/bizes/334627',
#   'naverEasyOrderUrl': None,
#   'hasNaverSmartOrder': False,
#   'reservationLabel': {'standard': True,
#    'preOrder': False,
#    'table': False,
#    'takeout': False},
#   'reservation': {'benefit': ''},
#   'hasBroadcastInfo': False,
#   'broadcastInfo': None,
#   'shopWindowInfo': None,
#   'hasNPay': False,
#   'carWash': '',
#   'parkingPrice': '-1',
#   'card': '',
#   'distance': '18853.61',
#   'marker': 'nres://marker/00064-00122',
#   'markerSelected': 'nres://marker/00064-00276',
#   'microReview': [],
#   'michelinGuide': None,
#   'indoor': None,
#   'markerLabel': None,
#   'subway': None,
#   'evChargerInfo': {'summary': {'quickEvCharger': {'chargingSpeed': '급속',
#      'availability': '',
#      'names': ''},
#     'slowEvCharger': {'chargingSpeed': '완속', 'availability': '', 'names': ''}},
#    'evChargerList': []}},
#  {'index': '10',
#   'rank': '11',
#   'id': '31570129',
#   'name': '본보야지',
#   'tel': '02-782-8889',
#   'isCallLink': False,
#   'virtualTel': '0507-1429-8889',
#   'ppc': '1',
#   'category': ['음식점', '이탈리아음식'],
#   'categoryPath': [['220036', '220044', '220127', '220913'],
#    ['222606', '222607', '1004452']],
#   'address': '서울특별시 영등포구 여의도동 24',
#   'roadAddress': '서울특별시 영등포구 국제금융로2길 7 한주빌딩 2층',
#   'abbrAddress': '여의도동 24',
#   'shortAddress': ['서울 영등포구', '국제금융로2길 7', '한주빌딩 2층'],
#   'display': '본보야지',
#   'telDisplay': '02-782-8889',
#   'context': ['스테이크', '크림파스타', '이탈리안레스토랑', '고급스러운', '데이트'],
#   'reviewCount': 863,
#   'ktCallMd': '5e3b9779f519862cb84de28fbd5bc8a6',
#   'coupon': '0',
#   'thumUrl': 'https://ldb-phinf.pstatic.net/20200324_21/1585039332979XsTjC_JPEG/s8SV4-Mbv4pLPFsjvN73f_zW.jpeg.jpg',
#   'type': 's',
#   'isSite': '1',
#   'posExact': '1',
#   'x': '126.9267148',
#   'y': '37.5245769',
#   'itemLevel': '8',
#   'isAdultBusiness': False,
#   'streetPanorama': {'id': '5znDjxirY9wcdt/vhlYDYQ==',
#    'pan': '140.43',
#    'tilt': '10.00',
#    'lng': '126.9265930',
#    'lat': '37.5247239',
#    'fov': '120'},
#   'skyPanorama': {'id': 'J+LoR5zLzqhkEe/oRZsyBg==',
#    'pan': '162.39',
#    'tilt': '-30.00',
#    'lng': '126.9262314',
#    'lat': '37.5260925',
#    'fov': '124'},
#   'insidePanorama': None,
#   'interiorPanorama': None,
#   'indoorPanorama': None,
#   'theme': None,
#   'poiInfo': {'relation': None,
#    'hasRelation': False,
#    'road': {'poiShapeType': '1',
#     'shapeKey': None,
#     'boundary': None,
#     'detail': None},
#    'hasRoad': False,
#    'land': None,
#    'hasLand': False,
#    'polygon': None,
#    'hasPolygon': False},
#   'homePage': 'http://blog.naver.com/ifcbona8',
#   'description': '',
#   'entranceCoords': {'car': [{'rep': True, 'x': 126.9268136, 'y': 37.5244001}],
#    'walk': [{'rep': True, 'x': 126.9267572, 'y': 37.524741}]},
#   'isPollingPlace': False,
#   'bizhourInfo': '매일 11:30~23:00 (11:30-22:00)코로나로 인해 한시적 단축 운영 / 연중무휴 | 매일 15:00~17:30 브레이크타임',
#   'menuInfo': '에피-깔라마리 19,000 | 에피-망고살사&새우구이 19,000 | 해산물리조또 24,000 | 피자-마르게리따 25,000 | 채끝스테이크 47,000 | 푸아그라&안심스테이크 55,000 | 소갈빗살로제파스타 25,000 | 트러플알리오올리오 22,000 | 아메리카노 5,000 | 타라파카 까베르네쇼비뇽(레드와인) 39,000',
#   'petrolInfo': None,
#   'couponUrl': None,
#   'couponUrlMobile': None,
#   'hasCardBenefit': False,
#   'menuExist': '1',
#   'hasNaverBooking': False,
#   'naverBookingUrl': '',
#   'naverEasyOrderUrl': None,
#   'hasNaverSmartOrder': False,
#   'reservationLabel': {'standard': False,
#    'preOrder': False,
#    'table': False,
#    'takeout': False},
#   'reservation': {'benefit': ''},
#   'hasBroadcastInfo': False,
#   'broadcastInfo': None,
#   'shopWindowInfo': None,
#   'hasNPay': False,
#   'carWash': '',
#   'parkingPrice': '-1',
#   'card': '',
#   'distance': '18652.46',
#   'marker': 'nres://marker/00064-00122',
#   'markerSelected': 'nres://marker/00064-00276',
#   'microReview': ['스테이크와 파스타가 맛있는 분위기 있는 레스토랑',
#    '피자가 맛있는 여의도이탈리안레스토랑',
#    '파스타가 정말 맛있는 이탈리안 레스토랑',
#    'ifc몰 맛집 점심먹기좋은 여의도 파스타',
#    '여의도맛집 보나베띠 ifc점에서 맛있는 스테이크와 리조또'],
#   'michelinGuide': None,
#   'indoor': None,
#   'markerLabel': None,
#   'subway': None,
#   'evChargerInfo': {'summary': {'quickEvCharger': {'chargingSpeed': '급속',
#      'availability': '',
#      'names': ''},
#     'slowEvCharger': {'chargingSpeed': '완속', 'availability': '', 'names': ''}},
#    'evChargerList': []}},
#  {'index': '11',
#   'rank': '12',
#   'id': '1974070800',
#   'name': '진가와 여의도점',
#   'tel': '02-782-9072',
#   'isCallLink': False,
#   'virtualTel': '0507-1311-9072',
#   'ppc': '1',
#   'category': ['일식', '일식당'],
#   'categoryPath': [['220036', '220038', '220081', '1002185'],
#    ['222606', '222607', '1004380', '1002043']],
#   'address': '서울특별시 영등포구 여의도동 25 씨티플라자 3층',
#   'roadAddress': '서울특별시 영등포구 국제금융로2길 17 씨티플라자 3층',
#   'abbrAddress': '여의도동 25 씨티플라자 3층',
#   'shortAddress': ['서울 영등포구', '국제금융로2길 17', '씨티플라자 3층'],
#   'display': '진가와 여의도점',
#   'telDisplay': '02-782-9072',
#   'context': [],
#   'reviewCount': 362,
#   'ktCallMd': '414981fa3770e574f31e8f693d0c810d',
#   'coupon': '0',
#   'thumUrl': 'https://ldb-phinf.pstatic.net/20181102_230/1541151668589eBPvf_JPEG/o-HjhXZdmG5nYEJ0GlVJFvio.jpg',
#   'type': 's',
#   'isSite': '1',
#   'posExact': '1',
#   'x': '126.9260364',
#   'y': '37.5240423',
#   'itemLevel': '12',
#   'isAdultBusiness': False,
#   'streetPanorama': {'id': 'o+OW3qd+SArsLiemIJNUqQ==',
#    'pan': '133.05',
#    'tilt': '10.00',
#    'lng': '126.9258215',
#    'lat': '37.5242427',
#    'fov': '120'},
#   'skyPanorama': {'id': 'Hl8uGMXPQylFNK1teScQhw==',
#    'pan': '-23.65',
#    'tilt': '-30.00',
#    'lng': '126.9265900',
#    'lat': '37.5227776',
#    'fov': '124'},
#   'insidePanorama': None,
#   'interiorPanorama': None,
#   'indoorPanorama': None,
#   'theme': None,
#   'poiInfo': {'relation': None,
#    'hasRelation': False,
#    'road': {'poiShapeType': '1',
#     'shapeKey': None,
#     'boundary': None,
#     'detail': None},
#    'hasRoad': False,
#    'land': None,
#    'hasLand': False,
#    'polygon': None,
#    'hasPolygon': False},
#   'homePage': 'http://www.instagram.com/jinkawa_korea',
#   'description': '',
#   'entranceCoords': {'car': [{'rep': True, 'x': 126.926024, 'y': 37.52425}],
#    'walk': [{'rep': True, 'x': 126.926024, 'y': 37.52425},
#     {'rep': False, 'x': 126.925923, 'y': 37.523881}]},
#   'isPollingPlace': False,
#   'bizhourInfo': '평일 11:00~22:00 브레이크타임 : 14:30~17:30, Last order 21:00 | 주말 11:30~21:00 브레이크타임 : 15:00~17:00,Last order 20:00',
#   'menuInfo': '진가와 가이세키 44,000 | 사시미스시정식 28,000 | 스끼야끼나베 33,000 | 삼미소면 15,000 | 붓카케 우동 12,000 | 냉메밀 정식 18,000 | 스키야끼동정식 20,000 | 사케동정식 17,000 | 진가와 소바마끼 11,000 | 치킨 가라아게 18,000 | 한우채끝 타다끼 25,000 | 사바학고 스시 20,000 | 모듬 스시 22,000 | 모듬 튀김 28,000 | 모듬 사시미 변동가격(업주문의) | 마구로 사시미 48,000',
#   'petrolInfo': None,
#   'couponUrl': None,
#   'couponUrlMobile': None,
#   'hasCardBenefit': False,
#   'menuExist': '1',
#   'hasNaverBooking': False,
#   'naverBookingUrl': '',
#   'naverEasyOrderUrl': None,
#   'hasNaverSmartOrder': False,
#   'reservationLabel': {'standard': False,
#    'preOrder': False,
#    'table': False,
#    'takeout': False},
#   'reservation': {'benefit': ''},
#   'hasBroadcastInfo': False,
#   'broadcastInfo': None,
#   'shopWindowInfo': None,
#   'hasNPay': False,
#   'carWash': '',
#   'parkingPrice': '-1',
#   'card': '',
#   'distance': '18587.26',
#   'marker': 'nres://marker/00064-00122',
#   'markerSelected': 'nres://marker/00064-00276',
#   'microReview': [],
#   'michelinGuide': None,
#   'indoor': None,
#   'markerLabel': None,
#   'subway': None,
#   'evChargerInfo': {'summary': {'quickEvCharger': {'chargingSpeed': '급속',
#      'availability': '',
#      'names': ''},
#     'slowEvCharger': {'chargingSpeed': '완속', 'availability': '', 'names': ''}},
#    'evChargerList': []}},
#  {'index': '12',
#   'rank': '13',
#   'id': '37420412',
#   'name': '사대부집 곳간',
#   'tel': '02-2055-4441',
#   'isCallLink': False,
#   'virtualTel': '',
#   'ppc': '1',
#   'category': ['음식점', '한식'],
#   'categoryPath': [['220036', '220037', '220053']],
#   'address': '서울특별시 영등포구 여의도동 28-1',
#   'roadAddress': '서울특별시 영등포구 여의대로 24 전경련회관 50, 51F',
#   'abbrAddress': '여의도동 28-1',
#   'shortAddress': ['서울 영등포구', '여의대로 24', '전경련회관 50, 51F'],
#   'display': '사대부집 곳간',
#   'telDisplay': '02-2055-4441',
#   'context': ['한식당', '한식뷔페', '이탈리안레스토랑', '고급스러운', '경치'],
#   'reviewCount': 509,
#   'ktCallMd': 'ed891a564456a03874a3dd2034105917',
#   'coupon': '0',
#   'thumUrl': 'https://ldb-phinf.pstatic.net/20180129_79/1517217497087suI72_JPEG/pXPKxMkOBnsCRnJBppNwlwsr.jpg',
#   'type': 's',
#   'isSite': '1',
#   'posExact': '1',
#   'x': '126.9202079',
#   'y': '37.5221961',
#   'itemLevel': '8',
#   'isAdultBusiness': False,
#   'streetPanorama': {'id': '3R2Vk+xX0WwtaerI2C8gKQ==',
#    'pan': '-49.58',
#    'tilt': '10.00',
#    'lng': '126.9206956',
#    'lat': '37.5217804',
#    'fov': '120'},
#   'skyPanorama': {'id': 'pOE0T4Ed249sSaRslvt5AA==',
#    'pan': '-145.01',
#    'tilt': '-30.00',
#    'lng': '126.9206161',
#    'lat': '37.5227776',
#    'fov': '124'},
#   'insidePanorama': None,
#   'interiorPanorama': None,
#   'indoorPanorama': None,
#   'theme': None,
#   'poiInfo': {'relation': None,
#    'hasRelation': False,
#    'road': {'poiShapeType': '1',
#     'shapeKey': None,
#     'boundary': None,
#     'detail': None},
#    'hasRoad': False,
#    'land': None,
#    'hasLand': False,
#    'polygon': None,
#    'hasPolygon': False},
#   'homePage': 'http://www.theskyfarm.co.kr/',
#   'description': '',
#   'entranceCoords': {'car': [{'rep': True, 'x': 126.9207173, 'y': 37.5219423}],
#    'walk': [{'rep': True, 'x': 126.9197117, 'y': 37.5224266}]},
#   'isPollingPlace': False,
#   'bizhourInfo': '평일 11:30~21:30 Break Time 15:00~17:00 | 주말 11:30~21:30 Break Time 15:00~17:00',
#   'menuInfo': '한방오리탕 반상 36,000 | 제주 은갈치구이 반상 34,000 | 주꾸미 연포탕 반상 33,000 | 재첩부빔밥 반상 28,000',
#   'petrolInfo': None,
#   'couponUrl': None,
#   'couponUrlMobile': None,
#   'hasCardBenefit': False,
#   'menuExist': '1',
#   'hasNaverBooking': True,
#   'naverBookingUrl': 'https://booking.naver.com/booking/6/bizes/408108',
#   'naverEasyOrderUrl': None,
#   'hasNaverSmartOrder': False,
#   'reservationLabel': {'standard': True,
#    'preOrder': False,
#    'table': False,
#    'takeout': False},
#   'reservation': {'benefit': ''},
#   'hasBroadcastInfo': True,
#   'broadcastInfo': {'name': '밥블레스유', 'menu': '한식뷔페'},
#   'shopWindowInfo': None,
#   'hasNPay': True,
#   'carWash': '',
#   'parkingPrice': '-1',
#   'card': '',
#   'distance': '18056.71',
#   'marker': 'nres://marker/00064-00122',
#   'markerSelected': 'nres://marker/00064-00276',
#   'microReview': ['여의도 전경련회관 50층 전망좋은 한식 뷔페 맛집',
#    '밥블레스유 팀이 다녀간 여의도 한식뷔페',
#    '서울도심 50층에 있는 전망 좋은 한식뷔페',
#    '가족모임 장소로 추천하는 여의도 사대부집',
#    '여의도 가족모임 하기 좋았던 사대부집'],
#   'michelinGuide': None,
#   'indoor': None,
#   'markerLabel': None,
#   'subway': None,
#   'evChargerInfo': {'summary': {'quickEvCharger': {'chargingSpeed': '급속',
#      'availability': '',
#      'names': ''},
#     'slowEvCharger': {'chargingSpeed': '완속', 'availability': '', 'names': ''}},
#    'evChargerList': []}},
#  {'index': '13',
#   'rank': '14',
#   'id': '38704048',
#   'name': '하얀과자점',
#   'tel': '070-8844-0326',
#   'isCallLink': False,
#   'virtualTel': '0507-1410-0326',
#   'ppc': '1',
#   'category': ['음식점', '카페,디저트'],
#   'categoryPath': [['220036', '220052', '220563'],
#    ['222606', '222607', '1004452']],
#   'address': '서울특별시 영등포구 여의도동 44-21 중앙빌딩 120호',
#   'roadAddress': '서울특별시 영등포구 국제금융로8길 19 중앙빌딩 120호',
#   'abbrAddress': '여의도동 44-21 중앙빌딩 120호',
#   'shortAddress': ['서울 영등포구', '국제금융로8길 19', '중앙빌딩 120호'],
#   'display': '하얀과자점',
#   'telDisplay': '070-8844-0326',
#   'context': ['당근케이크', '디저트', '롤케이크', '타르트', '마카롱'],
#   'reviewCount': 224,
#   'ktCallMd': '521dd2d56a70c3eaffc7b41a39da4488',
#   'coupon': '0',
#   'thumUrl': 'https://ldb-phinf.pstatic.net/20191008_137/15705210703269V5rW_JPEG/eNvcnzkcj93aASI-K4qRByO8.jpg',
#   'type': 's',
#   'isSite': '1',
#   'posExact': '1',
#   'x': '126.9292542',
#   'y': '37.5208376',
#   'itemLevel': '8',
#   'isAdultBusiness': False,
#   'streetPanorama': {'id': 'z9KKA33n04siq1R3H/vONg==',
#    'pan': '-118.67',
#    'tilt': '10.00',
#    'lng': '126.9294546',
#    'lat': '37.5209469',
#    'fov': '120'},
#   'skyPanorama': {'id': 'LL6AvTiXHryvPt9WzQXPZQ==',
#    'pan': '167.19',
#    'tilt': '-30.00',
#    'lng': '126.9288101',
#    'lat': '37.5227776',
#    'fov': '124'},
#   'insidePanorama': None,
#   'interiorPanorama': None,
#   'indoorPanorama': None,
#   'theme': None,
#   'poiInfo': {'relation': None,
#    'hasRelation': False,
#    'road': {'poiShapeType': '1',
#     'shapeKey': None,
#     'boundary': None,
#     'detail': None},
#    'hasRoad': False,
#    'land': None,
#    'hasLand': False,
#    'polygon': None,
#    'hasPolygon': False},
#   'homePage': 'http://www.instagram.com/hayan_dessert',
#   'description': '',
#   'entranceCoords': {'car': [{'rep': True, 'x': 126.9294768, 'y': 37.5208398}],
#    'walk': [{'rep': True, 'x': 126.9290719, 'y': 37.5208733},
#     {'rep': False, 'x': 126.928904, 'y': 37.520602}]},
#   'isPollingPlace': False,
#   'bizhourInfo': '평일 10:00~21:00 | 토요일 10:00~18:00 | 공휴일 10:00~18:00 | 일요일 휴무',
#   'menuInfo': '감자케익 6,500 | 까페오레 4,000 | 아인슈페너 4,500 | 리얼쇼콜라떼 4,800 | 수제젤라또(요거트/바닐라) 4,500 | 수제살구소다 5,500 | 침깨쿠키 700 | 검은깨쿠키 700 | 모카쿠키 800 | 라이스크런치쿠키 800 | 오트밀피칸쿠키 1,000 | 후르츠마끼쿠키 1,000 | 쿠키 선물세트 22,000~45,000 | 플레인스콘 3,600 | 애플루바브스콘 4,800 | 생딸기스콘 4,800 | 앙버터 스콘 5,800 | 까눌레 소 2,800 | 까눌레 대 3,500 | 당근케익 5,000 | 리얼브라우니 5,000 | 초코마쉬멜로유 3,000',
#   'petrolInfo': None,
#   'couponUrl': None,
#   'couponUrlMobile': None,
#   'hasCardBenefit': False,
#   'menuExist': '1',
#   'hasNaverBooking': False,
#   'naverBookingUrl': '',
#   'naverEasyOrderUrl': None,
#   'hasNaverSmartOrder': False,
#   'reservationLabel': {'standard': False,
#    'preOrder': False,
#    'table': False,
#    'takeout': False},
#   'reservation': {'benefit': ''},
#   'hasBroadcastInfo': False,
#   'broadcastInfo': None,
#   'shopWindowInfo': None,
#   'hasNPay': True,
#   'carWash': '',
#   'parkingPrice': '-1',
#   'card': '',
#   'distance': '18841.00',
#   'marker': 'nres://marker/00064-00038',
#   'markerSelected': 'nres://marker/00064-00191',
#   'microReview': [],
#   'michelinGuide': None,
#   'indoor': None,
#   'markerLabel': None,
#   'subway': None,
#   'evChargerInfo': {'summary': {'quickEvCharger': {'chargingSpeed': '급속',
#      'availability': '',
#      'names': ''},
#     'slowEvCharger': {'chargingSpeed': '완속', 'availability': '', 'names': ''}},
#    'evChargerList': []}},
#  {'index': '14',
#   'rank': '15',
#   'id': '1451225823',
#   'name': '스시젠',
#   'tel': '02-784-7789',
#   'isCallLink': False,
#   'virtualTel': '0507-1425-7806',
#   'ppc': '1',
#   'category': ['일식', '일식당'],
#   'categoryPath': [['220036', '220038', '220081', '220804'],
#    ['222606', '222607', '1004452']],
#   'address': '서울특별시 영등포구 여의도동 36',
#   'roadAddress': '서울특별시 영등포구 의사당대로 127 지하 11호',
#   'abbrAddress': '여의도동 36',
#   'shortAddress': ['서울 영등포구', '의사당대로 127', '지하 11호'],
#   'display': '스시젠',
#   'telDisplay': '02-784-7789',
#   'context': [],
#   'reviewCount': 49,
#   'ktCallMd': '395942c0504df59ed0767b07458f62f7',
#   'coupon': '0',
#   'thumUrl': 'https://ldb-phinf.pstatic.net/20200524_166/1590298917062rNWOp_JPEG/KakaoTalk_20200524_142859762_05.jpg',
#   'type': 's',
#   'isSite': '1',
#   'posExact': '1',
#   'x': '126.9265677',
#   'y': '37.5204236',
#   'itemLevel': '8',
#   'isAdultBusiness': False,
#   'streetPanorama': {'id': 'pGKucRNgMyV1S+WwkH4BHA==',
#    'pan': '-114.07',
#    'tilt': '10.00',
#    'lng': '126.9267089',
#    'lat': '37.5204865',
#    'fov': '120'},
#   'skyPanorama': {'id': 'xMTuzP2BOcPQAchf5vqeHQ==',
#    'pan': '63.20',
#    'tilt': '-30.00',
#    'lng': '126.9240799',
#    'lat': '37.5191650',
#    'fov': '124'},
#   'insidePanorama': None,
#   'interiorPanorama': None,
#   'indoorPanorama': None,
#   'theme': None,
#   'poiInfo': {'relation': None,
#    'hasRelation': False,
#    'road': {'poiShapeType': '1',
#     'shapeKey': None,
#     'boundary': None,
#     'detail': None},
#    'hasRoad': False,
#    'land': None,
#    'hasLand': False,
#    'polygon': None,
#    'hasPolygon': False},
#   'homePage': 'http://www.instagram.com/jdg0114korea',
#   'description': '',
#   'entranceCoords': None,
#   'isPollingPlace': False,
# ...
#      'availability': '',
#      'names': ''},
#     'slowEvCharger': {'chargingSpeed': '완속', 'availability': '', 'names': ''}},
#    'evChargerList': []}},
#  {'index': '15',
#   'rank': '16',
#   'id': '1720342718',
#   'name': '도쿄등심 여의도점',
#   'tel': '02-782-2260',
#   'isCallLink': False,
#   'virtualTel': '0507-1312-2260',
#   'ppc': '1',
#   'category': ['육류,고기요리', '소고기구이'],
#   'categoryPath': [['220036', '220037', '220075', '220764', '1002399'],
#    ['222606', '222607', '1004452']],
#   'address': '서울특별시 영등포구 여의도동 35-3',
#   'roadAddress': '서울특별시 영등포구 여의나루로 50 한국교직원공제회관 지하1층 9호',
#   'abbrAddress': '여의도동 35-3',
#   'shortAddress': ['서울 영등포구', '여의나루로 50', '한국교직원공제회관 지하1층 9호'],
#   'display': '도쿄등심 여의도점',
#   'telDisplay': '02-782-2260',
#   'context': [],
#   'reviewCount': 1144,
#   'ktCallMd': '4f36736031ac201376b5a93d9b682e79',
#   'coupon': '0',
#   'thumUrl': 'https://ldb-phinf.pstatic.net/20200901_251/1598945354483I0znI_JPEG/%BF%A9%C0%C7%B5%B5%C1%A1%B4%EB%C7%A5%BB%E7%C1%F8.jpg',
#   'type': 's',
#   'isSite': '1',
#   'posExact': '1',
#   'x': '126.9256512',
#   'y': '37.5218052',
#   'itemLevel': '8',
#   'isAdultBusiness': False,
#   'streetPanorama': {'id': '29e+QBK5eLe4pJ+oDv83ug==',
#    'pan': '133.87',
#    'tilt': '10.00',
#    'lng': '126.9251685',
#    'lat': '37.5222681',
#    'fov': '120'},
#   'skyPanorama': {'id': 'qDBSTxwmtQw17Cu92NL0aQ==',
#    'pan': '151.66',
#    'tilt': '-30.00',
#    'lng': '126.9251251',
#    'lat': '37.5227776',
#    'fov': '124'},
#   'insidePanorama': None,
#   'interiorPanorama': None,
#   'indoorPanorama': None,
#   'theme': None,
#   'poiInfo': {'relation': None,
#    'hasRelation': False,
#    'road': {'poiShapeType': '1',
#     'shapeKey': None,
#     'boundary': None,
#     'detail': None},
#    'hasRoad': False,
#    'land': None,
#    'hasLand': False,
#    'polygon': None,
#    'hasPolygon': False},
#   'homePage': 'https://openyeouido.modoo.at',
#   'description': '',
#   'entranceCoords': {'car': [{'rep': True, 'x': 126.925668, 'y': 37.522278}],
#    'walk': [{'rep': True, 'x': 126.925668, 'y': 37.522278}]},
#   'isPollingPlace': False,
#   'bizhourInfo': '평일 11:00~23:00 월~금 영업시간 / 라스트 오더 21:30 | 주말 12:00~23:00 토,일 영업시간 / 라스트 오더 21:30 | 평일 15:00~17:00 월~금 브레이크타임 | 주말 16:00~17:00 토,일 브레이크타임',
#   'menuInfo': '런치 스페셜 A 29,000 | 도쿄 스페셜 A 69,000 | 워터에이징 한우 등심 49,500 | 워터에이징 한우 안심 49,500 | 콜키지프리 1',
#   'petrolInfo': None,
#   'couponUrl': None,
#   'couponUrlMobile': None,
#   'hasCardBenefit': False,
#   'menuExist': '1',
#   'hasNaverBooking': True,
#   'naverBookingUrl': 'https://booking.naver.com/booking/6/bizes/164459',
#   'naverEasyOrderUrl': None,
#   'hasNaverSmartOrder': False,
#   'reservationLabel': {'standard': True,
#    'preOrder': False,
#    'table': False,
#    'takeout': False},
#   'reservation': {'benefit': ''},
#   'hasBroadcastInfo': False,
#   'broadcastInfo': None,
#   'shopWindowInfo': None,
#   'hasNPay': False,
#   'carWash': '',
#   'parkingPrice': '-1',
#   'card': '',
#   'distance': '18532.03',
#   'marker': 'nres://marker/00064-00122',
#   'markerSelected': 'nres://marker/00064-00276',
#   'microReview': ['가족 여의도 데이트 맛있는 소고기 도쿄등심',
#    '여의도 데이트 모임장소로 추천하는 도쿄등심 한우',
#    '여의도회식 여직원 취향저격 장소 원한다면 도쿄등심',
#    '한우오마카세맛있는집 도쿄등심',
#    '도쿄등심 여의도 파란색 색감 독특한 ifc몰 맛집'],
#   'michelinGuide': None,
#   'indoor': None,
#   'markerLabel': None,
#   'subway': None,
#   'evChargerInfo': {'summary': {'quickEvCharger': {'chargingSpeed': '급속',
#      'availability': '',
#      'names': ''},
#     'slowEvCharger': {'chargingSpeed': '완속', 'availability': '', 'names': ''}},
#    'evChargerList': []}},
#  {'index': '16',
#   'rank': '17',
#   'id': '1732363102',
#   'name': '히노노리',
#   'tel': '02-6747-0773',
#   'isCallLink': False,
#   'virtualTel': '0507-1367-0773',
#   'ppc': '1',
#   'category': ['일식', '일식당'],
#   'categoryPath': [['220036', '220038', '220081', '220804']],
#   'address': '서울특별시 영등포구 여의도동 23-6',
#   'roadAddress': '서울특별시 영등포구 의사당대로 83 103호',
#   'abbrAddress': '여의도동 23-6',
#   'shortAddress': ['서울 영등포구', '의사당대로 83', '103호'],
#   'display': '히노노리',
#   'telDisplay': '02-6747-0773',
#   'context': [],
#   'reviewCount': 20,
#   'ktCallMd': '4c72bc8353941399d548a0f5cd89846b',
#   'coupon': '0',
#   'thumUrl': 'https://ldb-phinf.pstatic.net/20200914_4/1600073240625oPq0M_JPEG/Asu2uLWSkQXc137Hr8I2otS0.jpg',
#   'type': 's',
#   'isSite': '1',
#   'posExact': '1',
#   'x': '126.9236298',
#   'y': '37.5232307',
#   'itemLevel': '12',
#   'isAdultBusiness': False,
#   'streetPanorama': {'id': '6Ew5lv3Pm3rv/+OxgZVBHw==',
#    'pan': '-54.48',
#    'tilt': '10.00',
#    'lng': '126.9238824',
#    'lat': '37.5230502',
#    'fov': '120'},
#   'skyPanorama': {'id': 'gWYp9/93ngHhoLy6UWKQlA==',
#    'pan': '-45.31',
#    'tilt': '-30.00',
#    'lng': '126.9240875',
#    'lat': '37.5227776',
#    'fov': '124'},
#   'insidePanorama': None,
#   'interiorPanorama': None,
#   'indoorPanorama': None,
#   'theme': None,
#   'poiInfo': {'relation': None,
#    'hasRelation': False,
#    'road': {'poiShapeType': '1',
#     'shapeKey': None,
#     'boundary': None,
#     'detail': None},
#    'hasRoad': False,
#    'land': None,
#    'hasLand': False,
#    'polygon': None,
#    'hasPolygon': False},
#   'homePage': 'http://www.instagram.com/hino.nori/',
#   'description': '',
#   'entranceCoords': {'car': [{'rep': True, 'x': 126.923842, 'y': 37.52319}],
#    'walk': [{'rep': True, 'x': 126.923842, 'y': 37.52319}]},
#   'isPollingPlace': False,
#   'bizhourInfo': '매일 11:00~22:00 Break Time 15시~17시 / Lunch Last order 14:30',
#   'menuInfo': '히노세트 16,000 | 노리세트 22,000 | 새우튀김 4,200',
#   'petrolInfo': None,
#   'couponUrl': None,
#   'couponUrlMobile': None,
#   'hasCardBenefit': False,
#   'menuExist': '1',
#   'hasNaverBooking': False,
#   'naverBookingUrl': '',
#   'naverEasyOrderUrl': None,
#   'hasNaverSmartOrder': False,
#   'reservationLabel': {'standard': False,
#    'preOrder': False,
#    'table': False,
#    'takeout': False},
#   'reservation': {'benefit': ''},
#   'hasBroadcastInfo': False,
#   'broadcastInfo': None,
#   'shopWindowInfo': None,
#   'hasNPay': False,
#   'carWash': '',
#   'parkingPrice': '-1',
#   'card': '',
#   'distance': '18367.54',
#   'marker': 'nres://marker/00064-00122',
#   'markerSelected': 'nres://marker/00064-00276',
#   'microReview': [],
#   'michelinGuide': None,
#   'indoor': None,
#   'markerLabel': None,
#   'subway': None,
#   'evChargerInfo': {'summary': {'quickEvCharger': {'chargingSpeed': '급속',
#      'availability': '',
#      'names': ''},
#     'slowEvCharger': {'chargingSpeed': '완속', 'availability': '', 'names': ''}},
#    'evChargerList': []}},
#  {'index': '17',
#   'rank': '18',
#   'id': '21052525',
#   'name': '폴앤폴리나 여의도점',
#   'tel': '02-761-1966',
#   'isCallLink': False,
#   'virtualTel': '',
#   'ppc': '1',
#   'category': ['카페,디저트', '베이커리'],
#   'categoryPath': [['220036', '220052', '220564', '221161'],
#    ['222606', '222607', '1004452']],
#   'address': '서울특별시 영등포구 여의도동 37 아일렉스빌딩 1층',
#   'roadAddress': '서울특별시 영등포구 의사당대로 108 아일렉스 상가',
#   'abbrAddress': '여의도동 37 아일렉스빌딩 1층',
#   'shortAddress': ['서울 영등포구', '의사당대로 108', '아일렉스 상가'],
#   'display': '폴앤폴리나 여의도점',
#   'telDisplay': '02-761-1966',
#   'context': ['스콘', '프레즐', '식빵', '화려한', '나들이'],
#   'reviewCount': 293,
#   'ktCallMd': '9e8456bae90e4b7e6385528b557300d9',
#   'coupon': '0',
#   'thumUrl': 'https://ldb-phinf.pstatic.net/20200703_259/1593780644263MJ5Fk_JPEG/gLccoHjYW30bbusRysoj93z8.jpg',
#   'type': 's',
#   'isSite': '1',
#   'posExact': '1',
#   'x': '126.9238941',
#   'y': '37.5210045',
#   'itemLevel': '12',
#   'isAdultBusiness': False,
#   'streetPanorama': {'id': 'EnJKesXoiXr5drp6DUPvvA==',
#    'pan': '-106.83',
#    'tilt': '10.00',
#    'lng': '126.9243896',
#    'lat': '37.5211539',
#    'fov': '120'},
#   'skyPanorama': {'id': 'gWYp9/93ngHhoLy6UWKQlA==',
#    'pan': '-173.86',
#    'tilt': '-30.00',
#    'lng': '126.9240875',
#    'lat': '37.5227776',
#    'fov': '124'},
#   'insidePanorama': None,
#   'interiorPanorama': None,
#   'indoorPanorama': None,
#   'theme': None,
#   'poiInfo': {'relation': None,
#    'hasRelation': False,
#    'road': {'poiShapeType': '1',
#     'shapeKey': None,
#     'boundary': None,
#     'detail': None},
#    'hasRoad': False,
#    'land': None,
#    'hasLand': False,
#    'polygon': None,
#    'hasPolygon': False},
#   'homePage': '',
#   'description': '',
#   'entranceCoords': {'car': None,
#    'walk': [{'rep': True, 'x': 126.9243188, 'y': 37.5212061}]},
#   'isPollingPlace': False,
#   'bizhourInfo': '평일 12:00~19:00 | 일요일 휴무 12월25일, 구정연휴, 추석 | 토요일 11:00~18:00',
#   'menuInfo': '블랙올리브 3,600 | 허브빵 1,700 | 치아바타 3,100 | 화이트 치아바타 2,800',
#   'petrolInfo': None,
#   'couponUrl': None,
#   'couponUrlMobile': None,
#   'hasCardBenefit': False,
#   'menuExist': '1',
#   'hasNaverBooking': False,
#   'naverBookingUrl': '',
#   'naverEasyOrderUrl': None,
#   'hasNaverSmartOrder': False,
#   'reservationLabel': {'standard': False,
#    'preOrder': False,
#    'table': False,
#    'takeout': False},
#   'reservation': {'benefit': ''},
#   'hasBroadcastInfo': False,
#   'broadcastInfo': None,
#   'shopWindowInfo': None,
#   'hasNPay': False,
#   'carWash': '',
#   'parkingPrice': '-1',
#   'card': '',
#   'distance': '18370.52',
#   'marker': 'nres://marker/00064-00013',
#   'markerSelected': 'nres://marker/00064-00166',
#   'microReview': ['제대로 된 깜빠뉴를 내는 여의도 대표 빵집',
#    '수요미식회로 유명한 폴앤폴리나 빵집',
#    '여의도 유명한 빵집',
#    '여의도에서 만난 빵집',
#    '기본에 충실한 빵집'],
#   'michelinGuide': None,
#   'indoor': None,
#   'markerLabel': None,
#   'subway': None,
#   'evChargerInfo': {'summary': {'quickEvCharger': {'chargingSpeed': '급속',
#      'availability': '',
#      'names': ''},
#     'slowEvCharger': {'chargingSpeed': '완속', 'availability': '', 'names': ''}},
#    'evChargerList': []}},
#  {'index': '18',
#   'rank': '19',
#   'id': '1603372541',
#   'name': '패트릭스와플',
#   'tel': '02-782-8896',
#   'isCallLink': False,
#   'virtualTel': '',
#   'ppc': '1',
#   'category': ['카페,디저트', '와플'],
#   'categoryPath': [['220036', '220052', '220567', '221188'],
#    ['222606', '222607', '1004452']],
#   'address': '서울특별시 영등포구 여의도동 37 아일렉스 지하1층 B06호',
#   'roadAddress': '서울특별시 영등포구 의사당대로 108 아일렉스 지하1층 비06호',
#   'abbrAddress': '여의도동 37 아일렉스 지하1층 B06호',
#   'shortAddress': ['서울 영등포구', '의사당대로 108', '아일렉스 지하1층 비06호'],
#   'display': '패트릭스와플',
#   'telDisplay': '02-782-8896',
#   'context': [],
#   'reviewCount': 83,
#   'ktCallMd': '5aaecbb25fef88a67753c23004f191c3',
#   'coupon': '0',
#   'thumUrl': 'https://ldb-phinf.pstatic.net/20190226_15/1551163260681kUbX5_JPEG/wJMX53DgIED1Fuxg7wXwl3kA.jpeg.jpg',
#   'type': 's',
#   'isSite': '1',
#   'posExact': '1',
#   'x': '126.9238388',
#   'y': '37.5210051',
#   'itemLevel': '12',
#   'isAdultBusiness': False,
#   'streetPanorama': {'id': 'O+vx1pahNOon1DFNlC0bkw==',
#    'pan': '126.60',
#    'tilt': '10.00',
#    'lng': '126.9235554',
#    'lat': '37.5212151',
#    'fov': '120'},
#   'skyPanorama': {'id': 'gWYp9/93ngHhoLy6UWKQlA==',
#    'pan': '-172.10',
#    'tilt': '-30.00',
#    'lng': '126.9240875',
#    'lat': '37.5227776',
#    'fov': '124'},
#   'insidePanorama': None,
#   'interiorPanorama': None,
#   'indoorPanorama': None,
#   'theme': None,
#   'poiInfo': {'relation': None,
#    'hasRelation': False,
#    'road': {'poiShapeType': '1',
#     'shapeKey': None,
#     'boundary': None,
#     'detail': None},
#    'hasRoad': False,
#    'land': None,
#    'hasLand': False,
#    'polygon': None,
#    'hasPolygon': False},
#   'homePage': 'https://www.instagram.com/patrickswaffle02',
#   'description': '',
#   'entranceCoords': {'car': None,
#    'walk': [{'rep': True, 'x': 126.9243188, 'y': 37.5212061}]},
#   'isPollingPlace': False,
#   'bizhourInfo': '일요일 11:00~19:30 Last Order 19:00 / 토요일 휴무 | 평일 11:00~19:30 Last Order 19:00 / 토요일 휴무',
#   'menuInfo': '오리지널 와플 2,600 | 말차 와플 3,300 | 코코넛 와플 3,300 | 아메리카노(Hot/Ice) 2,900 | 라떼(Hot/Ice) 3,800',
#   'petrolInfo': None,
#   'couponUrl': None,
#   'couponUrlMobile': None,
#   'hasCardBenefit': False,
#   'menuExist': '1',
#   'hasNaverBooking': False,
#   'naverBookingUrl': '',
#   'naverEasyOrderUrl': None,
#   'hasNaverSmartOrder': False,
#   'reservationLabel': {'standard': False,
#    'preOrder': False,
#    'table': False,
#    'takeout': False},
#   'reservation': {'benefit': ''},
#   'hasBroadcastInfo': True,
#   'broadcastInfo': {'name': '수요미식회', 'menu': '벨기에와플/말차와플/코코넛와플'},
#   'shopWindowInfo': None,
#   'hasNPay': False,
#   'carWash': '',
#   'parkingPrice': '-1',
#   'card': '',
#   'distance': '18365.66',
#   'marker': 'nres://marker/00064-00013',
#   'markerSelected': 'nres://marker/00064-00166',
#   'microReview': [],
#   'michelinGuide': None,
#   'indoor': None,
#   'markerLabel': None,
#   'subway': None,
#   'evChargerInfo': {'summary': {'quickEvCharger': {'chargingSpeed': '급속',
#      'availability': '',
#      'names': ''},
#     'slowEvCharger': {'chargingSpeed': '완속', 'availability': '', 'names': ''}},
#    'evChargerList': []}},
#  {'index': '19',
#   'rank': '20',
#   'id': '13391329',
#   'name': '이타마에',
#   'tel': '02-2652-7037',
#   'isCallLink': False,
#   'virtualTel': '0507-1404-7037',
#   'ppc': '1',
#   'category': ['술집', '이자카야'],
#   'categoryPath': [['220036', '220051', '220556', '221121'],
#    ['222606', '222607', '1004452']],
#   'address': '서울특별시 영등포구 여의도동 37',
#   'roadAddress': '서울특별시 영등포구 의사당대로 108 아일렉스빌딩 502호',
#   'abbrAddress': '여의도동 37',
#   'shortAddress': ['서울 영등포구', '의사당대로 108', '아일렉스빌딩 502호'],
#   'display': '이타마에',
#   'telDisplay': '02-2652-7037',
#   'context': ['이자카야', '일식', '초밥', '프라이빗', '데이트'],
#   'reviewCount': 203,
#   'ktCallMd': '2ff68e9c7e059d739d10c4553feb6f7e',
#   'coupon': '0',
#   'thumUrl': 'https://ldb-phinf.pstatic.net/20180424_211/15245489514381VrLa_JPEG/DSC06060.JPG',
#   'type': 's',
#   'isSite': '1',
#   'posExact': '1',
#   'x': '126.9239878',
#   'y': '37.5210130',
#   'itemLevel': '8',
#   'isAdultBusiness': False,
#   'streetPanorama': {'id': 'EnJKesXoiXr5drp6DUPvvA==',
#    'pan': '-109.38',
#    'tilt': '10.00',
#    'lng': '126.9243896',
#    'lat': '37.5211539',
#    'fov': '120'},
#   'skyPanorama': {'id': 'gWYp9/93ngHhoLy6UWKQlA==',
#    'pan': '-176.86',
#    'tilt': '-30.00',
#    'lng': '126.9240875',
#    'lat': '37.5227776',
#    'fov': '124'},
#   'insidePanorama': None,
#   'interiorPanorama': None,
#   'indoorPanorama': None,
#   'theme': None,
#   'poiInfo': {'relation': None,
#    'hasRelation': False,
#    'road': {'poiShapeType': '1',
#     'shapeKey': None,
#     'boundary': None,
#     'detail': None},
#    'hasRoad': False,
#    'land': None,
#    'hasLand': False,
#    'polygon': None,
#    'hasPolygon': False},
#   'homePage': 'http://itamae.modoo.at/',
#   'description': '',
#   'entranceCoords': {'car': None,
#    'walk': [{'rep': True, 'x': 126.9243188, 'y': 37.5212061}]},
#   'isPollingPlace': False,
#   'bizhourInfo': '금요일 11:30~22:00 B.T 15:00~17:00 | 목요일 11:30~22:00 B.T 15:00~17:00 | 수요일 11:30~22:00 B.T 15:00~17:00 | 화요일 11:30~22:00 B.T 15:00~17:00 | 월요일 11:30~22:00 B.T 15:00~17:00 | 토요일 17:30~22:00',
#   'menuInfo': '점심정식 29,000 | 코스요리 40,000~90,000 | 모듬사시미,참치회 33,000~65,000 | 생연어회 30,000 | 북해도산가리비사시미 27,000 | 흰살생선회카르파쵸(광어.농어 등) 23,000 | 참치와 장마 와사비 무침 22,000 | 마구로 낫또 21,000 | 타코와사비 장마어니언샐러드 15,000 | 긴다라데리야끼 28,000 | 카이센 야끼우동 22,000 | 타마고 오코노미야끼 18,000 | 닭다리살 데리야끼 18,000 | 소고기아스파라거스 야채볶음 23,000 | 차돌박이숙주볶음 22,000 | 금일의 추천생선구이/조림 변동가격(업주문의) | 마구로타다키 23,000 | 닭다리살 남방즈케 19,000 | 생연어샐러드 23,000 | 아게다시도후 샐러드 16,000 | 나베,국물류 18,000~33,000 | 금일의 모듬 꼬치구이 23,000 | 새우덴뿌라 20,000 | 토리니쿠 가라아게 15,000 | 이카 가라아게 15,000 | 수제고롯케 16,000 | 모듬생선초밥 22,000~28,000 | 연어뱃살아부리초밥 17,000',
#   'petrolInfo': None,
#   'couponUrl': None,
#   'couponUrlMobile': None,
#   'hasCardBenefit': False,
#   'menuExist': '1',
#   'hasNaverBooking': True,
#   'naverBookingUrl': 'https://booking.naver.com/booking/6/bizes/136029',
#   'naverEasyOrderUrl': None,
#   'hasNaverSmartOrder': False,
#   'reservationLabel': {'standard': True,
#    'preOrder': False,
#    'table': False,
#    'takeout': False},
#   'reservation': {'benefit': ''},
#   'hasBroadcastInfo': False,
#   'broadcastInfo': None,
#   'shopWindowInfo': None,
#   'hasNPay': False,
#   'carWash': '',
#   'parkingPrice': '-1',
#   'card': '',
#   'distance': '18378.84',
#   'marker': 'nres://marker/00064-00119',
#   'markerSelected': 'nres://marker/00064-00273',
#   'microReview': ['식사도 가능한 여의도 이자카야 술집',
#    '여의도술집 조용한 저녁식사장소',
#    '여의도 조용하고 분위기 좋은 룸식 이자카야',
#    '여의도에서 시끄럽지 않은 고급 이자카야',
#    '6번 출구 분위기 좋은 술집'],
#   'michelinGuide': None,
#   'indoor': None,
#   'markerLabel': None,
#   'subway': None,
#   'evChargerInfo': {'summary': {'quickEvCharger': {'chargingSpeed': '급속',
#      'availability': '',
#      'names': ''},
#     'slowEvCharger': {'chargingSpeed': '완속', 'availability': '', 'names': ''}},
#    'evChargerList': []}}]

# %%
datas = response.json()["result"]["place"]["list"]
datas[0]
# Out:
# {'index': '0',
#  'rank': '1',
#  'id': '1251024640',
#  'name': '아루히',
#  'tel': '02-780-3903',
#  'isCallLink': False,
#  'virtualTel': '',
#  'ppc': '1',
#  'category': ['일식', '일식당'],
#  'categoryPath': [['220036', '220038', '220081', '220804'],
#   ['222606', '222607', '1004452']],
#  'address': '서울특별시 영등포구 여의도동 35-5',
#  'roadAddress': '서울특별시 영등포구 여의나루로 42 2층',
#  'abbrAddress': '여의도동 35-5',
#  'shortAddress': ['서울 영등포구', '여의나루로 42', '2층'],
#  'display': '아루히',
#  'telDisplay': '02-780-3903',
#  'context': [],
#  'reviewCount': 586,
#  'ktCallMd': 'd922b24a6b816844740eedc691cc6a78',
#  'coupon': '0',
#  'thumUrl': 'https://ldb-phinf.pstatic.net/20190227_268/15512563826654E3P4_JPEG/W09GhSwxyXXkx1z0q744tJBG.jpg',
#  'type': 's',
#  'isSite': '1',
#  'posExact': '1',
#  'x': '126.9249813',
#  'y': '37.5214725',
#  'itemLevel': '8',
#  'isAdultBusiness': False,
#  'streetPanorama': {'id': '+9RWNvH6ApOfUpiTC5paOw==',
#   'pan': '40.33',
#   'tilt': '10.00',
#   'lng': '126.9247758',
#   'lat': '37.5212303',
#   'fov': '120'},
#  'skyPanorama': {'id': 'qDBSTxwmtQw17Cu92NL0aQ==',
#   'pan': '-173.80',
#   'tilt': '-30.00',
#   'lng': '126.9251251',
#   'lat': '37.5227776',
#   'fov': '124'},
#  'insidePanorama': None,
#  'interiorPanorama': None,
#  'indoorPanorama': None,
#  'theme': None,
#  'poiInfo': {'relation': None,
#   'hasRelation': False,
#   'road': {'poiShapeType': '1',
#    'shapeKey': None,
#    'boundary': None,
#    'detail': None},
#   'hasRoad': False,
#   'land': None,
#   'hasLand': False,
#   'polygon': None,
#   'hasPolygon': False},
#  'homePage': 'http://www.instagram.com/aruhi_specialday',
#  'description': '',
#  'entranceCoords': {'car': [{'rep': True, 'x': 126.925, 'y': 37.521884},
#    {'rep': False, 'x': 126.9251363, 'y': 37.5210919}],
#   'walk': [{'rep': True, 'x': 126.9248586, 'y': 37.5218122},
#    {'rep': False, 'x': 126.9249882, 'y': 37.5212405}]},
#  'isPollingPlace': False,
#  'bizhourInfo': '매일 11:30~21:30 (월~일/ Break Time 15:00~17:30)',
#  'menuInfo': '오마카세 런치 33,000 | 오마카세 디너 35,000',
#  'petrolInfo': None,
#  'couponUrl': None,
#  'couponUrlMobile': None,
#  'hasCardBenefit': False,
#  'menuExist': '1',
#  'hasNaverBooking': False,
#  'naverBookingUrl': 'https://booking.naver.com/booking/6/bizes/223362',
#  'naverEasyOrderUrl': None,
#  'hasNaverSmartOrder': False,
#  'reservationLabel': {'standard': False,
#   'preOrder': False,
#   'table': False,
#   'takeout': False},
#  'reservation': {'benefit': ''},
#  'hasBroadcastInfo': False,
#  'broadcastInfo': None,
#  'shopWindowInfo': None,
#  'hasNPay': False,
#  'carWash': '',
#  'parkingPrice': '-1',
#  'card': '',
#  'distance': '18470.18',
#  'marker': 'nres://marker/00064-00122',
#  'markerSelected': 'nres://marker/00064-00276',
#  'microReview': ['수강신청보다 힘들다는 여의도 스시',
#   '여의도 스시 오마카세 가성비 훌륭한 스시',
#   '가성비 내리는 여의도 스시',
#   '가성비 좋기로 유명한 스시집',
#   '스시 오마카세 또 없을 것 같은 곳'],
#  'michelinGuide': None,
#  'indoor': None,
#  'markerLabel': None,
#  'subway': None,
#  'evChargerInfo': {'summary': {'quickEvCharger': {'chargingSpeed': '급속',
#     'availability': '',
#     'names': ''},
#    'slowEvCharger': {'chargingSpeed': '완속', 'availability': '', 'names': ''}},
#   'evChargerList': []}}

# %%
ids = [data["id"] for data in datas]
ranks = [data["rank"] for data in datas]
names = [data["name"] for data in datas]
tels = [data["tel"] for data in datas]
addrs = [data["address"] for data in datas]
categories = [data["category"] for data in datas]
menus = [data["menuInfo"] for data in datas]
reviews = [data["microReview"] for data in datas]

# %%
columns = ["ids", "ranks", "names", "tels", "addrs", "categories", "menus", "reviews"]
info = pd.DataFrame(columns=columns)
info["ids"] = ids
info["ranks"] = ranks
info["names"] = names
info["tels"] = tels
info["addrs"] = addrs
info["categories"] = categories
info["menus"] = menus
info["reviews"] = reviews

# %%
info
# Out:
#            ids ranks         names           tels  \
# 0   1251024640     1           아루히    02-780-3903
# 1   1483440401     2  후라토식당 여의도직영점    02-780-7090
# 2   1891132344     3   미도인 파이낸스여의도    02-780-1995
# 3     37392371     4       세상의모든아침   02-2055-4442
# 4     33879318     5     콘래드서울 제스트   02-6137-7100
# 5   1343621328     6       함루 여의도점   02-2070-2030
# 6   1978405203     7        오복수산참치    02-783-9988
# 7     11678773     8           진주집    02-780-6108
# 8     34033812     9  콘래드서울 37그릴앤바   02-6137-7110
# 9   1670537887    10            단아    02-780-8711
# 10    31570129    11          본보야지    02-782-8889
# 11  1974070800    12      진가와 여의도점    02-782-9072
# 12    37420412    13       사대부집 곳간   02-2055-4441
# 13    38704048    14         하얀과자점  070-8844-0326
# 14  1451225823    15           스시젠    02-784-7789
# 15  1720342718    16     도쿄등심 여의도점    02-782-2260
# 16  1732363102    17          히노노리   02-6747-0773
# 17    21052525    18    폴앤폴리나 여의도점    02-761-1966
# 18  1603372541    19        패트릭스와플    02-782-8896
# 19    13391329    20          이타마에   02-2652-7037
#
#                                        addrs        categories  \
# 0                       서울특별시 영등포구 여의도동 35-5         [일식, 일식당]
# 1                       서울특별시 영등포구 여의도동 23-8         [일식, 일식당]
# 2   서울특별시 영등포구 여의도동 23-8 파이낸스타워 2층 202, 203호         [음식점, 양식]
# 3        서울특별시 영등포구 여의도동 28-1 전경련회관 50층, 51층        [음식점, 브런치]
# 4                         서울특별시 영등포구 여의도동 23         [음식점, 뷔페]
# 5                       서울특별시 영등포구 여의도동 23-8         [일식, 일식당]
# 6                       서울특별시 영등포구 여의도동 23-6         [한식, 생선회]
# 7                       서울특별시 영등포구 여의도동 36-2          [한식, 국수]
# 8                         서울특별시 영등포구 여의도동 23         [음식점, 양식]
# 9                      서울특별시 영등포구 여의도동 44-25         [음식점, 한식]
# 10                        서울특별시 영등포구 여의도동 24     [음식점, 이탈리아음식]
# 11               서울특별시 영등포구 여의도동 25 씨티플라자 3층         [일식, 일식당]
# 12                      서울특별시 영등포구 여의도동 28-1         [음식점, 한식]
# 13           서울특별시 영등포구 여의도동 44-21 중앙빌딩 120호     [음식점, 카페,디저트]
# 14                        서울특별시 영등포구 여의도동 36         [일식, 일식당]
# 15                      서울특별시 영등포구 여의도동 35-3  [육류,고기요리, 소고기구이]
# 16                      서울특별시 영등포구 여의도동 23-6         [일식, 일식당]
# 17              서울특별시 영등포구 여의도동 37 아일렉스빌딩 1층    [카페,디저트, 베이커리]
# 18         서울특별시 영등포구 여의도동 37 아일렉스 지하1층 B06호      [카페,디저트, 와플]
# 19                        서울특별시 영등포구 여의도동 37        [술집, 이자카야]
#
#                                                 menus  \
# 0                     오마카세 런치 33,000 | 오마카세 디너 35,000
# 1   규카츠 15,000 | 반숙 오므라이스 11,000 | 스테키 정식 14,000 |...
# 2   400 등심 스테이크 덮밥 (하루 7그릇 한정) 14,700 | 미도인 구첩 반상 ...
# 3   바게트 프렌치 토스트 24,000 | 샥슈카 29,000 | 트러플 블랙 리조또 2...
# 4   성인 아침 (평일, 주말) 50,000 | 성인 평일 점심 85,000 | 어린이 ...
# 5   히츠마부시 보통 1마리 37,000 | 히츠마부시 특 1.5마리 46,000 | 한...
# 6   생참치사시미 55,000 | 코스요리 55,000 | 카이센동 18,000 | 우니...
# 7   냉콩국수 11,000 | 비빔국수 9,000 | 닭칼국수 9,000 | 육개장칼국수...
# 8   테이스팅 메뉴 155,000 | 주말 브런치 79,000 | 모듬 육류구이 140,...
# 9   [점심] 맑은 민어탕 정식 30,000 | [점심] 연저육 솥밥 세트 25,000 ...
# 10  에피-깔라마리 19,000 | 에피-망고살사&새우구이 19,000 | 해산물리조또 ...
# 11  진가와 가이세키 44,000 | 사시미스시정식 28,000 | 스끼야끼나베 33,0...
# 12  한방오리탕 반상 36,000 | 제주 은갈치구이 반상 34,000 | 주꾸미 연포탕...
# 13  감자케익 6,500 | 까페오레 4,000 | 아인슈페너 4,500 | 리얼쇼콜라떼...
# 14  런치 스시오마카세 45,000 | 디너 스시 오마카세 67,000 | 디너 사시미 ...
# 15  런치 스페셜 A 29,000 | 도쿄 스페셜 A 69,000 | 워터에이징 한우 등...
# 16             히노세트 16,000 | 노리세트 22,000 | 새우튀김 4,200
# 17  블랙올리브 3,600 | 허브빵 1,700 | 치아바타 3,100 | 화이트 치아바...
# 18  오리지널 와플 2,600 | 말차 와플 3,300 | 코코넛 와플 3,300 | 아...
# 19  점심정식 29,000 | 코스요리 40,000~90,000 | 모듬사시미,참치회 3...
#
#                                               reviews
# 0   [수강신청보다 힘들다는 여의도 스시, 여의도 스시 오마카세 가성비 훌륭한 스시, 가...
# 1                                                  []
# 2                                                  []
# 3   [전경련회관 50층에서 여의도 전망 바라보며 브런치, 전경련 회관 50층 한강이 내...
# 4   [여의도 콘래드 호텔의 분위기 좋은 뷔페, 여의도 맛있는뷔페, 여의도 고급스러운 호...
# 5                                                  []
# 6                                                  []
# 7   [이영자 맛집리스트에도 올라와있는 콩국수 닭칼국수, 닭칼국수 콩국수가 유명한 이영자...
# 8   [전망과 야경이 끝내주는 로맨틱한 호텔 레스토랑, 야경좋은 레스토랑, 크리스마스 이...
# 9                                                  []
# 10  [스테이크와 파스타가 맛있는 분위기 있는 레스토랑, 피자가 맛있는 여의도이탈리안레스...
# 11                                                 []
# 12  [여의도 전경련회관 50층 전망좋은 한식 뷔페 맛집, 밥블레스유 팀이 다녀간 여의도...
# 13                                                 []
# 14                                                 []
# 15  [가족 여의도 데이트 맛있는 소고기 도쿄등심, 여의도 데이트 모임장소로 추천하는 도...
# 16                                                 []
# 17  [제대로 된 깜빠뉴를 내는 여의도 대표 빵집, 수요미식회로 유명한 폴앤폴리나 빵집,...
# 18                                                 []
# 19  [식사도 가능한 여의도 이자카야 술집, 여의도술집 조용한 저녁식사장소, 여의도 조용...

# %%
url = "https://m.place.naver.com/restaurant/{}/home".format(ids[0])
print(url)
# Out:
# https://m.place.naver.com/restaurant/1251024640/home

# %%
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
dom = TextResponse(response.url, body=response.text, encoding='utf-8')
dom
# Out:
# <200 https://m.place.naver.com/restaurant/1251024640/home>

# %%
dom.text
# Out:
# '\n    <!DOCTYPE html>\n    <html lang="ko">\n      <head>\n        <title>ë\x84¤ì\x9d´ë²\x84 í\x94\x8cë\xa0\x88ì\x9d´ì\x8a¤</title>\n        <meta charset="utf-8" />\n        <meta httpequiv="x-ua-compatible" content="ie=edge" />\n        <meta id="_viewport" name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no, shrink-to-fit=no viewport-fit=cover" />\n        <meta name="format-detection" content="telephone=no" />\n        <link rel="icon" type="image/png" href=https://m-place.pstatic.net/assets/shared/images/favicon-72.png />\n        <link rel="icon" type="image/png" sizes="96x96" href=https://m-place.pstatic.net/assets/shared/images/favicon-96.png />\n        <link rel="icon" type="image/png" sizes="144x144" href=https://m-place.pstatic.net/assets/shared/images/favicon-144.png />\n        <link rel="icon" type="image/png" sizes="192x192" href=https://m-place.pstatic.net/assets/shared/images/favicon-192.png />\n        <link rel="apple-touch-icon" href=https://m-place.pstatic.net/assets/shared/images/favicon-120.png />\n        <link rel="apple-touch-icon" sizes="180x180" href=https://m-place.pstatic.net/assets/shared/images/favicon-180.png />\n        <link rel="apple-touch-icon" sizes="152x152" href=https://m-place.pstatic.net/assets/shared/images/favicon-152.png />\n        <link rel="apple-touch-icon" sizes="167x167" href=https://m-place.pstatic.net/assets/shared/images/favicon-167.png />\n        <meta id="og:title" property="og:title" content="ì\x95\x84ë£¨í\x9e\x88 : ë\x84¤ì\x9d´ë²\x84" data-isomorphic-meta="true"/><meta id="og:description" property="og:description" content="ë°©ë¬¸ì\x9e\x90ë¦¬ë·° 2032 Â· â\x98\x854.79 Â· ì\x88\x98ê°\x95ì\x8b\xa0ì²\xadë³´ë\x8b¤ í\x9e\x98ë\x93¤ë\x8b¤ë\x8a\x94 ì\x97¬ì\x9d\x98ë\x8f\x84 ì\x8a¤ì\x8b\x9c" data-isomorphic-meta="true"/><meta id="og:type" property="og:type" content="article" data-isomorphic-meta="true"/><meta id="og:article:author" property="og:article:author" content="ë\x84¤ì\x9d´ë²\x84 í\x94\x8cë\xa0\x88ì\x9d´ì\x8a¤" data-isomorphic-meta="true"/><meta id="og:site_name" property="og:site_name" content="ë\x84¤ì\x9d´ë²\x84 í\x94\x8cë\xa0\x88ì\x9d´ì\x8a¤" data-isomorphic-meta="true"/><meta id="og:image" property="og:image" content="https://search.pstatic.net/common/?autoRotate=true&amp;quality=100&amp;type=f640_380&amp;src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20190227_268%2F15512563826654E3P4_JPEG%2FW09GhSwxyXXkx1z0q744tJBG.jpg" data-isomorphic-meta="true"/><meta id="twitter:card" property="twitter:card" content="summary_large_image" data-isomorphic-meta="true"/><meta id="twitter:title" property="twitter:title" content="ì\x95\x84ë£¨í\x9e\x88 : ë\x84¤ì\x9d´ë²\x84" data-isomorphic-meta="true"/><meta id="twitter:description" property="twitter:description" content="ë°©ë¬¸ì\x9e\x90ë¦¬ë·° 2032 Â· â\x98\x854.79 Â· ì\x88\x98ê°\x95ì\x8b\xa0ì²\xadë³´ë\x8b¤ í\x9e\x98ë\x93¤ë\x8b¤ë\x8a\x94 ì\x97¬ì\x9d\x98ë\x8f\x84 ì\x8a¤ì\x8b\x9c" data-isomorphic-meta="true"/><meta id="twitter:site" property="twitter:site" content="ë\x84¤ì\x9d´ë²\x84 í\x94\x8cë\xa0\x88ì\x9d´ì\x8a¤" data-isomorphic-meta="true"/><meta id="twitter:image" property="twitter:image" content="https://search.pstatic.net/common/?autoRotate=true&amp;quality=100&amp;type=f640_380&amp;src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20190227_268%2F15512563826654E3P4_JPEG%2FW09GhSwxyXXkx1z0q744tJBG.jpg" data-isomorphic-meta="true"/>\n      </head>\n      <body class="is_place">\n        <div id="place-style-loader">\n          <style id="205091" type="text/css" data-isomorphic-style="true">\n</style><style id="252656" type="text/css" data-isomorphic-style="true">.place_section._2qgJW .place_section_header ._2cD9i{margin-top:2px}.place_section._2qgJW .place_section_header ._2dyQc{display:flex;align-items:center;position:absolute;top:0;right:18px;bottom:0;font-size:1.4rem;font-weight:400;color:#8f8f8f}.RXztH{padding:7px 18px 22px}._3ESdu{margin-top:16px;padding:12px 0 0;border-top: ...

# %%
elements = dom.xpath('//*[@id="app-root"]/div/div[2]/div[1]/div/div/div[1]/div/span[1]/em')
elements
# Out:
# [<Selector xpath='//*[@id="app-root"]/div/div[2]/div[1]/div/div/div[1]/div/span[1]/em' data='<em>4.79</em>'>]

# %%
elements[0].extract()
# Out:
# '<em>4.79</em>'
