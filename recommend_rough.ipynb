# %%
import requests
import urllib.parse as urlparse
from geopy import distance

# %%
naver_KEY_ID = 'nWxD0TpBM0o2UmWor2YT'
naver_KEY_secret = 'yNSdVVOHuN'

# %%
class Route:
    def __init__(self, headers={"X-NCP-APIGW-API-KEY-ID": "umg9dmbud3",
           "X-NCP-APIGW-API-KEY": "SfOEeqmpLBYapFIBn6HTtS62DcnDq6T7N5v9dMqX"}):
        self.headers = headers
    
    # 각 출발지 -> 위경도 변환
    def addr_to_xy(self):
        # 주소값 입력
        self.d1_name = input("출발지 1을 입력하세요. : ")
        self.d2_name = input("출발지 2를 입력하세요. : ")
        # URL 설정
        self.d1_url = "https://naveropenapi.apigw.ntruss.com/map-geocode/v2/geocode?query={}".format(self.d1_name)
        self.d2_url = "https://naveropenapi.apigw.ntruss.com/map-geocode/v2/geocode?query={}".format(self.d2_name)
        # 리퀘스트
        self.response1 = requests.get(self.d1_url, headers=self.headers)
        self.response2 = requests.get(self.d2_url, headers=self.headers)
        # JSON 파싱하여 위경도 추출
        self.d1_x = self.response1.json()["addresses"][0]["x"] 
        self.d1_y = self.response1.json()["addresses"][0]["y"]
        self.d2_x = self.response2.json()["addresses"][0]["x"]
        self.d2_y =  self.response2.json()["addresses"][0]["y"]
        return self.d1_x, self.d1_y, self.d2_x, self.d2_y
    
    # 출발지간 위경도 -> 경로값 변환
    def road_path(self):
        self.d1_xy = str(self.d1_x) + "," + str(self.d1_y)
        self.d2_xy = str(self.d2_x) + "," + str(self.d2_y)
        self.d_option = "traoptimal"
        self.d_url = "https://naveropenapi.apigw.ntruss.com/map-direction/v1/driving?start={}&goal={}&option={}".format(self.d1_xy, self.d2_xy, self.d_option)
        self.response = requests.get(self.d_url, headers=self.headers)
        self.path = self.response.json()["route"]["traoptimal"][0]["path"]
        self.avg_path = self.response.json()["route"]["traoptimal"][0]["summary"]["distance"] / len(self.path)
        print("거리 : {}m, ".format(self.response.json()["route"]["traoptimal"][0]["summary"]["distance"]), len(self.path), ", ", self.avg_path)
        return self.path
    
    # 출발지간 대중교통 경로
    def trans_path(self, path_type=0):
        self.path_type = path_type
        self.key = 'lxOFkKZ6BCIrJYAQQbeuYsBW+6br+fKss6pEigRpVqA'
        self.url = 'https://api.odsay.com/v1/api/searchPubTransPathT'
        self.params = {'apiKey' : self.key,
                  'SX' : self.d1_x,
                  'SY' : self.d1_y,
                  'EX' : self.d2_x,
                  'EY' : self.d2_y,
                  'SearchPathType' : self.path_type,
                  'OPT':0,
                 }
        self.url = self.url + '?' + urlparse.urlencode(self.params)
        self.response = requests.get(self.url)
        # 경로내 정류장 위경도 추출
        self.transit_count = self.response.json()['result']['path'][0]['info']['busTransitCount'] + self.response.json()['result']['path'][0]['info']['subwayTransitCount']
        self.distance = round(self.response.json()['result']['path'][0]['info']['totalDistance'] / 1000,2)
        self.stop_lat_lng = []
        for i in range(1, 2*self.transit_count, 2):
            self.stop_info = self.response.json()['result']['path'][0]['subPath'][i]['passStopList']['stations']
            self.stop_lat_lng += [(float(a['y']),float(a['x'])) for a in self.stop_info]
        # 경로가 1km이하거나, 정류장이 5개 미만이면 모든 위경도 표출하고, 이외에는 중간 6개의 정류장 위경도만 표출
        if self.distance <= 1 or len(self.stop_lat_lng) <= 5:
            self.meet_point = self.stop_lat_lng
        else:
            self.meet_point = self.stop_lat_lng[len(self.stop_lat_lng)//2-3:len(self.stop_lat_lng)//2+3]
        print('거리: {}km'.format(self.distance))
        return self.meet_point, self.stop_lat_lng
    
    def busmetro(*args):
        rte = Route()
        d1_x, d1_y, d2_x, d2_y = rte.addr_to_xy()
        # 대중교통 이동
        meet_points, all_points = rte.trans_path()
        # 경로내 위, 경도 최대 최소값 구하기
        lat_list = [point[0] for point in all_points]
        lng_list = [point[1] for point in all_points]
        min(lat_list), max(lat_list), min(lng_list), max(lng_list)
        import pandas as pd
        df = pd.read_csv('df.csv')
        df['latlng'] = df.apply(lambda x:(x['lat'], x['lng']), axis=1)
        # 경로 square 내 맛집 추출
        direction_square = df[(df['lat']<=max(lat_list)) & (df['lat']>=min(lat_list)) & (df['lng']>=min(lng_list)) & (df['lng']<=max(lng_list))]
        # square 내 경로 1km 이내 맛집 추출
        matzip=pd.DataFrame()
        for lat_lng in direction_square['latlng']:
            for point in meet_points:
                dis = distance.distance(point, lat_lng).km
                if dis <= 1:
                    df_1 = direction_square[direction_square['latlng'] == lat_lng]
                    matzip = matzip.append(df_1).reset_index(drop=True)
        cd = matzip.category == input("'한식', '양식', '디저트', '일식', '바', '중식', '분식', '기타', '동남아식', '뷔페': ")
        matzip = matzip[cd].sort_values(by='rating', ascending=False).head()
        return matzip[['fname', 'tel', 'addr', 'bizhour', 'category', 'menu', 'rating']]

    
    
#     서울시 강서구 강서로 426
#     서울시 도봉구 방학2동 344-5

# %%
Route.busmetro()
# Out:
# 출발지 1을 입력하세요. : 서울시 강서구 강서로 426
# 출발지 2를 입력하세요. : 서울시 도봉구 방학2동 344-5
# 거리: 37.99km
# '한식', '양식', '디저트', '일식', '바', '중식', '분식', '기타', '동남아식', '뷔페': 한식
#       fname           tel                   addr  \
# 378     우래옥  02-2265-0151     서울특별시 중구 주교동 118-1
# 84     순대실록   02-742-5338     서울특별시 종로구 동숭동 1-41
# 85     순대실록   02-742-5338     서울특별시 종로구 동숭동 1-41
# 843  꾸이꾸이멱살  02-6368-7999  서울특별시 성북구 동선동1가 85-90
# 333    평양면옥  02-2267-7784      서울특별시 중구 장충동1가 13
#
#                                                bizhour category  \
# 378                      매일 11:30~21:30 | 월요일 휴무 명절 휴무       한식
# 84                                      매일 07:00~24:00       한식
# 85                                      매일 07:00~24:00       한식
# 843  매일 12:00~00:00 Break time 15:00-17:00 Last ord...       한식
# 333                                     매일 11:00~21:30       한식
#
#                                                   menu  rating
# 378  평양냉면 14,000 | 비빔냉면 14,000 | 생등심 55,000 | 장국밥 1...    4.41
# 84   전통 순댓국 8,000~10,000 | 순대스테이크 14,000 | 순대철판볶음 2...    4.32
# 85   전통 순댓국 8,000~10,000 | 순대스테이크 14,000 | 순대철판볶음 2...    4.32
# 843  특수부위 멱살 9,900 | 특수부위 꼬들삼겹살(덜미살) 12,000 | 특수부위 ...    4.26
# 333  편육 30,000 | 제육 28,000 | 냉면 12,000 | 불고기 35,000...    4.26

# %%
# 자동차 경로
def car():
    # 출발지 입력
    d1 = input("출발지 1을 입력하세요. : ")
    d2 = input("출발지 2을 입력하세요. : ")
        
    # URL 설정
    d1_url = "https://naveropenapi.apigw.ntruss.com/map-geocode/v2/geocode?query={}".format(d1)
    d2_url = "https://naveropenapi.apigw.ntruss.com/map-geocode/v2/geocode?query={}".format(d2)
        
    # 리퀘스트
    headers={"X-NCP-APIGW-API-KEY-ID": "r97kqovind", "X-NCP-APIGW-API-KEY": "FWeecTIqiwQGs2RGil1IPA8wg9QURxjYBzyEPxR7"}
    response1 = requests.get(d1_url, headers=headers)
    response2 = requests.get(d2_url, headers=headers)
        
    # JSON 파싱하여 위경도 추출
    d1_x = response1.json()["addresses"][0]["x"]
    d1_y = response1.json()["addresses"][0]["y"]
    d2_x = response2.json()["addresses"][0]["x"]
    d2_y = response2.json()["addresses"][0]["y"]
    d1_xy = d1_x + ", " + d1_y
    d2_xy = d2_x + ", " + d2_y
        
    # 출발지간 위경도 -> 경로값 변환
    d_option = "traoptimal"
    d_url = "https://naveropenapi.apigw.ntruss.com/map-direction/v1/driving?start={}&goal={}&option={}".format(d1_xy, d2_xy, d_option)
    response = requests.get(d_url, headers=headers)
    path = response.json()["route"]["traoptimal"][0]["path"]    
        
    # 중간 경로의 모든 값
    middle_path = path[len(path)//3:int(len(path)//(3/2))]
    # 중간 경로 중 크롤링 포인트
    crawling_point = middle_path[::10]
    
    mid_lng_min = min([data[0] for data in middle_path])
    mid_lng_max = max([data[0] for data in middle_path])
    mid_lat_min = min([data[1] for data in middle_path])
    mid_lat_max = max([data[1] for data in middle_path])
    
    # 조건
    df = pd.read_csv('./df.csv')
    cd0 = df['lng'] > mid_lng_min
    cd1 = df['lng'] < mid_lng_max
    cd2 = df['lat'] > mid_lat_min
    cd3 = df['lat'] < mid_lat_max 
    cd4 = df['category'] == input("'한식', '양식', '디저트', '일식', '바', '중식', '분식', '기타', '동남아식', '뷔페': ")
    all_cd = cd0 & cd1 & cd2 & cd3 & cd4
    
    df = df[all_cd].sort_values(by='rating', ascending=False).head()
    return df[['fname', 'tel', 'addr', 'bizhour', 'category', 'menu', 'rating']]

# %%
car()
# Out:
# 출발지 1을 입력하세요. : 서울시 강서구 강서로 426
# 출발지 2을 입력하세요. : 서울시 도봉구 방학2동 344-5
# '한식', '양식', '디저트', '일식', '바', '중식', '분식', '기타', '동남아식', '뷔페': 한식
#               fname            tel                    addr  \
# 5373         제주미목식당   02-6952-4448  서울특별시 은평구 불광동 108-2 1층
# 5410           팔덕식당  010-8078-8338     서울특별시 은평구 갈현동 424-1
# 5718  김순례닭강정 은평뉴타운점    02-356-7399        서울특별시 은평구 진관동 64
# 5720     이차돌 은평뉴타운점    02-351-3750        서울특별시 은평구 진관동 62
# 5705         예산국수명가    02-356-1402        서울특별시 은평구 진관동 29
#
#                                                 bizhour category  \
# 5373                                     매일 17:00~01:00       한식
# 5410  매일 11:00~22:00 매주 월요일 휴무 (일일 100인분 소진시 마감) | 매...       한식
# 5718  목요일 14:00~23:40 | 화요일 14:00~23:40 | 금요일 14:00~...       한식
# 5720                    매일 11:30~23:00 Last Order 22:15       한식
# 5705  평일 11:00~00:00 재료 소진시 마감 | 주말 11:00~00:00 재료 소...       한식
#
#                                                    menu  rating
# 5373  A세트(2인추천) 45,000 | B세트(3인추천) 60,000 | 미목살 30,0...    4.16
# 5410  매운 등갈비찜 13,000 | 가마솥 곤드레밥 5,000 | 메밀전 추가 2,000...    4.16
# 5718  김순례닭강정오리지날 18,000 | 양조간장 강정 19,000 | 숯불갈비맛 강정 ...    4.12
# 5720  차돌박이 7,900 | 차돌삼겹 5,900 | 부채살 스테이크 8,900 | LA ...    4.04
# 5705  예산국수 4,900 | 비빔국수 5,900 | 김치예산국수 5,500 | 매운비빔국...    4.04

# %%
# 경로 square 내 맛집 추출
direction_square = df[(df['lat']<=max(lat_list)) & (df['lat']>=min(lat_list)) & (df['lng']>=min(lng_list)) & (df['lng']<=max(lng_list))]

# %%
# square 내 경로 1km 이내 맛집 추출
matzip=pd.DataFrame()
for lat_lng in direction_square['latlng']:
    for point in meet_points:
        dis = distance.distance(point, lat_lng).km
        if dis <= 1:
            df_1 = direction_square[direction_square['latlng'] == lat_lng]
            matzip = matzip.append(df_1).reset_index(drop=True)

# %%
matzip
# Out:
#      Unnamed: 0           fname         name            tel  \
# 0           402        원조순희네빈대떡     원조순희네빈대떡   02-2264-5057
# 1           403          어머니국시방       어머니국시방   02-2272-9414
# 2           404     진옥화할매원조닭한마리  진옥화할매원조닭한마리   02-2275-9666
# 3           405       제주바다 서울본점         제주바다  010-2499-1193
# 4           406         박가네 빈대떡          박가네   02-2264-0847
# ..          ...             ...          ...            ...
# 932        4777  아웃백스테이크하우스 미아점   아웃백스테이크하우스    02-944-2661
# 933        4779  노브랜드버거 미아사거리역점       노브랜드버거    02-945-5280
# 934        4780           천태막국수        천태막국수    02-985-5255
# 935        4783              오센           오센    02-988-0548
# 936        4785          더파이어셰프       더파이어셰프    02-982-6808
#
#                       addr     si   gu  dong  \
# 0     서울특별시 종로구 종로5가 138-9  서울특별시  종로구  종로5가
# 1       서울특별시 종로구 종로5가 407  서울특별시  종로구  종로5가
# 2    서울특별시 종로구 종로5가 265-22  서울특별시  종로구  종로5가
# 3     서울특별시 종로구 효제동 201 1층  서울특별시  종로구   효제동
# 4    서울특별시 종로구 종로5가 138-10  서울특별시  종로구  종로5가
# ..                     ...    ...  ...   ...
# 932     서울특별시 강북구 미아동 70-6  서울특별시  강북구   미아동
# 933    서울특별시 강북구 미아동 35-30  서울특별시  강북구   미아동
# 934    서울특별시 강북구 미아동 72-18  서울특별시  강북구   미아동
# 935    서울특별시 강북구 미아동 35-24  서울특별시  강북구   미아동
# 936  서울특별시 강북구 미아동 860-189  서울특별시  강북구   미아동
#
#                                                bizhour category  ...  \
# 0    평일 08:00~23:00 설날, 추석당일 휴무 | 일요일 08:00~22:00 저...       한식  ...
# 1                                       매일 10:00~16:30       한식  ...
# 2              매일 10:30~01:00 마지막주문 23:30(휴무:명절 전날,당일)       한식  ...
# 3                                    매일 11:00~24:00 무휴       한식  ...
# 4                                  매일 08:00~22:00 연중무휴       한식  ...
# ..                                                 ...      ...  ...
# 932    매일 10:30~21:00 Last Order 20:30 / 11월24일 ~12월7일       양식  ...
# 933                                     매일 11:00~01:00       양식  ...
# 934                                     매일 11:00~21:30       한식  ...
# 935  목요일 17:00~03:00 | 수요일 17:00~03:00 | 화요일 17:00~...        바  ...
# 936  매일 11:30~24:00 매주 수요일은 휴무입니다 | 매일 16:00~17:00 ...       양식  ...
#
#                                                    img         lng        lat  \
# 0    https://ldb-phinf.pstatic.net/20160108_16/1452...  127.000729  37.570594
# 1    https://ldb-phinf.pstatic.net/20150831_21/1440...  127.006543  37.570161
# 2    https://ldb-phinf.pstatic.net/20150831_186/144...  127.005739  37.570350
# 3    https://ldb-phinf.pstatic.net//20161006_294/14...  127.003981  37.571986
# 4    https://ldb-phinf.pstatic.net/20170612_61/1497...  127.000825  37.570535
# ..                                                 ...         ...        ...
# 932  https://ldb-phinf.pstatic.net/20200108_22/1578...  127.030532  37.614601
# 933  https://ldb-phinf.pstatic.net/20200327_96/1585...  127.030728  37.611850
# 934  https://ldb-phinf.pstatic.net/20200822_162/159...  127.031059  37.614653
# 935  https://ldb-phinf.pstatic.net/20200529_95/1590...  127.030518  37.612259
# 936  https://ldb-phinf.pstatic.net/20151113_82/1447...  127.031090  37.612731
#
#     n_rating  b_rating  mg_rating  d_rating  mn_rating  rating  \
# 0       4.33      3.53       3.68      1.94       3.54    3.88
# 1       4.50      3.53       0.00      1.94       3.54    3.05
# 2       4.31      3.53       3.60      1.94       3.54    3.85
# 3       4.30      3.53       3.68      1.94       3.54    3.87
# 4       4.31      3.53       3.68      1.94       3.54    3.87
# ..       ...       ...        ...       ...        ...     ...
# 932     4.32      3.53       3.68      1.94       3.54    3.88
# 933     4.36      3.53       3.68      1.05       3.54    3.83
# 934     4.76      3.53       3.68      1.94       3.54    4.10
# 935     4.52      3.53       3.68      0.80       3.54    3.89
# 936     4.45      3.53       3.68      1.40       3.54    3.90
#
#                                latlng
# 0           (37.5705942, 127.0007294)
# 1           (37.5701611, 127.0065429)
# 2             (37.57035, 127.0057389)
# 3    (37.57198629999999, 127.0039815)
# 4            (37.570535, 127.0008248)
# ..                                ...
# 932         (37.6146006, 127.0305324)
# 933         (37.6118504, 127.0307281)
# 934  (37.6146531, 127.03105890000002)
# 935          (37.6122593, 127.030518)
# 936            (37.612731, 127.03109)
#
# [937 rows x 23 columns]

# %%
df = pd.read_csv('./df.csv')
df = df.drop(columns='Unnamed: 0')

# %%
cd0 = df.category == '한식'
cd1 = df.lat < 37.572380
cd2 = df.lat > 37.562380
cd3 = df.lng < 126.974200
cd4 = df.lng > 126.964200
cd_all = cd0 & cd1 & cd2 & cd3 & cd4
df[cd_all].sort_values(by='rating', ascending=False).head()
# Out:
#       fname   name           tel                              addr     si  \
# 45    광화문뚝감  광화문뚝감   02-722-5894              서울특별시 종로구 당주동 128-14  서울특별시
# 5808    동해관    동해관   02-363-4221              서울특별시 서대문구 냉천동 183-2  서울특별시
# 745     덕수정    덕수정   02-755-0180                  서울특별시 중구 정동 11-5  서울특별시
# 5842   이판저판   이판저판   02-313-8629                서울특별시 서대문구 냉천동 227  서울특별시
# 13     암소서울   암소서울  02-6744-0123  서울특별시 종로구 신문로1가 115 콘코디언빌딩 지하 1층  서울특별시
#
#         gu   dong                                  bizhour category  \
# 45     종로구    당주동  매일 00:00~24:00 명절 휴무, 15:00~17:00브레이크타임       한식
# 5808  서대문구    냉천동                           평일 11:30~22:30       한식
# 745     중구     정동                  매일 11:00~22:00 | 일요일 휴무       한식
# 5842  서대문구    냉천동                           매일 00:00~24:00       한식
# 13     종로구  신문로1가  매일 11:00~21:00 | 매일 15:00~16:00 브레이크 타임       한식
#
#                                                    menu  ...  \
# 45    감자탕 25,000~41,000 | 해물뼈찜 29,000~44,000 | 뚝감(뚝배...  ...
# 5808                      점심정식코스 25,000 | 저녁진미코스 40,000  ...
# 745   부대찌개 8,000 | 오징어볶음 10,000 | 삼치구이 8,000 | 우거지갈비...  ...
# 5842  생삼겹살 9,000 | 막걸리 4,000 | 한라산 5,000 | 진한복분자 15,...  ...
# 13    종가 159,000 | 반가 ( 런치 ) 79,000 | 회식 ( 6인이상 ) 99...  ...
#
#                                             microreview  \
# 45    ['광화문 맛집 기다린 자만이 먹을 수 있는 뚝배기 감자탕', '그릇 뚝딱하는 뚝배...
# 5808                                                 []
# 745   ['오징어볶음이 맛있는 부대찌개전문점', '오징어볶음 고등학교 나를 살찌운 음식',...
# 5842                                                 []
# 13    ['토니정쉐프의 한식다이닝을 맛볼 수 있는 광화문맛집', '광화문 맛집 이름걸고 하...
#
#                                                     img         lng  \
# 45    https://ldb-phinf.pstatic.net/20190930_207/156...  126.972592
# 5808  https://ldb-phinf.pstatic.net/20200402_20/1585...  126.964985
# 745   https://ldb-phinf.pstatic.net/20150901_108/144...  126.972550
# 5842  https://ldb-phinf.pstatic.net/20200302_107/158...  126.964462
# 13    https://ldb-phinf.pstatic.net/20191129_184/157...  126.973197
#
#             lat  n_rating  b_rating  mg_rating  d_rating  mn_rating  rating
# 45    37.572069      4.45      3.53       4.30      3.05       3.54    4.18
# 5808  37.566476      4.62      3.53       3.68      1.94       3.54    4.03
# 745   37.565900      4.33      3.53       4.00      2.75       3.54    4.02
# 5842  37.567742      4.61      3.53       3.68      1.94       3.54    4.02
# 13    37.569784      4.65      3.53       3.68      0.95       3.54    3.97
#
# [5 rows x 21 columns]

# %%
var map = new naver.maps.Map('map', {
    center: new naver.maps.LatLng(37.3595704, 127.105399),
    zoom: 15
});

var marker = new naver.maps.Marker({
    position: new naver.maps.LatLng(37.3595704, 127.105399),
    map: map
});
# Out:
#   File "<ipython-input-9-05ee77621b94>", line 1
#     var map = new naver.maps.Map('map', {
#           ^
# SyntaxError: invalid syntax

# %%
<script type="text/javascript" src="https://openapi.map.naver.com/openapi/v3/maps.js?ncpClientId=YOUR_CLIENT_ID"></script>
# Out:
#   File "<ipython-input-10-a03d0a6869f0>", line 1
#     <script type="text/javascript" src="https://openapi.map.naver.com/openapi/v3/maps.js?ncpClientId=YOUR_CLIENT_ID"></script>
#     ^
# SyntaxError: invalid syntax

# %%
from flask import Flask
from flask_googlemaps import GoogleMaps

app = Flask(__name__)

# you can set key as config
app.config['GOOGLEMAPS_KEY'] = "8JZ7i18MjFuM35dJHq70n3Hx4"

# Initialize the extension
GoogleMaps(app)

# you can also pass the key here if you prefer
GoogleMaps(app, key="8JZ7i18MjFuM35dJHq70n3Hx4")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-4-f97ed98de03c> in <module>
#      11
#      12 # you can also pass the key here if you prefer
# ---> 13 GoogleMaps(app, key="8JZ7i18MjFuM35dJHq70n3Hx4")
#
# ~\anaconda3\lib\site-packages\flask_googlemaps\__init__.py in __init__(self, app, **kwargs)
#     787         self.key = kwargs.get('key')
#     788         if app:
# --> 789             self.init_app(app)
#     790
#     791     def init_app(self, app):
#
# ~\anaconda3\lib\site-packages\flask_googlemaps\__init__.py in init_app(self, app)
#     792         if self.key:
#     793             app.config['GOOGLEMAPS_KEY'] = self.key
# --> 794         self.register_blueprint(app)
#     795         app.add_template_filter(googlemap_html)
#     796         app.add_template_filter(googlemap_js)
#
# ~\anaconda3\lib\site-packages\flask_googlemaps\__init__.py in register_blueprint(self, app)
#     807             "googlemaps", __name__, template_folder="templates"
#     808         )
# --> 809         app.register_blueprint(module)
#     810         return module
#
# ~\anaconda3\lib\site-packages\flask\app.py in wrapper_func(self, *args, **kwargs)
#      96                 "before the application starts serving requests."
#      97             )
# ---> 98         return f(self, *args, **kwargs)
#      99
#     100     return update_wrapper(wrapper_func, f)
#
# ~\anaconda3\lib\site-packages\flask\app.py in register_blueprint(self, blueprint, **options)
#    1158                 ' share the same name "%s". Blueprints that are created on the'
#    1159                 " fly need unique names."
# -> 1160                 % (blueprint, self.blueprints[blueprint.name], blueprint.name)
#    1161             )
#    1162         else:
#
# AssertionError: A name collision occurred between blueprints <flask.blueprints.Blueprint object at 0x000001BEA7E50808> and <flask.blueprints.Blueprint object at 0x000001BEA7E506C8>. Both share the same name "googlemaps". Blueprints that are created on the fly need unique names.

# %%
from flask import Flask, render_template
from flask_googlemaps import GoogleMaps
from flask_googlemaps import Map

app = Flask(__name__, template_folder=".")
GoogleMaps(app)

@app.route("/")
def mapview():
    # creating a map in the view
    mymap = Map(
        identifier="view-side",
        lat=37.4419,
        lng=-122.1419,
        markers=[(37.4419, -122.1419)]
    )
    sndmap = Map(
        identifier="sndmap",
        lat=37.4419,
        lng=-122.1419,
        markers=[
          {
             'icon': 'http://maps.google.com/mapfiles/ms/icons/green-dot.png',
             'lat': 37.4419,
             'lng': -122.1419,
             'infobox': "<b>Hello World</b>"
          },
          {
             'icon': 'http://maps.google.com/mapfiles/ms/icons/blue-dot.png',
             'lat': 37.4300,
             'lng': -122.1400,
             'infobox': "<b>Hello World from other place</b>"
          }
        ]
    )
    return render_template('example.html', mymap=mymap, sndmap=sndmap)

if __name__ == "__main__":
    app.run(debug=True)
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: on
#  * Restarting with windowsapi reloader
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# C:\Users\USER\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3339: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
<!DOCTYPE html>
<html>
  <head>
    {{"decoupled-map"|googlemap_js(37.4419, -122.1419, markers=[(37.4419,
    -122.1419)])}} {{mymap.js}} {{sndmap.js}}
  </head>
  <body>
    <h1>Flask Google Maps Example</h1>

    <h2>Template function centered, no marker</h2>
    {{googlemap("simple-map", 37.4419, -122.1419)}}

    <h2>Template filter decoupled with single marker</h2>
    {{"decoupled-map"|googlemap_html(37.4419, -122.1419)}}

    <h2>Template function with multiple markers</h2>
    {% with map=googlemap_obj("another-map", 37.4419, -122.1419,
    markers=[(37.4419, -122.1419), (37.4300, -122.1400)]) %} {{map.html}}
    {{map.js}} {% endwith %}

    <h2>First map generated in view</h2>
    {{mymap.html}}

    <h2>Second map generated in view</h2>
    <h3>Example for different icons in multiple markers with infoboxes</h3>
    {{sndmap.html}}
  </body>
</html>
# Out:
#   File "<ipython-input-6-553e1de4a8d3>", line 1
#     <!DOCTYPE html>
#     ^
# SyntaxError: invalid syntax

# %%
    Map(
        identifier="catsmap",
        lat=37.4419,
        lng=-122.1419,
        markers=[
            {
                'icon': 'http://maps.google.com/mapfiles/ms/icons/green-dot.png',
                'lat':  37.4419,
                'lng':  -122.1419,
                'infobox': "<img src='cat1.jpg' />"
            },
            {
                'icon': 'http://maps.google.com/mapfiles/ms/icons/blue-dot.png',
                'lat': 37.4300,
                'lng': -122.1400,
                'infobox': "<img src='cat2.jpg' />"
            },
            {
                'icon': 'http://maps.google.com/mapfiles/ms/icons/yellow-dot.png',
                'lat': 37.4500,
                'lng': -122.1350,
                'infobox': "<img src='cat3.jpg' />"
            }
        ]
    )

# %%
@app.route('/map-unbounded/')
def map_unbounded():
"""Create map with markers out of bounds."""
    locations = []    # long list of coordinates
    map = Map(
        lat=locations[0].latitude,
        lng=locations[0].longitude,
        markers=[(loc.latitude, loc.longitude) for loc in locations]
    )
    return render_template('map.html', map=map)
# Out:
#   File "<ipython-input-8-b7aa70ea3fc3>", line 3
#     """Create map with markers out of bounds."""
#                                                ^
# IndentationError: expected an indented block
